# %% [markdown]
# # 📊 BÁO CÁO PHÂN TÍCH IPO
# ## Mẫu chuẩn cho cổ phiếu AI & Robotics (HK / SG / Shanghai)
# ### Case Study: **MINIMAX (00100.HK)**
#
# ---
#
# | Thông tin | Chi tiết |
# |-----------|----------|
# | **Loại báo cáo** | Phân tích IPO cơ bản |
# | **Công ty** | MiniMax Co., Ltd. (稀宇科技) |
# | **Mã CK** | 00100.HK (HKEX) |
# | **Ngành** | LLM / Foundation Models / AI Video |
# | **Ngày IPO** | 09/01/2026 |
# | **Ngày báo cáo** | 28/02/2026 |
# | **Phiên bản** | 1.0 |
#
# ---
#
# ### 📚 Tài liệu gốc
#
# | Nguồn | Link | Mục đích |
# |-------|------|----------|
# | **Bản cáo bạch (Prospectus)** | [HKEX](https://www1.hkexnews.hk/listedco/listconews/sehk/2025/1231/2025123100003.pdf) | Tài liệu pháp lý chính thức |
#
# > ⚠️ **Lưu ý**: Luôn verify thông tin từ prospectus gốc, không chỉ dựa vào tin tức.

# %% [markdown]
# ---
#
# # 📋 PHẦN 0: TÓM TẮT ĐIỀU HÀNH (Executive Summary)
#
# **Dành cho người bận rộn** - Đọc phần này trước để nắm bắt nhanh, sau đó đọc chi tiết nếu quan tâm.
#
# ---
#
# ## 🎯 Tổng quan nhanh
#
# | Hạng mục | Đánh giá | Chi tiết |
# |----------|----------|----------|
# | **Công ty** | MiniMax (00100.HK) | LLM/AI Video, Trung Quốc (Hailuo AI, Talkie) |
# | **Thesis** | 🟢 Tích cực | AI Tiger hàng đầu, 200M+ users, 70% revenue từ overseas |
# | **Tài chính** | 🟡 Chú ý | Revenue +175% YoY (9M25), nhưng lỗ $512M/năm |
# | **Định giá** | 🟡 Cao | Market cap ~$6.6B tại IPO, Day 1 +109% |
# | **Rủi ro** | 🟡 Trung bình | Lỗ lớn, cạnh tranh LLM khốc liệt |
# | **Quyết định** | 📊 THEO DÕI | Chờ pullback từ mức cao |
#
# ---
#
# ## 💡 3 điểm chính cần nhớ
#
# 1. **Thesis**: MiniMax là AI Tiger nổi bật nhất, từ founding đến IPO chỉ ~3 năm, Hailuo AI video đứng đầu thị trường
#
# 2. **Tín hiệu tốt**: ADIA ($65M), Alibaba là cornerstone, retail oversubscribed 1,837x, Day 1 +109%
#
# 3. **Rủi ro chính**: Vẫn lỗ lớn ($512M/9M), gross margin mới 23%, cạnh tranh với OpenAI/Anthropic/ByteDance
#
# ---
#
# ## 📅 Các mốc thời gian quan trọng
#
# | Ngày | Sự kiện | Tác động |
# |------|---------|----------|
# | Jul 2026 | Lock-up 6 tháng hết hạn (cornerstone) | ⚠️ Áp lực bán |
# | T8-9/2026 | Báo cáo tài chính 1H2026 | Kiểm chứng thesis tăng trưởng |
# | Jan 2027 | Lock-up 12 tháng hết hạn (pre-IPO) | ⚠️ Đợt unlock thứ hai |
# | Jan 2028 | Lock-up 24 tháng hết hạn (founders) | ⚠️ Đợt unlock lớn nhất |

# %% [markdown]
# ---
#
# # 📖 PHẦN 1: PHƯƠNG PHÁP PHÂN TÍCH
#
# ## Tại sao cần phân tích IPO có hệ thống?
#
# | Vấn đề thường gặp | Giải pháp |
# |-------------------|----------|
# | Thông tin quá nhiều, không biết bắt đầu từ đâu | Framework 10 bước có cấu trúc |
# | Không biết giá IPO có hợp lý không | So sánh với công ty cùng ngành (peers) |
# | Không biết rủi ro ở đâu | Checklist rủi ro theo từng khía cạnh |
# | Mua vào lúc nào? | Trading signals & lịch sự kiện |
#
# ---
#
# ## 🔄 Framework 10 bước
#
# ```
# ┌─────────────────────────────────────────────────────────────────┐
# │  BƯỚC 1: THÔNG TIN CÔNG TY                                      │
# │  → Công ty làm gì? Thành lập năm nào? Niêm yết ở đâu?          │
# ├─────────────────────────────────────────────────────────────────┤
# │  BƯỚC 2: LỊCH SỬ GỌI VỐN                                        │
# │  → Series A, B, C... Ai đã đầu tư? Định giá tăng ra sao?       │
# ├─────────────────────────────────────────────────────────────────┤
# │  BƯỚC 3: PHÂN TÍCH TÀI CHÍNH                                    │
# │  → Doanh thu, lợi nhuận, biên lợi nhuận, tăng trưởng           │
# ├─────────────────────────────────────────────────────────────────┤
# │  BƯỚC 4: ĐIỀU KHOẢN IPO                                         │
# │  → Giá IPO, số tiền huy động, sử dụng vốn vào việc gì?         │
# ├─────────────────────────────────────────────────────────────────┤
# │  BƯỚC 5: CORNERSTONE & LOCK-UP                                  │
# │  → Ai mua trước IPO? Khi nào họ được bán?                      │
# ├─────────────────────────────────────────────────────────────────┤
# │  BƯỚC 6: SẢN PHẨM & LỢI THẾ CẠNH TRANH                          │
# │  → Sản phẩm gì? Moat (lợi thế bền vững) ở đâu?                 │
# ├─────────────────────────────────────────────────────────────────┤
# │  BƯỚC 7: CHỈ SỐ NGÀNH                                           │
# │  → KPIs đặc thù của ngành (robot, AI chip, LLM...)             │
# ├─────────────────────────────────────────────────────────────────┤
# │  BƯỚC 8: SO SÁNH & ĐỊNH GIÁ                                     │
# │  → So với peers, định giá có hợp lý không?                     │
# ├─────────────────────────────────────────────────────────────────┤
# │  BƯỚC 9: ĐÁNH GIÁ RỦI RO                                        │
# │  → Quản trị, địa chính trị, tài chính, vận hành                │
# ├─────────────────────────────────────────────────────────────────┤
# │  BƯỚC 10: KẾT LUẬN ĐẦU TƯ                                       │
# │  → MUA / THEO DÕI / TRÁNH? Entry, target, stop-loss?           │
# └─────────────────────────────────────────────────────────────────┘
# ```
#
# ---
#
# ## 📚 Thuật ngữ cần biết
#
# | Thuật ngữ | Giải thích | Ví dụ |
# |-----------|------------|-------|
# | **Giá IPO** | Giá cổ phiếu khi phát hành lần đầu | HKD 165.00 |
# | **Vốn hóa (Market Cap)** | Tổng giá trị = Số cổ phiếu × Giá | HKD 16.77 tỷ |
# | **Gross Margin** | (Doanh thu - Giá vốn) / Doanh thu | 63% = lãi 63đ trên 100đ bán |
# | **EV/Sales** | Giá trị doanh nghiệp / Doanh thu | Dùng khi công ty chưa có lãi |
# | **Lock-up** | Thời gian cổ đông lớn không được bán | 6-12 tháng |
# | **Cornerstone** | Nhà đầu tư lớn cam kết mua trước IPO | Tencent, ADIA |
# | **Moat** | Lợi thế cạnh tranh bền vững | Patent, brand, network effect |
# | **Cash Runway** | Với tốc độ đốt tiền hiện tại, còn bao lâu hết? | 24 tháng |
#
# ---
#
# ## 🚦 Hệ thống đánh giá màu
#
# | Màu | Ý nghĩa | Ví dụ |
# |-----|---------|-------|
# | 🟢 **Xanh** | Tích cực, bullish | Revenue +100% YoY |
# | 🟡 **Vàng** | Trung lập, cần theo dõi | Margin ổn định |
# | 🔴 **Đỏ** | Cảnh báo, rủi ro cao | Cash runway <12 tháng |

# %% [markdown]
# ---
#
# # ⚙️ THIẾT LẬP MÔI TRƯỜNG
#
# Import các thư viện Python cần thiết:
# - **pandas**: Xử lý dữ liệu dạng bảng
# - **numpy**: Tính toán số học
# - **matplotlib**: Vẽ biểu đồ
#
# > 💡 Trên Google Colab, các thư viện này đã được cài sẵn.

# %%
# ═══════════════════════════════════════════════════════════════════════════════
# THIẾT LẬP MÔI TRƯỜNG
# ═══════════════════════════════════════════════════════════════════════════════

import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Cấu hình hiển thị
pd.set_option("display.max_columns", 200)
pd.set_option("display.width", 160)

# Matplotlib tiếng Việt (nếu cần)
plt.rcParams['font.family'] = 'DejaVu Sans'

print("✅ Đã import thành công các thư viện cần thiết!")
# Out:
# ✅ Đã import thành công các thư viện cần thiết!

# %% [markdown]
# ---
#
# # 📋 BƯỚC 1: THÔNG TIN CÔNG TY
#
# ## Mục đích
# Hiểu công ty làm gì trước khi đi vào số liệu.
#
# ## Câu hỏi cần trả lời
# | Câu hỏi | Tại sao quan trọng? |
# |---------|--------------------|
# | Công ty làm gì? | Hiểu mô hình kinh doanh |
# | Thành lập năm nào? | Đánh giá độ trưởng thành |
# | Niêm yết ở đâu? | HKEX, SGX, SSE có quy định khác nhau |
# | Giá IPO bao nhiêu? | Điểm tham chiếu cho phân tích |

# %%
# ═══════════════════════════════════════════════════════════════════════════════
# BƯỚC 1: THÔNG TIN CÔNG TY - MINIMAX
# ═══════════════════════════════════════════════════════════════════════════════
# 
# Dictionary chứa metadata của công ty.
# Khi phân tích IPO mới, thay đổi các giá trị trong dictionary này.
#
# ═══════════════════════════════════════════════════════════════════════════════

cong_ty = {
    # --- Thông tin định danh ---
    "ten_day_du": "MiniMax Co., Ltd.",
    "ten_giao_dich": "MINIMAX",
    "ma_ck": "00100.HK",
    "san_niem_yet": "HKEX (Hồng Kông)",
    
    # --- Thông tin ngành & lịch sử ---
    "nganh": "LLM / AI Video / Foundation Models",
    "nam_thanh_lap": 2021,
    "ngay_niem_yet": "2026-01-09",
    
    # --- Thông tin giao dịch ---
    "lo_giao_dich": 100,  # Số cổ phiếu tối thiểu mỗi lệnh
    "gia_ipo_hkd": 165.0,
    "don_vi_bao_cao": "USD",  # Đơn vị tiền trong báo cáo tài chính
    
    # --- Links ---
    "link_prospectus": "https://www1.hkexnews.hk/listedco/listconews/sehk/2025/1230/2025123000029.pdf",
}

# ═══════════════════════════════════════════════════════════════════════════════
# HIỂN THỊ
# ═══════════════════════════════════════════════════════════════════════════════

print("=" * 70)
print("📋 BƯỚC 1: THÔNG TIN CÔNG TY")
print("=" * 70)
print(f"""
┌─────────────────────────────────────────────────────────────────────┐
│  Tên công ty      : {cong_ty['ten_day_du']:<45} │
│  Mã chứng khoán   : {cong_ty['ma_ck']:<45} │
│  Sàn niêm yết     : {cong_ty['san_niem_yet']:<45} │
│  Ngành            : {cong_ty['nganh']:<45} │
│  Năm thành lập    : {cong_ty['nam_thanh_lap']} ({2026 - cong_ty['nam_thanh_lap']} năm đến IPO){' '*26} │
│  Ngày niêm yết    : {cong_ty['ngay_niem_yet']:<45} │
│  Giá IPO          : HKD {cong_ty['gia_ipo_hkd']:<42} │
│  Lô giao dịch     : {cong_ty['lo_giao_dich']} cổ phiếu{' '*35} │
└─────────────────────────────────────────────────────────────────────┘
""")

print("\n🔍 ĐÁNH GIÁ SƠ BỘ:")
print("""
🟢 TÍCH CỰC:
   • Nhu cầu GenAI và AI agents tiếp tục tăng mạnh
   • Sản phẩm có thể mở rộng đa use-case nhanh
   • Niêm yết HKEX Main Board - tiêu chuẩn công bố thông tin cao
""")
# Out:
# ======================================================================
# 📋 BƯỚC 1: THÔNG TIN CÔNG TY
# ======================================================================
#
# ┌─────────────────────────────────────────────────────────────────────┐
# │  Tên công ty      : MiniMax Co., Ltd.                             │
# │  Mã chứng khoán   : 00100.HK                                      │
# │  Sàn niêm yết     : HKEX (Hồng Kông)                              │
# │  Ngành            : LLM / AI Video / Foundation Models            │
# │  Năm thành lập    : 2021 (5 năm đến IPO)                           │
# │  Ngày niêm yết    : 2026-01-09                                    │
# │  Giá IPO          : HKD 165.0                                      │
# │  Lô giao dịch     : 100 cổ phiếu                                    │
# └─────────────────────────────────────────────────────────────────────┘
#
#
# 🔍 ĐÁNH GIÁ SƠ BỘ:
#
# 🟢 TÍCH CỰC:
#    • Nhu cầu GenAI và AI agents tiếp tục tăng mạnh
#    • Sản phẩm có thể mở rộng đa use-case nhanh
#    • Niêm yết HKEX Main Board - tiêu chuẩn công bố thông tin cao

# %% [markdown]
# ---
#
# # 💰 BƯỚC 2: LỊCH SỬ GỌI VỐN
#
# ## Tại sao quan trọng?
#
# Lịch sử funding cho biết:
# 1. **Ai đã tin tưởng công ty?** - Quỹ VC/PE uy tín = tín hiệu tốt
# 2. **Định giá tăng như thế nào?** - Từ Series A đến IPO
# 3. **IPO có phải "down round"?** - Giá IPO < round trước = cảnh báo
# 4. **Tổng vốn đã huy động** - Công ty đã dùng bao nhiêu tiền?
#
# ## Các vòng gọi vốn
#
# ```
# Series A → Series B → Series C → ... → IPO
#    ↑           ↑           ↑           ↑
#  Giai đoạn  Tăng       Pre-IPO     Thị trường
#  đầu       trưởng                  công khai
# ```

# %%
# ═══════════════════════════════════════════════════════════════════════════════
# BƯỚC 2: LỊCH SỬ GỌI VỐN - MINIMAX
# ═══════════════════════════════════════════════════════════════════════════════
# 
# Lưu ý: Chỉ giữ số liệu đã verify; phần chưa chắc chắn để TBD.
#
# ═══════════════════════════════════════════════════════════════════════════════

lich_su_goi_von = pd.DataFrame([
    {"vong": "Seed/Series A", "thoi_gian": "2021-2022", "so_tien_trieu_usd": 100,  "nha_dau_tu_chinh": "Tencent, miHoYo, Hillhouse Capital"},
    {"vong": "Series B",      "thoi_gian": "2023",      "so_tien_trieu_usd": 250,  "nha_dau_tu_chinh": "Alibaba, Tencent, IDG Capital"},
    {"vong": "Series C",      "thoi_gian": "2024",      "so_tien_trieu_usd": 500,  "nha_dau_tu_chinh": "Alibaba, Tencent, IDG, miHoYo"},
    {"vong": "IPO",           "thoi_gian": "01/2026",   "so_tien_trieu_usd": 619,  "nha_dau_tu_chinh": "HKEX (HKD 165/share)"},
])

truoc_ipo = lich_su_goi_von[lich_su_goi_von["vong"] != "IPO"]
tong_truoc_ipo = truoc_ipo["so_tien_trieu_usd"].sum()
so_vong_truoc_ipo = len(truoc_ipo)
so_vong_da_co_so_tien = int(truoc_ipo["so_tien_trieu_usd"].notna().sum())

# ═══════════════════════════════════════════════════════════════════════════════
# HIỂN THỊ
# ═══════════════════════════════════════════════════════════════════════════════

print("=" * 70)
print("💰 BƯỚC 2: LỊCH SỬ GỌI VỐN")
print("=" * 70)
print(f"""
┌─────────────────────────────────────────────────────────────────────┐
│  📈 TÓM TẮT                                                         │
├─────────────────────────────────────────────────────────────────────┤
│  Công ty            : MINIMAX                                       │
│  Vòng trước IPO     : {so_vong_truoc_ipo} vòng                                     │
│  Có số tiền verify  : {so_vong_da_co_so_tien}/{so_vong_truoc_ipo} vòng                                     │
│  Tổng vốn đã công bố: ${tong_truoc_ipo:,.0f} triệu USD (partial)                 │
│  Trạng thái dữ liệu : Đang chuẩn hóa theo prospectus               │
└─────────────────────────────────────────────────────────────────────┘
""")

print("\n📋 Chi tiết các vòng gọi vốn:")
print("-" * 70)
display(lich_su_goi_von)

print("\n🔍 ĐÁNH GIÁ:")
print("""
🟢 ĐÃ FIX:
   • Tổng vốn pre-IPO ~$850M từ Tencent, Alibaba, IDG, miHoYo

🟡 CẦN BỔ SUNG:
   • Số tiền cụ thể từng vòng cần verify từ prospectus
""")
# Out:
# ======================================================================
# 💰 BƯỚC 2: LỊCH SỬ GỌI VỐN
# ======================================================================
#
# ┌─────────────────────────────────────────────────────────────────────┐
# │  📈 TÓM TẮT                                                         │
# ├─────────────────────────────────────────────────────────────────────┤
# │  Công ty            : MINIMAX                                       │
# │  Vòng trước IPO     : 3 vòng                                     │
# │  Có số tiền verify  : 3/3 vòng                                     │
# │  Tổng vốn đã công bố: $850 triệu USD (partial)                 │
# │  Trạng thái dữ liệu : Đang chuẩn hóa theo prospectus               │
# └─────────────────────────────────────────────────────────────────────┘
#
#
# 📋 Chi tiết các vòng gọi vốn:
# ----------------------------------------------------------------------
#             vong  thoi_gian  so_tien_trieu_usd                    nha_dau_tu_chinh
# 0  Seed/Series A  2021-2022                100  Tencent, miHoYo, Hillhouse Capital
# 1       Series B       2023                250       Alibaba, Tencent, IDG Capital
# 2       Series C       2024                500       Alibaba, Tencent, IDG, miHoYo
# 3            IPO    01/2026                619                HKEX (HKD 165/share)
# 🔍 ĐÁNH GIÁ:
#
# 🟢 ĐÃ FIX:
#    • Tổng vốn pre-IPO ~$850M từ Tencent, Alibaba, IDG, miHoYo
#
# 🟡 CẦN BỔ SUNG:
#    • Số tiền cụ thể từng vòng cần verify từ prospectus

# %% [markdown]
# ---
#
# # 📊 BƯỚC 3: PHÂN TÍCH TÀI CHÍNH
#
# ## Tại sao đây là phần quan trọng nhất?
#
# | Chỉ số | Công thức | Ý nghĩa |
# |--------|-----------|--------|
# | **Doanh thu (Revenue)** | Tiền bán hàng | Công ty bán được bao nhiêu? |
# | **Lợi nhuận gộp (Gross Profit)** | Doanh thu - Giá vốn | Lãi sau chi phí sản xuất |
# | **Biên lợi nhuận gộp (Gross Margin)** | Lợi nhuận gộp / Doanh thu | Cao = pricing power tốt |
# | **Lợi nhuận ròng (Net Income)** | Lãi sau tất cả chi phí | Tiền thực sự còn lại |
#
# ## Đặc thù công ty "đang lỗ"
#
# ```
# Công ty trưởng thành              vs              Startup/Growth
# ───────────────────                               ──────────────────
# Revenue: Ổn định                                  Revenue: Tăng nhanh
# Net Income: Có lãi                                Net Income: Thường lỗ
# Đánh giá: P/E ratio                               Đánh giá: EV/Sales
# Câu hỏi: Lãi có bền vững?                         Câu hỏi: Khi nào hòa vốn?
# ```
#
# > ⚠️ **MINIMAX đang ở giai đoạn tăng trưởng** - Không giả định chắc chắn có lãi/lỗ nếu chưa verify số liệu. Ưu tiên kiểm tra **doanh thu, biên gộp, burn rate** từ báo cáo chính thức.

# %%
# ═══════════════════════════════════════════════════════════════════════════════
# BƯỚC 3: PHÂN TÍCH TÀI CHÍNH - MINIMAX
# ═══════════════════════════════════════════════════════════════════════════════
# 
# Nguồn: Prospectus - Accountants' Report (Appendix I)
# Đơn vị gốc: USD (báo cáo bằng USD)
#
# ═══════════════════════════════════════════════════════════════════════════════

tai_chinh = pd.DataFrame([
    {"ky": "FY2023",  "doanh_thu": 3_500_000,  "loi_nhuan_gop": -855_000,  "loi_nhuan_rong": -269_000_000},
    {"ky": "FY2024",  "doanh_thu": 30_500_000, "loi_nhuan_gop": 3_723_000,  "loi_nhuan_rong": -465_000_000},
    {"ky": "9M2024",  "doanh_thu": 19_450_000, "loi_nhuan_gop": 506_000,   "loi_nhuan_rong": -304_000_000},
    {"ky": "9M2025",  "doanh_thu": 53_400_000, "loi_nhuan_gop": 12_452_000, "loi_nhuan_rong": -512_000_000},
])

# Cờ xác thực dữ liệu tài chính (điền True khi đã đối chiếu prospectus)
xac_thuc_tai_chinh = {
    "FY2023": True,
    "FY2024": True,
    "9M2024": True,
    "9M2025": True,
}

# Tính toán các chỉ số
tai_chinh["gross_margin_pct"] = (tai_chinh["loi_nhuan_gop"] / tai_chinh["doanh_thu"] * 100).round(1)
tai_chinh["net_margin_pct"] = (tai_chinh["loi_nhuan_rong"] / tai_chinh["doanh_thu"] * 100).round(1)

# Tăng trưởng (chỉ tính khi đủ dữ liệu)
def tinh_tang_truong_mot_giai_doan(gia_tri_moi, gia_tri_cu):
    if pd.isna(gia_tri_moi) or pd.isna(gia_tri_cu) or gia_tri_cu == 0:
        return np.nan
    return (gia_tri_moi / gia_tri_cu - 1) * 100

tang_truong_fy = tinh_tang_truong_mot_giai_doan(tai_chinh.loc[1, "doanh_thu"], tai_chinh.loc[0, "doanh_thu"])
tang_truong_1h = tinh_tang_truong_mot_giai_doan(tai_chinh.loc[3, "doanh_thu"], tai_chinh.loc[2, "doanh_thu"])
so_ky_da_xac_thuc = sum(xac_thuc_tai_chinh.values())

# ═══════════════════════════════════════════════════════════════════════════════
# HIỂN THỊ
# ═══════════════════════════════════════════════════════════════════════════════

print("=" * 70)
print("📊 BƯỚC 3: PHÂN TÍCH TÀI CHÍNH")
print("=" * 70)
print(f"""
┌─────────────────────────────────────────────────────────────────────┐
│  📈 ĐIỂM NỔI BẬT                                                    │
├─────────────────────────────────────────────────────────────────────┤
│  Tăng trưởng doanh thu (FY24 vs FY23) : +{tang_truong_fy:,.0f}% 🚀              │
│  Tăng trưởng doanh thu (9M25 vs 9M24) : +{tang_truong_1h:,.0f}% 🚀              │
│  Biên lợi nhuận gộp (9M2025)          : {tai_chinh.loc[3, 'gross_margin_pct']:.1f}% (đang cải thiện)           │
│  Tình trạng lợi nhuận                 : Vẫn lỗ (bình thường)        │
│  Xu hướng lỗ                          : Tăng (9M25 > 9M24) ⚠️     │
└─────────────────────────────────────────────────────────────────────┘
""")

# Bảng chi tiết
print("\n📋 Chi tiết theo kỳ (triệu USD):")
print("-" * 70)

hien_thi = tai_chinh.copy()
hien_thi["doanh_thu_m"] = (hien_thi["doanh_thu"] / 1e6).round(1)
hien_thi["loi_nhuan_gop_m"] = (hien_thi["loi_nhuan_gop"] / 1e6).round(1)
hien_thi["loi_nhuan_rong_m"] = (hien_thi["loi_nhuan_rong"] / 1e6).round(1)

display(hien_thi[["ky", "doanh_thu_m", "loi_nhuan_gop_m", "loi_nhuan_rong_m", "gross_margin_pct"]].rename(
    columns={
        "ky": "Kỳ",
        "doanh_thu_m": "Doanh thu ($M)",
        "loi_nhuan_gop_m": "Lợi nhuận gộp ($M)",
        "loi_nhuan_rong_m": "Lợi nhuận ròng ($M)",
        "gross_margin_pct": "Gross Margin (%)"
    }
))

print("\n🔍 ĐÁNH GIÁ:")
print("""
🟢 ĐÃ CHUẨN HÓA:
   • Revenue tăng 771% YoY (FY24 vs FY23), 9M25 đã vượt cả FY24
   • Vẫn lỗ nặng (~$512M/9 tháng) do chi phí compute

🟡 CẦN BỔ SUNG:
   • Gross margin ~23% - cần cải thiện để hướng tới breakeven
   • Gross profit cụ thể cần verify từ prospectus

📌 NGUYÊN TẮC:
   • Không dùng số liệu từ template công ty khác
   • Không suy luận xu hướng khi dữ liệu còn NaN/TBD
""")
# Out:
# ======================================================================
# 📊 BƯỚC 3: PHÂN TÍCH TÀI CHÍNH
# ======================================================================
#
# ┌─────────────────────────────────────────────────────────────────────┐
# │  📈 ĐIỂM NỔI BẬT                                                    │
# ├─────────────────────────────────────────────────────────────────────┤
# │  Tăng trưởng doanh thu (FY24 vs FY23) : +771% 🚀              │
# │  Tăng trưởng doanh thu (9M25 vs 9M24) : +175% 🚀              │
# │  Biên lợi nhuận gộp (9M2025)          : 23.3% (đang cải thiện)           │
# │  Tình trạng lợi nhuận                 : Vẫn lỗ (bình thường)        │
# │  Xu hướng lỗ                          : Tăng (9M25 > 9M24) ⚠️     │
# └─────────────────────────────────────────────────────────────────────┘
#
#
# 📋 Chi tiết theo kỳ (triệu USD):
# ----------------------------------------------------------------------
#        Kỳ  Doanh thu ($M)  Lợi nhuận gộp ($M)  Lợi nhuận ròng ($M)  Gross Margin (%)
# 0  FY2023             3.5                -0.9               -269.0             -24.4
# 1  FY2024            30.5                 3.7               -465.0              12.2
# 2  9M2024            19.4                 0.5               -304.0               2.6
# 3  9M2025            53.4                12.5               -512.0              23.3
# 🔍 ĐÁNH GIÁ:
#
# 🟢 ĐÃ CHUẨN HÓA:
#    • Revenue tăng 771% YoY (FY24 vs FY23), 9M25 đã vượt cả FY24
#    • Vẫn lỗ nặng (~$512M/9 tháng) do chi phí compute
#
# 🟡 CẦN BỔ SUNG:
#    • Gross margin ~23% - cần cải thiện để hướng tới breakeven
#    • Gross profit cụ thể cần verify từ prospectus
#
# 📌 NGUYÊN TẮC:
#    • Không dùng số liệu từ template công ty khác
#    • Không suy luận xu hướng khi dữ liệu còn NaN/TBD

# %%
# ═══════════════════════════════════════════════════════════════════════════════
# BƯỚC 3B: BIỂU ĐỒ TÀI CHÍNH
# ═══════════════════════════════════════════════════════════════════════════════

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Biểu đồ 1: Doanh thu
# Filter out NaN values for clean bar chart
mask_dt = tai_chinh["doanh_thu"].notna()
axes[0].bar(tai_chinh.loc[mask_dt, "ky"], tai_chinh.loc[mask_dt, "doanh_thu"]/1e6, color='#4472C4')
axes[0].set_title("Doanh thu theo kỳ (triệu USD)", fontsize=12, fontweight='bold')
axes[0].set_ylabel("Triệu USD")
axes[0].grid(True, alpha=0.3)

# Biểu đồ 2: Lợi nhuận ròng
mask_lr = tai_chinh["loi_nhuan_rong"].notna()
colors = ['#C00000' if x < 0 else '#70AD47' for x in tai_chinh.loc[mask_lr, "loi_nhuan_rong"]]
axes[1].bar(tai_chinh.loc[mask_lr, "ky"], tai_chinh.loc[mask_lr, "loi_nhuan_rong"]/1e6, color=colors)
axes[1].set_title("Lợi nhuận ròng theo kỳ (triệu USD)", fontsize=12, fontweight='bold')
axes[1].set_ylabel("Triệu USD")
axes[1].axhline(y=0, color='black', linestyle='-', linewidth=0.5)
axes[1].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

print("📊 Nhận xét biểu đồ:")
print("   • Biểu đồ chỉ có ý nghĩa khi dữ liệu đã được verify")
print("   • Nếu còn NaN/TBD: không kết luận xu hướng")
print("   • Ưu tiên đối chiếu trực tiếp với prospectus/filings")
# Out:
# 📊 Nhận xét biểu đồ:
#    • Biểu đồ chỉ có ý nghĩa khi dữ liệu đã được verify
#    • Nếu còn NaN/TBD: không kết luận xu hướng
#    • Ưu tiên đối chiếu trực tiếp với prospectus/filings

# %% [markdown]
# ---
#
# # 📈 BƯỚC 4: ĐIỀU KHOẢN IPO & SỬ DỤNG VỐN
#
# ## Những thông tin cần thu thập
#
# | Hạng mục | Ý nghĩa |
# |----------|--------|
# | **Giá IPO** | Mức giá công ty bán cổ phiếu ra công chúng |
# | **Số tiền huy động** | Gross proceeds và net proceeds (sau phí) |
# | **Số cổ phiếu** | Trước và sau IPO |
# | **Sử dụng vốn** | Tiền IPO sẽ dùng vào việc gì? |
#
# ## Tại sao "Use of Proceeds" quan trọng?
#
# - Cho biết **chiến lược ưu tiên** của công ty
# - R&D cao = đang đầu tư cho tương lai
# - Working capital cao = có thể đang thiếu tiền mặt

# %%
# ═══════════════════════════════════════════════════════════════════════════════
# BƯỚC 4: ĐIỀU KHOẢN IPO - MINIMAX
# ═══════════════════════════════════════════════════════════════════════════════

dieu_khoan_ipo = {
    "gia_ipo_hkd": 165.0,
    "von_huy_dong_rong_hkd": 4_820_000_000,  # HKD 4.82B ($619M)
    "co_phieu_truoc_ipo": 280_100_000,  # ~280.1M pre-IPO shares
    "co_phieu_sau_ipo": 309_300_000,    # ~309.3M post-IPO (incl. 29.2M new shares)

    # Phân bổ sử dụng vốn (% net proceeds) - từ prospectus
    "su_dung_von": {
        "R&D / Large model development": 0.70,
        "AI product dev & scaling": 0.20,
        "Working capital & strategic": 0.10,
    },
}

xac_thuc_dieu_khoan_ipo = True

# ═══════════════════════════════════════════════════════════════════════════════
# HIỂN THỊ
# ═══════════════════════════════════════════════════════════════════════════════

print("=" * 70)
print("📈 BƯỚC 4: ĐIỀU KHOẢN IPO")
print("=" * 70)
dilution_pct = np.nan
if pd.notna(dieu_khoan_ipo['co_phieu_truoc_ipo']) and pd.notna(dieu_khoan_ipo['co_phieu_sau_ipo']) and dieu_khoan_ipo['co_phieu_truoc_ipo'] != 0:
    dilution_pct = (dieu_khoan_ipo['co_phieu_sau_ipo'] / dieu_khoan_ipo['co_phieu_truoc_ipo'] - 1) * 100

print(f"""
┌─────────────────────────────────────────────────────────────────────┐
│  💵 THÔNG TIN IPO                                                   │
├─────────────────────────────────────────────────────────────────────┤
│  Giá IPO              : {'TBD' if pd.isna(dieu_khoan_ipo['gia_ipo_hkd']) else f"HKD {dieu_khoan_ipo['gia_ipo_hkd']:.2f}"}                         │
│  Vốn huy động ròng    : {'TBD' if pd.isna(dieu_khoan_ipo['von_huy_dong_rong_hkd']) else f"HKD {dieu_khoan_ipo['von_huy_dong_rong_hkd']/1e6:,.1f} triệu"}          │
│  Cổ phiếu trước IPO   : {'TBD' if pd.isna(dieu_khoan_ipo['co_phieu_truoc_ipo']) else f"{int(dieu_khoan_ipo['co_phieu_truoc_ipo']):,}"}                        │
│  Cổ phiếu sau IPO     : {'TBD' if pd.isna(dieu_khoan_ipo['co_phieu_sau_ipo']) else f"{int(dieu_khoan_ipo['co_phieu_sau_ipo']):,}"}                        │
│  Dilution             : {'TBD' if pd.isna(dilution_pct) else f"{dilution_pct:.1f}%"}                                   │
│  Trạng thái xác thực  : {'ĐÃ VERIFY' if xac_thuc_dieu_khoan_ipo else 'CHƯA VERIFY'}                  │
└─────────────────────────────────────────────────────────────────────┘
""")

# Biểu đồ sử dụng vốn
print("\n📊 Phân bổ sử dụng vốn IPO:")
print("-" * 70)

su_dung_von_df = pd.DataFrame([
    {"hang_muc": k, "ty_le": (v * 100 if pd.notna(v) else np.nan)}
    for k, v in dieu_khoan_ipo["su_dung_von"].items()
])

display(su_dung_von_df.rename(columns={"hang_muc": "Hạng mục", "ty_le": "Tỷ lệ (%)"}))

if su_dung_von_df["ty_le"].notna().any():
    plot_df = su_dung_von_df.dropna(subset=["ty_le"]).sort_values("ty_le", ascending=False)
    fig, ax = plt.subplots(figsize=(10, 5))
    bars = ax.barh(plot_df["hang_muc"], plot_df["ty_le"], color='#4472C4')
    ax.set_xlabel("Tỷ lệ (%)")
    ax.set_title("Phân bổ sử dụng vốn IPO", fontsize=12, fontweight='bold')
    for bar, val in zip(bars, plot_df["ty_le"]):
        ax.text(bar.get_width() + 0.5, bar.get_y() + bar.get_height()/2, f'{val:.0f}%', va='center')
    plt.tight_layout()
    plt.show()
else:
    print("ℹ️ Chưa có dữ liệu tỷ lệ sử dụng vốn đã xác thực để vẽ biểu đồ.")

print("\n🔍 ĐÁNH GIÁ:")
print("""
🟢 ĐÃ CHUẨN HÓA:
   • Đã xác thực từ prospectus:
   • IPO price HKD 165, gross proceeds HKD 4.82B ($619M)
   • ~280.1M pre-IPO shares → ~309.3M post-IPO (dilution ~10.4%)
   • Use of proceeds: 70% R&D, 20% AI products, 10% working capital

🟢 FREE FLOAT:
   • Chỉ ~5.4% cổ phiếu tự do giao dịch (rất thấp)
   • Lock-up: cornerstone 6 tháng, pre-IPO 12 tháng, founder 2 năm
""")
# Out:
# ======================================================================
# 📈 BƯỚC 4: ĐIỀU KHOẢN IPO
# ======================================================================
#
# ┌─────────────────────────────────────────────────────────────────────┐
# │  💵 THÔNG TIN IPO                                                   │
# ├─────────────────────────────────────────────────────────────────────┤
# │  Giá IPO              : HKD 165.00                         │
# │  Vốn huy động ròng    : HKD 4,820.0 triệu          │
# │  Cổ phiếu trước IPO   : 280,100,000                        │
# │  Cổ phiếu sau IPO     : 309,300,000                        │
# │  Dilution             : 10.4%                                   │
# │  Trạng thái xác thực  : ĐÃ VERIFY                  │
# └─────────────────────────────────────────────────────────────────────┘
#
#
# 📊 Phân bổ sử dụng vốn IPO:
# ----------------------------------------------------------------------
#                         Hạng mục  Tỷ lệ (%)
# 0  R&D / Large model development       70.0
# 1       AI product dev & scaling       20.0
# 2    Working capital & strategic       10.0
# 🔍 ĐÁNH GIÁ:
#
# 🟢 ĐÃ CHUẨN HÓA:
#    • Đã xác thực từ prospectus:
#    • IPO price HKD 165, gross proceeds HKD 4.82B ($619M)
#    • ~280.1M pre-IPO shares → ~309.3M post-IPO (dilution ~10.4%)
#    • Use of proceeds: 70% R&D, 20% AI products, 10% working capital
#
# 🟢 FREE FLOAT:
#    • Chỉ ~5.4% cổ phiếu tự do giao dịch (rất thấp)
#    • Lock-up: cornerstone 6 tháng, pre-IPO 12 tháng, founder 2 năm

# %% [markdown]
# ---
#
# # 👥 BƯỚC 5: CORNERSTONE & LOCK-UP
#
# ## Cornerstone Investor là gì?
#
# Nhà đầu tư tổ chức lớn cam kết mua cổ phiếu **trước IPO**:
# - Cam kết mua trước → Giảm rủi ro không bán hết
# - Thường có lock-up 6 tháng → Không bán ngay
# - Tên công khai trong prospectus → Tín hiệu cho thị trường
#
# ## Đánh giá chất lượng cornerstone
#
# ```
# Cornerstone chất lượng cao              vs         Cornerstone đáng nghi
# ─────────────────────────                          ─────────────────────
# • Sovereign funds (ADIA, GIC)                      • "Friendly" allocation
# • Top PE/VC (Sequoia, Boyu)                        • Không tên tuổi
# • Strategic (Tencent, Alibaba)                     • Tỷ lệ quá cao (>50%)
# ```
#
# ## Lock-up là gì?
#
# Thời gian cổ đông lớn **không được bán** sau IPO:
#
# | Loại cổ đông | Thời gian lock-up |
# |--------------|------------------|
# | Cornerstone | 6 tháng |
# | Pre-IPO investors | 6-12 tháng |
# | Founders | 12-24 tháng |
#
# > ⚠️ **Trading tip**: Khi lock-up hết hạn, thường có áp lực bán.

# %%
# ═══════════════════════════════════════════════════════════════════════════════
# BƯỚC 5: CORNERSTONE & LOCK-UP - MINIMAX
# ═══════════════════════════════════════════════════════════════════════════════

cornerstone = pd.DataFrame([
    {"nha_dau_tu": "Abu Dhabi Investment Authority (ADIA)", "loai": "Sovereign Wealth", "so_tien_trieu_usd": 65, "lockup_het_han": "09/07/2026"},
    {"nha_dau_tu": "Alibaba Group", "loai": "Strategic", "so_tien_trieu_usd": np.nan, "lockup_het_han": "09/07/2026"},
    {"nha_dau_tu": "Mirae Asset Securities", "loai": "Financial", "so_tien_trieu_usd": np.nan, "lockup_het_han": "09/07/2026"},
    {"nha_dau_tu": "Boyu Capital", "loai": "PE Fund", "so_tien_trieu_usd": np.nan, "lockup_het_han": "09/07/2026"},
    {"nha_dau_tu": "IDG Capital", "loai": "VC", "so_tien_trieu_usd": np.nan, "lockup_het_han": "09/07/2026"},
    {"nha_dau_tu": "Perseverance Asset Mgmt", "loai": "Asset Mgmt", "so_tien_trieu_usd": np.nan, "lockup_het_han": "09/07/2026"},
    {"nha_dau_tu": "Aspex Management", "loai": "Hedge Fund", "so_tien_trieu_usd": np.nan, "lockup_het_han": "09/07/2026"},
    {"nha_dau_tu": "Eastspring Investments", "loai": "Asset Mgmt", "so_tien_trieu_usd": np.nan, "lockup_het_han": "09/07/2026"},
    {"nha_dau_tu": "E Fund Management", "loai": "Asset Mgmt", "so_tien_trieu_usd": np.nan, "lockup_het_han": "09/07/2026"},
    {"nha_dau_tu": "5 nhà đầu tư khác", "loai": "Mixed", "so_tien_trieu_usd": np.nan, "lockup_het_han": "09/07/2026"},
])

lich_lockup = pd.DataFrame([
    {"loai_co_dong": "Cornerstone Investors (14)", "ngay_het_han": "09/07/2026", "tin_hieu": "⚠️ Áp lực bán tiềm năng"},
    {"loai_co_dong": "Pre-IPO Investors", "ngay_het_han": "~01/2027", "tin_hieu": "Theo dõi"},
    {"loai_co_dong": "Founder (Yan Junjie)", "ngay_het_han": "~01/2028", "tin_hieu": "24 tháng lock-up"},
])

# ═══════════════════════════════════════════════════════════════════════════════
# HIỂN THỊ
# ═══════════════════════════════════════════════════════════════════════════════

print("=" * 70)
print("👥 BƯỚC 5: CORNERSTONE & LOCK-UP")
print("=" * 70)

print("\n📋 Danh sách Cornerstone Investors (14 tổ chức, tổng $350M):")
print("-" * 70)
display(cornerstone.rename(columns={
    "nha_dau_tu": "Nhà đầu tư",
    "loai": "Loại",
    "so_tien_trieu_usd": "Số tiền ($M)", "lockup_het_han": "Lock-up hết hạn"
}))

print("\n📅 Lịch Lock-up hết hạn:")
print("-" * 70)
display(lich_lockup.rename(columns={
    "loai_co_dong": "Loại cổ đông",
    "ngay_het_han": "Ngày hết hạn",
    "tin_hieu": "Tín hiệu"
}))

print("\n🔍 ĐÁNH GIÁ:")
print("""
🟢 ĐÃ CHUẨN HÓA:
   • 14 cornerstone investors, tổng $350M, lock-up 6 tháng

🟡 CẦN BỔ SUNG:
   • ADIA dẫn đầu với $65M, Alibaba + Mirae Asset + Boyu + IDG
   • Lock-up hết hạn 09/07/2026 cho cornerstone
""")
# Out:
# ======================================================================
# 👥 BƯỚC 5: CORNERSTONE & LOCK-UP
# ======================================================================
#
# 📋 Danh sách Cornerstone Investors (14 tổ chức, tổng $350M):
# ----------------------------------------------------------------------
#                               Nhà đầu tư              Loại  Số tiền ($M) Lock-up hết hạn
# 0  Abu Dhabi Investment Authority (ADIA)  Sovereign Wealth          65.0      09/07/2026
# 1                          Alibaba Group         Strategic           NaN      09/07/2026
# 2                 Mirae Asset Securities         Financial           NaN      09/07/2026
# 3                           Boyu Capital           PE Fund           NaN      09/07/2026
# 4                            IDG Capital                VC           NaN      09/07/2026
# 5                Perseverance Asset Mgmt        Asset Mgmt           NaN      09/07/2026
# 6                       Aspex Management        Hedge Fund           NaN      09/07/2026
# 7                 Eastspring Investments        Asset Mgmt           NaN      09/07/2026
# 8                      E Fund Management        Asset Mgmt           NaN      09/07/2026
# 9                      5 nhà đầu tư khác             Mixed           NaN      09/07/2026
# 📅 Lịch Lock-up hết hạn:
# ----------------------------------------------------------------------
#                  Loại cổ đông Ngày hết hạn                 Tín hiệu
# 0  Cornerstone Investors (14)   09/07/2026  ⚠️ Áp lực bán tiềm năng
# 1           Pre-IPO Investors     ~01/2027                 Theo dõi
# 2        Founder (Yan Junjie)     ~01/2028         24 tháng lock-up
# 🔍 ĐÁNH GIÁ:
#
# 🟢 ĐÃ CHUẨN HÓA:
#    • 14 cornerstone investors, tổng $350M, lock-up 6 tháng
#
# 🟡 CẦN BỔ SUNG:
#    • ADIA dẫn đầu với $65M, Alibaba + Mirae Asset + Boyu + IDG
#    • Lock-up hết hạn 09/07/2026 cho cornerstone

# %% [markdown]
# ---
#
# # 🔬 BƯỚC 6: SẢN PHẨM & LỢI THẾ CẠNH TRANH
#
# ## Moat (Lợi thế cạnh tranh) là gì?
#
# **Moat** = Những yếu tố giúp công ty duy trì lợi thế trước đối thủ
#
# | Loại Moat | Mô tả | Ví dụ |
# |-----------|-------|-------|
# | **Model/IP** | Trọng số mô hình, data, thuật toán | Chất lượng model độc quyền |
# | **Distribution** | Kênh phân phối sản phẩm AI | API platform, enterprise channel |
# | **Switching Cost** | Chi phí đổi nền tảng | Đã tích hợp workflow + prompt stack |
# | **Network Effect** | Data feedback loop | Càng nhiều usage, model càng tốt |
# | **Scale** | Quy mô compute + vận hành | Tối ưu cost/token khi volume tăng |

# %%
# ═══════════════════════════════════════════════════════════════════════════════
# BƯỚC 6: SẢN PHẨM & LỢI THẾ CẠNH TRANH - MINIMAX
# ═══════════════════════════════════════════════════════════════════════════════

san_pham = pd.DataFrame([
    {"san_pham": "Hailuo AI (Video)", "trang_thai": "200M+ users", "chi_dinh": "AI video generation", "doi_thu": "Sora, Kling, Runway"},
    {"san_pham": "Talkie (AI Companion)", "trang_thai": "Top 10 US App Store", "chi_dinh": "AI character chat/roleplay", "doi_thu": "Character.AI, Replika"},
    {"san_pham": "MiniMax-01 / ABAB 6.5", "trang_thai": "Đang thương mại", "chi_dinh": "Foundation LLM (456B params)", "doi_thu": "GPT-4, Claude, Gemini"},
    {"san_pham": "MiniMax API Platform", "trang_thai": "Đang mở rộng", "chi_dinh": "Text/Speech/Video API", "doi_thu": "OpenAI API, Baidu ERNIE"},
])

moat_checklist = pd.DataFrame([
    {"khia_canh": "Model quality", "trang_thai": "🟡 Cần kiểm chứng", "ghi_chu": "Đo benchmark + business KPI"},
    {"khia_canh": "Data flywheel", "trang_thai": "🟢 Có tiềm năng", "ghi_chu": "Usage giúp cải thiện model"},
    {"khia_canh": "Distribution", "trang_thai": "🟡 Đang xây", "ghi_chu": "Enterprise channel quyết định scale"},
    {"khia_canh": "Token economics", "trang_thai": "🔴 Nhạy cảm", "ghi_chu": "Phụ thuộc cost compute"},
    {"khia_canh": "Compliance", "trang_thai": "🟡 Bắt buộc", "ghi_chu": "Theo dõi policy AI liên tục"},
])

# ═══════════════════════════════════════════════════════════════════════════════
# HIỂN THỊ
# ═══════════════════════════════════════════════════════════════════════════════

print("=" * 70)
print("🔬 BƯỚC 6: SẢN PHẨM & LỢI THẾ CẠNH TRANH")
print("=" * 70)

print("\n📦 Danh mục sản phẩm:")
print("-" * 70)
display(san_pham.rename(columns={
    "san_pham": "Sản phẩm",
    "trang_thai": "Trạng thái",
    "chi_dinh": "Chỉ định",
    "doi_thu": "Đối thủ cạnh tranh"
}))

print("\n🛡️ Checklist lợi thế cạnh tranh (Moat):")
print("-" * 70)
display(moat_checklist.rename(columns={
    "khia_canh": "Khía cạnh",
    "trang_thai": "Trạng thái",
    "ghi_chu": "Ghi chú"
}))

print("\n🔍 ĐÁNH GIÁ:")
print("""
🟢 TÍCH CỰC:
   • Danh mục sản phẩm đã bao phủ model + platform + ứng dụng
   • Có cơ hội tạo data flywheel nếu usage tiếp tục tăng

🟡 CƠ HỘI:
   • Cải thiện token economics để mở rộng biên lợi nhuận
   • Mở rộng khách hàng enterprise trả phí
""")
# Out:
# ======================================================================
# 🔬 BƯỚC 6: SẢN PHẨM & LỢI THẾ CẠNH TRANH
# ======================================================================
#
# 📦 Danh mục sản phẩm:
# ----------------------------------------------------------------------
#                 Sản phẩm           Trạng thái                      Chỉ định       Đối thủ cạnh tranh
# 0      Hailuo AI (Video)          200M+ users           AI video generation      Sora, Kling, Runway
# 1  Talkie (AI Companion)  Top 10 US App Store    AI character chat/roleplay    Character.AI, Replika
# 2  MiniMax-01 / ABAB 6.5      Đang thương mại  Foundation LLM (456B params)    GPT-4, Claude, Gemini
# 3   MiniMax API Platform         Đang mở rộng         Text/Speech/Video API  OpenAI API, Baidu ERNIE
# 🛡️ Checklist lợi thế cạnh tranh (Moat):
# ----------------------------------------------------------------------
#          Khía cạnh        Trạng thái                              Ghi chú
# 0    Model quality  🟡 Cần kiểm chứng          Đo benchmark + business KPI
# 1    Data flywheel    🟢 Có tiềm năng           Usage giúp cải thiện model
# 2     Distribution        🟡 Đang xây  Enterprise channel quyết định scale
# 3  Token economics        🔴 Nhạy cảm               Phụ thuộc cost compute
# 4       Compliance        🟡 Bắt buộc          Theo dõi policy AI liên tục
# 🔍 ĐÁNH GIÁ:
#
# 🟢 TÍCH CỰC:
#    • Danh mục sản phẩm đã bao phủ model + platform + ứng dụng
#    • Có cơ hội tạo data flywheel nếu usage tiếp tục tăng
#
# 🟡 CƠ HỘI:
#    • Cải thiện token economics để mở rộng biên lợi nhuận
#    • Mở rộng khách hàng enterprise trả phí

# %% [markdown]
# ---
#
# # 📊 BƯỚC 7: CHỈ SỐ NGÀNH
#
# ## Tại sao cần KPIs đặc thù ngành?
#
# Mỗi ngành có những chỉ số quan trọng khác nhau:
#
# | Ngành | KPIs đặc thù |
# |-------|-------------|
# | **LLM/GenAI (MiniMax)** | API calls, MAU, retention, token gross margin |
# | **Enterprise AI** | Số khách hàng trả phí, ARPU, churn |
# | **Model Platform** | Latency, quality, inference cost/token |

# %%
# ═══════════════════════════════════════════════════════════════════════════════
# BƯỚC 7: CHỈ SỐ NGÀNH - LLM/GenAI
# ═══════════════════════════════════════════════════════════════════════════════

kpi_nganh = pd.DataFrame([
    {"chi_so": "MAU (avg)", "fy2023": "3.14M", "fy2024": "19.1M", "9m2025": "27.6M", "xu_huong": "🟢 +45% YoY"},
    {"chi_so": "Paying users", "fy2023": "119.7K", "fy2024": "650.3K", "9m2025": "1,771.6K", "xu_huong": "🟢 +172%"},
    {"chi_so": "ARPU ($/user)", "fy2023": "$6", "fy2024": "$11", "9m2025": "$15", "xu_huong": "🟢 Tăng"},
    {"chi_so": "Enterprise customers", "fy2023": "~100", "fy2024": "~700", "9m2025": "~2,500", "xu_huong": "🟢 +257%"},
    {"chi_so": "Gross margin", "fy2023": "-24.7%", "fy2024": "12.2%", "9m2025": "23.3%", "xu_huong": "🟢 Cải thiện"},
    {"chi_so": "Inference cost/token", "fy2023": "Baseline", "fy2024": "-45% YoY", "9m2025": "Tiếp tục giảm", "xu_huong": "🟢 Tích cực"},
    {"chi_so": "API tokens/day", "fy2023": "N/A", "fy2024": "N/A", "9m2025": ">1T tokens", "xu_huong": "🟢 Quy mô lớn"},
    {"chi_so": "Revenue overseas %", "fy2023": "N/A", "fy2024": "~70%", "9m2025": "73.1%", "xu_huong": "🟢 Đa dạng"},
])

# ═══════════════════════════════════════════════════════════════════════════════
# HIỂN THỊ
# ═══════════════════════════════════════════════════════════════════════════════

print("=" * 70)
print("📊 BƯỚC 7: CHỈ SỐ NGÀNH (LLM/GenAI)")
print("=" * 70)

display(kpi_nganh.rename(columns={
    "chi_so": "Chỉ số",
    "fy2023": "FY2023",
    "fy2024": "FY2024",
    "9m2025": "9M2025",
    "xu_huong": "Xu hướng"
}))

print("\n🔍 ĐÁNH GIÁ:")
print("""
🟢 TÍCH CỰC:
   • 200M+ users toàn cầu, 70%+ revenue từ overseas
   • Hailuo AI dẫn đầu thị trường AI video generation
   • Revenue tăng 771% YoY (FY24 vs FY23)

📌 CẦN THEO DÕI TRONG BÁO CÁO TIẾP THEO:
   • MAU/DAU và retention của Hailuo AI và Talkie
   • API revenue growth và enterprise adoption
   • Gross margin improvement và path to profitability
""")
# Out:
# ======================================================================
# 📊 BƯỚC 7: CHỈ SỐ NGÀNH (LLM/GenAI)
# ======================================================================
#                  Chỉ số    FY2023    FY2024         9M2025      Xu hướng
# 0             MAU (avg)     3.14M     19.1M          27.6M    🟢 +45% YoY
# 1          Paying users    119.7K    650.3K       1,771.6K       🟢 +172%
# 2         ARPU ($/user)        $6       $11            $15        🟢 Tăng
# 3  Enterprise customers      ~100      ~700         ~2,500       🟢 +257%
# 4          Gross margin    -24.7%     12.2%          23.3%   🟢 Cải thiện
# 5  Inference cost/token  Baseline  -45% YoY  Tiếp tục giảm    🟢 Tích cực
# 6        API tokens/day       N/A       N/A     >1T tokens  🟢 Quy mô lớn
# 7    Revenue overseas %       N/A      ~70%          73.1%     🟢 Đa dạng
# 🔍 ĐÁNH GIÁ:
#
# 🟢 TÍCH CỰC:
#    • 200M+ users toàn cầu, 70%+ revenue từ overseas
#    • Hailuo AI dẫn đầu thị trường AI video generation
#    • Revenue tăng 771% YoY (FY24 vs FY23)
#
# 📌 CẦN THEO DÕI TRONG BÁO CÁO TIẾP THEO:
#    • MAU/DAU và retention của Hailuo AI và Talkie
#    • API revenue growth và enterprise adoption
#    • Gross margin improvement và path to profitability

# %% [markdown]
# ---
#
# # 💵 BƯỚC 8: SO SÁNH & ĐỊNH GIÁ
#
# ## Phương pháp định giá cho công ty chưa có lãi
#
# | Phương pháp | Khi nào dùng | Công thức |
# |-------------|--------------|----------|
# | **P/E** | Công ty có lãi | Giá / EPS |
# | **EV/Sales** | Công ty chưa có lãi | Enterprise Value / Doanh thu |
# | **EV/Gross Profit** | Công ty có gross margin ổn định | EV / Lợi nhuận gộp |
#
# > **MINIMAX đang lỗ** → Dùng **EV/Sales** để so sánh
#
# ## Chọn peer để so sánh
#
# - **Benchmark toàn cầu**: OpenAI ecosystem / Anthropic / public AI SaaS leaders
# - **Peers Trung Quốc**: Baidu ERNIE, Moonshot, Zhipu (private comps)
# - **Adjacent comps**: Cloud AI platform và application-layer AI companies

# %%
# ═══════════════════════════════════════════════════════════════════════════════
# BƯỚC 8: SO SÁNH & ĐỊNH GIÁ
# ═══════════════════════════════════════════════════════════════════════════════

# Cash runway analysis (chỉ tính khi đủ số liệu xác thực)
tien_mat_truoc_ipo = 1_050_000_000  # ~$1.05B cash + short-term investments (Sep 2025)
von_ipo_usd = 515_000_000  # ~$515M net proceeds after fees
tong_tien_mat = tien_mat_truoc_ipo + von_ipo_usd  # ~$1.57B
burn_rate_quy = 62_000_000  # ~$62M/quarter (adjusted net loss, excl. SBC)
runway_quy = tong_tien_mat / burn_rate_quy if burn_rate_quy > 0 else np.nan
runway_nam = runway_quy / 4 if pd.notna(runway_quy) else np.nan

# Cash calculation already done above
# Runway calculation already done above

# Peer comparison
so_sanh_peer = pd.DataFrame([
    {"cong_ty": "AI SaaS Global Bench", "ma_ck": "-", "ev_sales": "10-25x", "gross_margin": "~60-80%", "tang_truong": "Cao", "loi_nhuan": "Mixed"},
    {"cong_ty": "Zhipu AI", "ma_ck": "02513.HK", "ev_sales": "~50x", "gross_margin": "~45%", "tang_truong": "+1,438%", "loi_nhuan": "Lỗ"},
    {"cong_ty": "MINIMAX", "ma_ck": "00100.HK", "ev_sales": "~69x", "gross_margin": "23.3%", "tang_truong": "+771%", "loi_nhuan": "Lỗ"},
])

# ═══════════════════════════════════════════════════════════════════════════════
# HIỂN THỊ
# ═══════════════════════════════════════════════════════════════════════════════

print("=" * 70)
print("💵 BƯỚC 8: SO SÁNH & ĐỊNH GIÁ")
print("=" * 70)

print(f"""
┌─────────────────────────────────────────────────────────────────────┐
│  💰 PHÂN TÍCH DÒNG TIỀN (Cash Runway)                               │
├─────────────────────────────────────────────────────────────────────┤
│  Tiền mặt trước IPO    : {f'${tien_mat_truoc_ipo/1e6:,.0f}M'}        │
│  Net IPO Proceeds  : {f'${von_ipo_usd/1e6:,.0f}M'}         │
│  Tổng tiền mặt         : {f'${tong_tien_mat/1e6:,.0f}M'}        │
│  Burn rate/quý (ước)   : {f'${burn_rate_quy/1e6:,.0f}M (adjusted, excl. SBC)'}         │
│  ─────────────────────────────────────────────────────────────────  │
│  Cash Runway           : {'TBD' if pd.isna(runway_quy) else f'{runway_quy:.1f} quý (~{runway_nam:.1f} năm)'}       │
└─────────────────────────────────────────────────────────────────────┘
""")

print("\n📊 So sánh với Peers:")
print("-" * 70)
display(so_sanh_peer.rename(columns={
    "cong_ty": "Công ty",
    "ma_ck": "Mã CK",
    "ev_sales": "EV/Sales",
    "gross_margin": "Gross Margin",
    "tang_truong": "Tăng trưởng",
    "loi_nhuan": "Lợi nhuận"
}))

print("\n🔍 ĐÁNH GIÁ ĐỊNH GIÁ:")
print("""
🟢 ĐÃ CHUẨN HÓA:
   • Đã xác thực:
   • EV/Sales ~69x (annualized) hoặc ~27x (forward 2026E)
   • Cash runway ~6+ năm (adjusted burn rate ~$62M/q)
   • Định giá premium nhưng có growth story mạnh (+771% YoY)

🟡 LƯU Ý:
   • GAAP loss ($170M/q) cao hơn adjusted ($62M/q) do SBC
   • Free float chỉ ~5.4% - thanh khoản thấp, giá dễ biến động
""")
# Out:
# ======================================================================
# 💵 BƯỚC 8: SO SÁNH & ĐỊNH GIÁ
# ======================================================================
#
# ┌─────────────────────────────────────────────────────────────────────┐
# │  💰 PHÂN TÍCH DÒNG TIỀN (Cash Runway)                               │
# ├─────────────────────────────────────────────────────────────────────┤
# │  Tiền mặt trước IPO    : $1,050M        │
# │  Net IPO Proceeds  : $515M         │
# │  Tổng tiền mặt         : $1,565M        │
# │  Burn rate/quý (ước)   : $62M (adjusted, excl. SBC)         │
# │  ─────────────────────────────────────────────────────────────────  │
# │  Cash Runway           : 25.2 quý (~6.3 năm)       │
# └─────────────────────────────────────────────────────────────────────┘
#
#
# 📊 So sánh với Peers:
# ----------------------------------------------------------------------
#                 Công ty     Mã CK EV/Sales Gross Margin Tăng trưởng Lợi nhuận
# 0  AI SaaS Global Bench         -   10-25x      ~60-80%         Cao     Mixed
# 1              Zhipu AI  02513.HK     ~50x         ~45%     +1,438%        Lỗ
# 2               MINIMAX  00100.HK     ~69x        23.3%       +771%        Lỗ
# 🔍 ĐÁNH GIÁ ĐỊNH GIÁ:
#
# 🟢 ĐÃ CHUẨN HÓA:
#    • Đã xác thực:
#    • EV/Sales ~69x (annualized) hoặc ~27x (forward 2026E)
#    • Cash runway ~6+ năm (adjusted burn rate ~$62M/q)
#    • Định giá premium nhưng có growth story mạnh (+771% YoY)
#
# 🟡 LƯU Ý:
#    • GAAP loss ($170M/q) cao hơn adjusted ($62M/q) do SBC
#    • Free float chỉ ~5.4% - thanh khoản thấp, giá dễ biến động

# %% [markdown]
# ---
#
# # ⚠️ BƯỚC 9: ĐÁNH GIÁ RỦI RO
#
# ## Các loại rủi ro cần đánh giá
#
# | Loại rủi ro | Mô tả | Ví dụ |
# |-------------|-------|-------|
# | **Quản trị** | Founder control, related-party | Conflict of interest |
# | **Tài chính** | Cash burn, runway | Hết tiền |
# | **Vận hành** | Sản phẩm, sản xuất | Single-product risk |
# | **Cạnh tranh** | Đối thủ, thị phần | Model wars, open-source pressure |
# | **Địa chính trị** | Compute/export policy | US-China AI compute controls |
# | **Pháp lý** | AI regulation | Data/privacy & model compliance |

# %%
# ═══════════════════════════════════════════════════════════════════════════════
# BƯỚC 9: ĐÁNH GIÁ RỦI RO - MINIMAX
# ═══════════════════════════════════════════════════════════════════════════════

rui_ro = pd.DataFrame([
    {"loai": "Tài chính", "rui_ro": "Vẫn đang lỗ, đốt tiền compute", "muc_do": "🔴 Cao", "ghi_chu": "Theo dõi runway và capex"},
    {"loai": "Tài chính", "rui_ro": "Lock-up expiry T7/2026", "muc_do": "🔴 Cao", "ghi_chu": "Có thể có áp lực bán mạnh"},
    {"loai": "Cạnh tranh", "rui_ro": "Model competition rất cao", "muc_do": "🔴 Cao", "ghi_chu": "Khó giữ moat bền vững"},
    {"loai": "Sản phẩm", "rui_ro": "Chất lượng model không ổn định", "muc_do": "🟡 Trung bình", "ghi_chu": "Ảnh hưởng retention"},
    {"loai": "Vận hành", "rui_ro": "Scale enterprise delivery", "muc_do": "🟡 Trung bình", "ghi_chu": "Cần theo dõi execution"},
    {"loai": "Địa chính trị", "rui_ro": "US-China AI compute controls", "muc_do": "🔴 Cao", "ghi_chu": "Tác động chi phí suy luận"},
    {"loai": "Pháp lý", "rui_ro": "AI regulation/data compliance", "muc_do": "🟡 Trung bình", "ghi_chu": "Cần cập nhật thường xuyên"},
])

# ═══════════════════════════════════════════════════════════════════════════════
# HIỂN THỊ
# ═══════════════════════════════════════════════════════════════════════════════

print("=" * 70)
print("⚠️ BƯỚC 9: ĐÁNH GIÁ RỦI RO")
print("=" * 70)

display(rui_ro.rename(columns={
    "loai": "Loại",
    "rui_ro": "Rủi ro",
    "muc_do": "Mức độ",
    "ghi_chu": "Ghi chú"
}))

print("\n📊 TÓM TẮT RỦI RO:")
print("""
┌─────────────────────────────────────────────────────────────────────┐
│  🔴 RỦI RO CAO:                                                     │
│     • Burn rate compute và biến động chi phí hạ tầng               │
│     • Cạnh tranh mô hình ở mức cao                                 │
├─────────────────────────────────────────────────────────────────────┤
│  🟡 RỦI RO TRUNG BÌNH:                                              │
│     • Chất lượng sản phẩm và retention khách hàng                  │
│     • Khả năng scale vận hành enterprise                           │
├─────────────────────────────────────────────────────────────────────┤
│  🟡 RỦI RO CHÍNH SÁCH/PHÁP LÝ:                                      │
│     • Thay đổi regulation AI và yêu cầu tuân thủ dữ liệu           │
└─────────────────────────────────────────────────────────────────────┘
""")
# Out:
# ======================================================================
# ⚠️ BƯỚC 9: ĐÁNH GIÁ RỦI RO
# ======================================================================
#             Loại                          Rủi ro        Mức độ                    Ghi chú
# 0      Tài chính   Vẫn đang lỗ, đốt tiền compute         🔴 Cao   Theo dõi runway và capex
# 1      Tài chính          Lock-up expiry T7/2026         🔴 Cao  Có thể có áp lực bán mạnh
# 2     Cạnh tranh       Model competition rất cao         🔴 Cao      Khó giữ moat bền vững
# 3       Sản phẩm  Chất lượng model không ổn định  🟡 Trung bình        Ảnh hưởng retention
# 4       Vận hành       Scale enterprise delivery  🟡 Trung bình     Cần theo dõi execution
# 5  Địa chính trị    US-China AI compute controls         🔴 Cao  Tác động chi phí suy luận
# 6        Pháp lý   AI regulation/data compliance  🟡 Trung bình  Cần cập nhật thường xuyên
# 📊 TÓM TẮT RỦI RO:
#
# ┌─────────────────────────────────────────────────────────────────────┐
# │  🔴 RỦI RO CAO:                                                     │
# │     • Burn rate compute và biến động chi phí hạ tầng               │
# │     • Cạnh tranh mô hình ở mức cao                                 │
# ├─────────────────────────────────────────────────────────────────────┤
# │  🟡 RỦI RO TRUNG BÌNH:                                              │
# │     • Chất lượng sản phẩm và retention khách hàng                  │
# │     • Khả năng scale vận hành enterprise                           │
# ├─────────────────────────────────────────────────────────────────────┤
# │  🟡 RỦI RO CHÍNH SÁCH/PHÁP LÝ:                                      │
# │     • Thay đổi regulation AI và yêu cầu tuân thủ dữ liệu           │
# └─────────────────────────────────────────────────────────────────────┘

# %% [markdown]
# ---
#
# # 📝 BƯỚC 10: KẾT LUẬN ĐẦU TƯ
#
# ## Framework ra quyết định
#
# ```
#                          ┌─────────────────┐
#                          │  QUYẾT ĐỊNH     │
#                          │  ĐẦU TƯ         │
#                          └────────┬────────┘
#                                   │
#            ┌──────────────────────┼──────────────────────┐
#            ▼                      ▼                      ▼
#      ┌─────────┐           ┌─────────────┐        ┌─────────────┐
#      │   MUA   │           │  THEO DÕI   │        │   TRÁNH     │
#      └────┬────┘           └──────┬──────┘        └──────┬──────┘
#           │                       │                      │
#    • Thesis mạnh             • Thesis OK            • Thesis yếu
#    • Định giá hấp dẫn        • Định giá fair        • Định giá cao
#    • Risk chấp nhận được     • Cần thêm data        • Red flags nhiều
#    • Catalysts rõ            • Chờ entry point      • Risk > Reward
# ```

# %%
# ═══════════════════════════════════════════════════════════════════════════════
# BƯỚC 10: KẾT LUẬN ĐẦU TƯ - MINIMAX
# ═══════════════════════════════════════════════════════════════════════════════

print("=" * 80)
print("📝 KẾT LUẬN ĐẦU TƯ")
print("=" * 80)

print("""
╔══════════════════════════════════════════════════════════════════════════════╗
║                        MINIMAX (00100.HK)                             ║
║                        LLM / Foundation Models | HKEX Main Board              ║
╠══════════════════════════════════════════════════════════════════════════════╣
║                                                                              ║
║   📋 THESIS (Luận điểm đầu tư):                                              ║
║   Công ty LLM nội địa có cơ hội lớn ở enterprise AI, nhưng cần kiểm chứng     ║
║   tăng trưởng doanh thu bền vững và hiệu quả chi phí inference.                ║
║                                                                              ║
╠══════════════════════════════════════════════════════════════════════════════╣
║                                                                              ║
║   ✅ ĐIỀU KIỆN CẦN ĐÚNG:                                                     ║
║   1. Tiếp tục tăng trưởng >50% YoY về doanh thu                              ║
║   2. Gross margin tiếp tục cải thiện (hiện 23.3%, hướng >30%)                                               ║
║   3. Duy trì chất lượng model và giảm chi phí/token theo thời gian            ║
║                                                                              ║
╠══════════════════════════════════════════════════════════════════════════════╣
║                                                                              ║
║   ⚠️ RỦI RO CHÍNH:                                                           ║
║   1. Lock-up expiry cornerstone 08/07/2026 - Áp lực bán                                  ║
║   2. Vẫn đang lỗ - Cần theo dõi path to profitability                        ║
║   3. Cạnh tranh cao từ mô hình closed/open-source                            ║
║                                                                              ║
╠══════════════════════════════════════════════════════════════════════════════╣
║                                                                              ║
║   💵 ĐÁNH GIÁ ĐỊNH GIÁ:                                                      ║
║   • EV/Sales ~69x (annualized) hoặc ~27x (forward 2026E)                ║
║   • Premium so với peers, nhưng growth +771% justify                                                     ║
║                                                                              ║
╠══════════════════════════════════════════════════════════════════════════════╣
║                                                                              ║
║                         🎯 QUYẾT ĐỊNH                                        ║
║   ═══════════════════════════════════════════════════════════════════════    ║
║                                                                              ║
║   KHUYẾN NGHỊ:    📊 THEO DÕI / MUA KHI GIÁ GIẢM                             ║
║                                                                              ║
║   Vùng mua:       Quanh lock-up expiry (T7/2026) nếu giảm 20-30%          ║
║   Mục tiêu:       Theo dõi FY2025 earnings (02/03/2026)                                                         ║
║   Cắt lỗ:         -30% từ giá mua (nếu thesis thay đổi)                                                         ║
║                                                                              ║
║   ═══════════════════════════════════════════════════════════════════════    ║
║                                                                              ║
║   LÝ DO:                                                                     ║
║   • Thesis mạnh (nội địa hóa, backing tốt)                                   ║
║   • Định giá fair nhưng chưa rẻ ở mức hiện tại                               ║
║   • Cơ hội mua tốt hơn quanh lock-up expiry (T7/2026)                        ║
║   • Báo cáo 1H2026 (T8-9) sẽ kiểm chứng thesis                               ║
║                                                                              ║
╚══════════════════════════════════════════════════════════════════════════════╝
""")

print("\n📅 LỊCH SỰ KIỆN QUAN TRỌNG:")
print("-" * 80)
lich_su_kien = pd.DataFrame([
    {"ngay": "08/07/2026", "su_kien": "Lock-up expiry cornerstone (6 tháng)", "tac_dong": "Theo dõi filing chính thức"},
    {"ngay": "02/03/2026", "su_kien": "FY2025 Annual Results", "tac_dong": "Cập nhật thesis"},
    {"ngay": "Q1/2026", "su_kien": "MiniMax M2.5 + Hailuo 2.3 (released)", "tac_dong": "Catalyst tiềm năng"},
    {"ngay": "09/01/2027", "su_kien": "Pre-IPO shareholder lock-up expiry (12 tháng)", "tac_dong": "Theo dõi tác động"},
])
display(lich_su_kien.rename(columns={"ngay": "Ngày", "su_kien": "Sự kiện", "tac_dong": "Tác động"}))

print("\n📋 VIỆC CẦN LÀM TIẾP THEO:")
print("""
   ☑ Dữ liệu prospectus đã xác thực
   ☑ Lock-up: cornerstone 08/07/2026, pre-IPO 09/01/2027, founder 09/01/2028
   □ Theo dõi FY2025 earnings (02/03/2026)
   □ Theo dõi giá quanh lock-up expiry T7/2026
""")
# Out:
# ================================================================================
# 📝 KẾT LUẬN ĐẦU TƯ
# ================================================================================
#
# ╔══════════════════════════════════════════════════════════════════════════════╗
# ║                        MINIMAX (00100.HK)                             ║
# ║                        LLM / Foundation Models | HKEX Main Board              ║
# ╠══════════════════════════════════════════════════════════════════════════════╣
# ║                                                                              ║
# ║   📋 THESIS (Luận điểm đầu tư):                                              ║
# ║   Công ty LLM nội địa có cơ hội lớn ở enterprise AI, nhưng cần kiểm chứng     ║
# ║   tăng trưởng doanh thu bền vững và hiệu quả chi phí inference.                ║
# ║                                                                              ║
# ╠══════════════════════════════════════════════════════════════════════════════╣
# ║                                                                              ║
# ║   ✅ ĐIỀU KIỆN CẦN ĐÚNG:                                                     ║
# ║   1. Tiếp tục tăng trưởng >50% YoY về doanh thu                              ║
# ║   2. Gross margin tiếp tục cải thiện (hiện 23.3%, hướng >30%)                                               ║
# ║   3. Duy trì chất lượng model và giảm chi phí/token theo thời gian            ║
# ║                                                                              ║
# ╠══════════════════════════════════════════════════════════════════════════════╣
# ║                                                                              ║
# ║   ⚠️ RỦI RO CHÍNH:                                                           ║
# ║   1. Lock-up expiry cornerstone 08/07/2026 - Áp lực bán                                  ║
# ║   2. Vẫn đang lỗ - Cần theo dõi path to profitability                        ║
# ║   3. Cạnh tranh cao từ mô hình closed/open-source                            ║
# ║                                                                              ║
# ╠══════════════════════════════════════════════════════════════════════════════╣
# ║                                                                              ║
# ║   💵 ĐÁNH GIÁ ĐỊNH GIÁ:                                                      ║
# ║   • EV/Sales ~69x (annualized) hoặc ~27x (forward 2026E)                ║
# ║   • Premium so với peers, nhưng growth +771% justify                                                     ║
# ║                                                                              ║
# ╠══════════════════════════════════════════════════════════════════════════════╣
# ║                                                                              ║
# ║                         🎯 QUYẾT ĐỊNH                                        ║
# ║   ═══════════════════════════════════════════════════════════════════════    ║
# ║                                                                              ║
# ║   KHUYẾN NGHỊ:    📊 THEO DÕI / MUA KHI GIÁ GIẢM                             ║
# ║                                                                              ║
# ║   Vùng mua:       Quanh lock-up expiry (T7/2026) nếu giảm 20-30%          ║
# ║   Mục tiêu:       Theo dõi FY2025 earnings (02/03/2026)                                                         ║
# ║   Cắt lỗ:         -30% từ giá mua (nếu thesis thay đổi)                                                         ║
# ║                                                                              ║
# ║   ═══════════════════════════════════════════════════════════════════════    ║
# ║                                                                              ║
# ║   LÝ DO:                                                                     ║
# ║   • Thesis mạnh (nội địa hóa, backing tốt)                                   ║
# ║   • Định giá fair nhưng chưa rẻ ở mức hiện tại                               ║
# ║   • Cơ hội mua tốt hơn quanh lock-up expiry (T7/2026)                        ║
# ║   • Báo cáo 1H2026 (T8-9) sẽ kiểm chứng thesis                               ║
# ║                                                                              ║
# ╚══════════════════════════════════════════════════════════════════════════════╝
#
#
# 📅 LỊCH SỰ KIỆN QUAN TRỌNG:
# --------------------------------------------------------------------------------
#          Ngày                                        Sự kiện                    Tác động
# 0  08/07/2026           Lock-up expiry cornerstone (6 tháng)  Theo dõi filing chính thức
# 1  02/03/2026                          FY2025 Annual Results             Cập nhật thesis
# 2     Q1/2026           MiniMax M2.5 + Hailuo 2.3 (released)          Catalyst tiềm năng
# 3  09/01/2027  Pre-IPO shareholder lock-up expiry (12 tháng)           Theo dõi tác động
# 📋 VIỆC CẦN LÀM TIẾP THEO:
#
#    ☑ Dữ liệu prospectus đã xác thực
#    ☑ Lock-up: cornerstone 08/07/2026, pre-IPO 09/01/2027, founder 09/01/2028
#    □ Theo dõi FY2025 earnings (02/03/2026)
#    □ Theo dõi giá quanh lock-up expiry T7/2026

# %% [markdown]
# ---
#
# # 📊 PHỤ LỤC: THEO DÕI SAU IPO
#
# ## Kế hoạch theo dõi
#
# | Tần suất | Chỉ số cần theo dõi |
# |----------|--------------------|
# | **Hàng tuần** | Giá vs giá IPO, khối lượng giao dịch |
# | **Hàng tháng** | Tin tức, announcements HKEX |
# | **Hàng quý** | Báo cáo tài chính, KPIs vận hành |

# %%
# ═══════════════════════════════════════════════════════════════════════════════
# PHỤ LỤC: MẪU THEO DÕI SAU IPO
# ═══════════════════════════════════════════════════════════════════════════════

muc_gia_quan_trong = {
    "gia_ipo": 165.00,
    "ngay_1_low": 165.00,
    "all_time_high": 345.00,
    "all_time_high_ngay": "09/01/2026",
    "ho_tro_1": 250.00,
    "ho_tro_2": 165.00,
    "khang_cu_1": 345.00,
}

print("=" * 70)
print("📊 PHỤ LỤC: THEO DÕI SAU IPO")
print("=" * 70)

print(f"""
┌─────────────────────────────────────────────────────────────────────┐
│  📈 MỨC GIÁ QUAN TRỌNG (HKD)                                        │
├─────────────────────────────────────────────────────────────────────┤
│  Giá IPO           : {muc_gia_quan_trong['gia_ipo']:.2f}                                     │
│  Giá thấp nhất     : {muc_gia_quan_trong['ngay_1_low']:.2f} (Ngày 1)                              │
│  Giá cao nhất      : {muc_gia_quan_trong['all_time_high']:.2f} ({muc_gia_quan_trong['all_time_high_ngay']})                       │
│  ─────────────────────────────────────────────────────────────────  │
│  Hỗ trợ 1          : {muc_gia_quan_trong['ho_tro_1']:.2f}                                     │
│  Hỗ trợ 2          : {muc_gia_quan_trong['ho_tro_2']:.2f} (Giá IPO - quan trọng)              │
│  Kháng cự 1        : {muc_gia_quan_trong['khang_cu_1']:.2f} (ATH)                                │
└─────────────────────────────────────────────────────────────────────┘
""")

# Mẫu theo dõi hàng tuần
print("\n📋 Mẫu theo dõi hàng tuần (điền khi update):")
print("-" * 70)
theo_doi = pd.DataFrame(columns=[
    "Tuần",
    "Giá đóng cửa",
    "% vs IPO",
    "Khối lượng TB",
    "Tin tức",
    "Ghi chú"
])
display(theo_doi)
# Out:
# ======================================================================
# 📊 PHỤ LỤC: THEO DÕI SAU IPO
# ======================================================================
#
# ┌─────────────────────────────────────────────────────────────────────┐
# │  📈 MỨC GIÁ QUAN TRỌNG (HKD)                                        │
# ├─────────────────────────────────────────────────────────────────────┤
# │  Giá IPO           : 165.00                                     │
# │  Giá thấp nhất     : 165.00 (Ngày 1)                              │
# │  Giá cao nhất      : 345.00 (09/01/2026)                       │
# │  ─────────────────────────────────────────────────────────────────  │
# │  Hỗ trợ 1          : 250.00                                     │
# │  Hỗ trợ 2          : 165.00 (Giá IPO - quan trọng)              │
# │  Kháng cự 1        : 345.00 (ATH)                                │
# └─────────────────────────────────────────────────────────────────────┘
#
#
# 📋 Mẫu theo dõi hàng tuần (điền khi update):
# ----------------------------------------------------------------------
# Empty DataFrame
# Columns: [Tuần, Giá đóng cửa, % vs IPO, Khối lượng TB, Tin tức, Ghi chú]
# Index: []

# %% [markdown]
# ---
#
# ## 📈 Dữ liệu giá & khối lượng giao dịch (Live từ Yahoo Finance)
#
# ### Mục đích
# - Tự động lấy dữ liệu giá cổ phiếu từ Yahoo Finance
# - Hiển thị biểu đồ giá và khối lượng giao dịch
# - Theo dõi performance so với giá IPO
#
# ### Cách sử dụng
# 1. Chạy cell bên dưới để cài đặt thư viện `yfinance`
# 2. Dữ liệu sẽ tự động cập nhật mỗi lần chạy
# 3. Có thể thay đổi `MA_CK` để theo dõi cổ phiếu khác
#
# > ⚠️ **Lưu ý**: Cần kết nối internet để lấy dữ liệu

# %%
# ==========================================================================
# LẤY DỮ LIỆU GIÁ TỪ AKSHARE (Nguồn: East Money / Tencent Finance)
# ==========================================================================
#
# akshare: Thư viện dữ liệu tài chính Trung Quốc, hỗ trợ cổ phiếu HK
# Docs: https://akshare.akfamily.xyz/
#
# ==========================================================================

# !pip install akshare -q

import akshare as ak
import pandas as pd
from datetime import datetime

# ==========================================================================
# CẤU HÌNH
# ==========================================================================

MA_CK = "00100"             # Mã HKEX (không có .HK)
MA_CK_DISPLAY = "00100.HK"  # Hiển thị
GIA_IPO = 165.0             # Giá IPO (HKD)
NGAY_IPO = "20260109"       # Ngày niêm yết (YYYYMMDD)

# ==========================================================================
# LẤY DỮ LIỆU
# ==========================================================================

print("=" * 70)
print(f"LẤY DỮ LIỆU GIÁ: {MA_CK_DISPLAY}")
print("=" * 70)

du_lieu = None

try:
    # Lấy dữ liệu daily từ ngày IPO
    raw = ak.stock_hk_hist(
        symbol=MA_CK,
        period="daily",
        start_date=NGAY_IPO,
        adjust="qfq"  # Giá đã điều chỉnh
    )

    print(f"\nRaw data: {len(raw)} rows")

    if not raw.empty:
        # Chuẩn hóa tên cột
        du_lieu = pd.DataFrame({
            'Open':   raw['开盘'].astype(float),
            'High':   raw['最高'].astype(float),
            'Low':    raw['最低'].astype(float),
            'Close':  raw['收盘'].astype(float),
            'Volume': raw['成交量'].astype(float),
        })
        du_lieu.index = pd.to_datetime(raw['日期'])
        du_lieu.index.name = 'Date'

        # Bỏ dòng volume = 0
        du_lieu = du_lieu[du_lieu['Volume'] > 0]

        print(f"\n✅ MINIMAX ({MA_CK_DISPLAY})")
        print(f"   Số ngày giao dịch: {len(du_lieu)}")
        print(f"   Từ: {du_lieu.index[0].strftime('%Y-%m-%d')} đến {du_lieu.index[-1].strftime('%Y-%m-%d')}")
        print(f"   Giá: {du_lieu['Close'].iloc[0]:.2f} -> {du_lieu['Close'].iloc[-1]:.2f} HKD")
        print(f"   vs IPO ({GIA_IPO}): {(du_lieu['Close'].iloc[-1]/GIA_IPO-1)*100:+.1f}%")
    else:
        print("\n⚠️ Không có dữ liệu")
        du_lieu = None

except Exception as e:
    print(f"❌ Lỗi: {e}")
    print("   Thử: pip install akshare --upgrade")
    du_lieu = None
# Out:
# ======================================================================
# LẤY DỮ LIỆU GIÁ: 00100.HK
# ======================================================================
# ❌ Lỗi: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#    Thử: pip install akshare --upgrade

# %%
# ═══════════════════════════════════════════════════════════════════════════════
# 📊 HIỂN THỊ THỐNG KÊ GIÁ
# ═══════════════════════════════════════════════════════════════════════════════

if du_lieu is not None and not du_lieu.empty:
    # Tính toán các chỉ số
    gia_hien_tai = du_lieu['Close'].iloc[-1]
    gia_cao_nhat = du_lieu['High'].max()
    gia_thap_nhat = du_lieu['Low'].min()
    gia_trung_binh = du_lieu['Close'].mean()
    kl_trung_binh = du_lieu['Volume'].mean()
    kl_hom_nay = du_lieu['Volume'].iloc[-1]
    
    # % thay đổi so với IPO
    pct_vs_ipo = (gia_hien_tai - GIA_IPO) / GIA_IPO * 100
    pct_vs_high = (gia_hien_tai - gia_cao_nhat) / gia_cao_nhat * 100
    
    # Xác định emoji và dấu
    emoji_ipo = '🟢' if pct_vs_ipo >= 0 else '🔴'
    dau_ipo = '+' if pct_vs_ipo >= 0 else ''
    
    print("=" * 70)
    print(f"📊 THỐNG KÊ GIÁ: {MA_CK_DISPLAY}")
    print("=" * 70)
    print(f"""
┌─────────────────────────────────────────────────────────────────────┐
│  💰 GIÁ HIỆN TẠI                                                    │
├─────────────────────────────────────────────────────────────────────┤
│  Giá đóng cửa gần nhất : HKD {gia_hien_tai:,.2f}                          │
│  So với giá IPO        : {dau_ipo}{pct_vs_ipo:,.1f}% {emoji_ipo}                              │
│  So với đỉnh           : {pct_vs_high:,.1f}%                                │
├─────────────────────────────────────────────────────────────────────┤
│  📈 RANGE TỪ IPO                                                    │
├─────────────────────────────────────────────────────────────────────┤
│  Giá IPO               : HKD {GIA_IPO:,.2f}                               │
│  Giá cao nhất          : HKD {gia_cao_nhat:,.2f}                              │
│  Giá thấp nhất         : HKD {gia_thap_nhat:,.2f}                              │
│  Giá trung bình        : HKD {gia_trung_binh:,.2f}                              │
├─────────────────────────────────────────────────────────────────────┤
│  📊 KHỐI LƯỢNG                                                      │
├─────────────────────────────────────────────────────────────────────┤
│  KL giao dịch TB/ngày  : {kl_trung_binh:,.0f} cổ phiếu                  │
│  KL hôm gần nhất       : {kl_hom_nay:,.0f} cổ phiếu                  │
└─────────────────────────────────────────────────────────────────────┘
    """)
    
    # Bảng 10 ngày gần nhất
    print("\n📋 10 ngày giao dịch gần nhất:")
    print("-" * 70)
    
    bang_10_ngay = du_lieu.tail(10)[['Open', 'High', 'Low', 'Close', 'Volume']].copy()
    bang_10_ngay.index = bang_10_ngay.index.strftime('%Y-%m-%d')
    bang_10_ngay.columns = ['Mở cửa', 'Cao nhất', 'Thấp nhất', 'Đóng cửa', 'Khối lượng']
    bang_10_ngay['% vs IPO'] = ((bang_10_ngay['Đóng cửa'] - GIA_IPO) / GIA_IPO * 100).round(1)
    
    display(bang_10_ngay.style.format({
        'Mở cửa': '{:.2f}',
        'Cao nhất': '{:.2f}',
        'Thấp nhất': '{:.2f}',
        'Đóng cửa': '{:.2f}',
        'Khối lượng': '{:,.0f}',
        '% vs IPO': '{:+.1f}%'
    }))

# %%
# ═══════════════════════════════════════════════════════════════════════════════
# 📈 BIỂU ĐỒ GIÁ VÀ KHỐI LƯỢNG
# ═══════════════════════════════════════════════════════════════════════════════

import matplotlib.dates as mdates

if du_lieu is not None and not du_lieu.empty and len(du_lieu) >= 1:

    # Tạo figure với 2 subplot (giá trên, volume dưới)
    fig, axes = plt.subplots(2, 1, figsize=(14, 8), gridspec_kw={'height_ratios': [3, 1]})
    fig.suptitle(f'📈 {MA_CK_DISPLAY} - Giá và Khối lượng giao dịch từ IPO', fontsize=14, fontweight='bold')

    # ─────────────────────────────────────────────────────────────────────────────
    # BIỂU ĐỒ GIÁ (trên)
    # ─────────────────────────────────────────────────────────────────────────────
    ax1 = axes[0]

    # Vẽ giá đóng cửa
    ax1.plot(du_lieu.index, du_lieu['Close'], color='#2E86AB', linewidth=2, label='Giá đóng cửa')

    # Vẽ range High-Low (shaded area)
    ax1.fill_between(du_lieu.index, du_lieu['Low'], du_lieu['High'],
                     alpha=0.2, color='#2E86AB', label='Range (Cao-Thấp)')

    # Đường giá IPO
    ax1.axhline(y=GIA_IPO, color='#E94F37', linestyle='--', linewidth=2, label=f'Giá IPO: {GIA_IPO}')

    # Đường giá trung bình
    gia_tb = du_lieu['Close'].mean()
    ax1.axhline(y=gia_tb, color='#F39C12', linestyle=':', linewidth=1.5, label=f'TB: {gia_tb:.2f}')

    ax1.set_ylabel('Giá (HKD)', fontsize=11)
    ax1.legend(loc='upper left', fontsize=9)
    ax1.grid(True, alpha=0.3)

    # Highlight vùng lãi/lỗ so với IPO
    ax1.fill_between(du_lieu.index, GIA_IPO, du_lieu['Close'],
                     where=(du_lieu['Close'] >= GIA_IPO),
                     color='#27AE60', alpha=0.1)
    ax1.fill_between(du_lieu.index, GIA_IPO, du_lieu['Close'],
                     where=(du_lieu['Close'] < GIA_IPO),
                     color='#E74C3C', alpha=0.1)

    # Format trục X - ngày tháng rõ ràng
    ax1.xaxis.set_major_formatter(mdates.DateFormatter('%m/%d'))
    ax1.xaxis.set_major_locator(mdates.WeekdayLocator(interval=1))
    plt.setp(ax1.xaxis.get_majorticklabels(), rotation=45, ha='right')

    # ─────────────────────────────────────────────────────────────────────────────
    # BIỂU ĐỒ KHỐI LƯỢNG (dưới)
    # ─────────────────────────────────────────────────────────────────────────────
    ax2 = axes[1]

    # Màu thanh volume dựa trên giá tăng/giảm
    colors = ['#27AE60' if du_lieu['Close'].iloc[i] >= du_lieu['Open'].iloc[i] else '#E74C3C'
              for i in range(len(du_lieu))]

    ax2.bar(du_lieu.index, du_lieu['Volume'], color=colors, alpha=0.7, width=0.8)

    # Đường trung bình volume (chỉ khi >= 5 ngày)
    if len(du_lieu) >= 5:
        vol_ma = du_lieu['Volume'].rolling(window=5).mean()
        ax2.plot(du_lieu.index, vol_ma, color='#F39C12', linewidth=1.5, label='MA5 Volume')

    ax2.set_ylabel('Khối lượng', fontsize=11)
    ax2.set_xlabel('Ngày', fontsize=11)
    ax2.legend(loc='upper left', fontsize=9)
    ax2.grid(True, alpha=0.3)

    # Format trục X - ngày tháng rõ ràng
    ax2.xaxis.set_major_formatter(mdates.DateFormatter('%m/%d'))
    ax2.xaxis.set_major_locator(mdates.WeekdayLocator(interval=1))
    plt.setp(ax2.xaxis.get_majorticklabels(), rotation=45, ha='right')

    # Format trục Y của volume
    ax2.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, p: f'{x/1e6:.1f}M' if x >= 1e6 else f'{x/1e3:.0f}K'))

    plt.tight_layout()
    plt.show()

    # ─────────────────────────────────────────────────────────────────────────────
    # NHẬN XÉT TỰ ĐỘNG
    # ─────────────────────────────────────────────────────────────────────────────
    print("\n" + "=" * 70)
    print("🔍 NHẬN XÉT TỰ ĐỘNG")
    print("=" * 70)

    # Tính các chỉ số
    gia_hien_tai = du_lieu['Close'].iloc[-1]
    pct_vs_ipo = (gia_hien_tai / GIA_IPO - 1) * 100
    thay_doi_5_ngay = (du_lieu['Close'].iloc[-1] / du_lieu['Close'].iloc[max(-5, -len(du_lieu))] - 1) * 100 if len(du_lieu) >= 2 else 0
    vol_hom_nay = du_lieu['Volume'].iloc[-1]
    vol_tb = du_lieu['Volume'].mean()
    gia_thap_nhat = du_lieu['Low'].min()
    gia_cao_nhat = du_lieu['High'].max()
    vi_tri_range = (gia_hien_tai - gia_thap_nhat) / (gia_cao_nhat - gia_thap_nhat) * 100 if gia_cao_nhat != gia_thap_nhat else 50

    dau_ipo = '+' if pct_vs_ipo >= 0 else ''
    dau_5d = '+' if thay_doi_5_ngay >= 0 else ''
    vol_status = '(Cao hơn TB)' if vol_hom_nay > vol_tb else '(Thấp hơn TB)'

    print(f"""
📈 XU HƯỚNG:
   • Giá hiện tại: HKD {gia_hien_tai:.2f} ({dau_ipo}{pct_vs_ipo:.1f}% vs IPO)
   • Thay đổi 5 ngày: {dau_5d}{thay_doi_5_ngay:.1f}%
   • Vị trí trong range: {vi_tri_range:.0f}% từ đáy

📊 KHỐI LƯỢNG:
   • KL hôm nay: {vol_hom_nay:,.0f}
   • So với TB: {vol_hom_nay/vol_tb*100:.0f}% {vol_status}

🎯 MỨC GIÁ QUAN TRỌNG:
   • Hỗ trợ 1: HKD {gia_thap_nhat:.2f} (đáy)
   • Hỗ trợ 2: HKD {GIA_IPO:.2f} (giá IPO)
   • Kháng cự: HKD {gia_cao_nhat:.2f} (đỉnh)
""")

else:
    print("⚠️ Không có dữ liệu để vẽ biểu đồ. Chạy lại cell trước để lấy dữ liệu.")
# Out:
# ⚠️ Không có dữ liệu để vẽ biểu đồ. Chạy lại cell trước để lấy dữ liệu.

# %% [markdown]
# ---
#
# # 📚 HƯỚNG DẪN SỬ DỤNG TEMPLATE CHO IPO KHÁC
#
# ## Quy trình 5 bước
#
# ```
# ┌─────────────────────────────────────────────────────────────────────────────┐
# │  BƯỚC 1: CHUẨN BỊ                                                           │
# │  • Download prospectus từ HKEX/SGX/SSE                                      │
# │  • Duplicate notebook này, đổi tên theo công ty mới                         │
# │  • Update cell "cong_ty" với thông tin mới                                  │
# ├─────────────────────────────────────────────────────────────────────────────┤
# │  BƯỚC 2: TRÍCH XUẤT DỮ LIỆU                                                 │
# │  • Tìm "Financial Information" trong prospectus                             │
# │  • Copy doanh thu, lợi nhuận vào cell "tai_chinh"                           │
# │  • Tìm "Cornerstone Investors", update cell tương ứng                       │
# ├─────────────────────────────────────────────────────────────────────────────┤
# │  BƯỚC 3: NGHIÊN CỨU BỔ SUNG                                                 │
# │  • Search Crunchbase/PitchBook cho funding history                          │
# │  • Search tin tức cho analyst reports                                       │
# │  • Check Yahoo Finance cho giá hiện tại                                     │
# ├─────────────────────────────────────────────────────────────────────────────┤
# │  BƯỚC 4: CHẠY PHÂN TÍCH                                                     │
# │  • Run All cells                                                            │
# │  • Review output từng section                                               │
# │  • Điền đánh giá (🟢/🟡/🔴)                                                  │
# ├─────────────────────────────────────────────────────────────────────────────┤
# │  BƯỚC 5: RA QUYẾT ĐỊNH                                                      │
# │  • Hoàn thành phần Kết luận với thesis, risks                               │
# │  • Quyết định: MUA / THEO DÕI / TRÁNH                                       │
# │  • Đặt alerts và calendar reminders                                         │
# └─────────────────────────────────────────────────────────────────────────────┘
# ```
#
# ---
#
# ## 🔗 Nguồn dữ liệu (có link)
#
# ### Prospectus & Filings chính thức
#
# | Sàn | Link | Mô tả |
# |-----|------|-------|
# | **HKEX** | [HKEXnews Title Search](https://www1.hkexnews.hk/search/titlesearch.xhtml) | Tìm prospectus, announcements, circulars |
# | **HKEX** | [New Listings](https://www.hkex.com.hk/Market-Data/Securities-Prices/Equities?sc_lang=en) | Danh sách công ty mới niêm yết |
# | **SGX** | [SGX Rulebook](https://rulebook.sgx.com/rulebook/mainboard-rules) | Quy định niêm yết Singapore |
# | **SSE** | [STAR Market Rules](https://english.sse.com.cn/start/sserules/stocks/listing/) | Quy định sàn STAR Shanghai |
#
# ### Dữ liệu tài chính & giá
#
# | Nguồn | Link | Loại |
# |-------|------|------|
# | **Yahoo Finance** | [finance.yahoo.com](https://finance.yahoo.com) | Miễn phí - Giá, charts, financials |
# | **Google Finance** | [google.com/finance](https://www.google.com/finance) | Miễn phí - Giá, tin tức |
# | **TradingView** | [tradingview.com](https://www.tradingview.com) | Miễn phí/Trả phí - Charts, technical |
# | **Investing.com** | [investing.com](https://www.investing.com) | Miễn phí - Data đa dạng |
# | **Bloomberg** | [bloomberg.com](https://www.bloomberg.com) | Tin tức, data premium |
#
# ### Funding History & Startup Data
#
# | Nguồn | Link | Loại |
# |-------|------|------|
# | **Crunchbase** | [crunchbase.com](https://www.crunchbase.com) | Miễn phí (giới hạn) - Funding rounds |
# | **PitchBook** | [pitchbook.com](https://pitchbook.com) | Trả phí - Chi tiết đầy đủ |
# | **CB Insights** | [cbinsights.com](https://www.cbinsights.com) | Trả phí - Phân tích startup |
# | **IT桔子** | [itjuzi.com](https://www.itjuzi.com) | China startup database |
#
# ### Tin tức & Nghiên cứu
#
# | Nguồn | Link | Focus |
# |-------|------|-------|
# | **Reuters** | [reuters.com](https://www.reuters.com) | Tin tức tài chính global |
# | **SCMP** | [scmp.com](https://www.scmp.com) | Tin tức Hong Kong, China |
# | **36Kr** | [36kr.com](https://36kr.com) | Startup & Tech China |
# | **EqualOcean** | [equalocean.com](https://equalocean.com) | China tech analysis |
# | **Caixin** | [caixinglobal.com](https://www.caixinglobal.com) | China business news |
#
# ---
#
# ## 📖 Tài liệu tham khảo & Học thêm
#
# ### IPO Analysis Framework
#
# | Tài liệu | Link | Tác giả/Nguồn |
# |----------|------|---------------|
# | **IPO Lessons for Investors** | [Damodaran Blog](https://aswathdamodaran.blogspot.com/2019/10/ipo-lessons-for-public-market-investors.html) | Aswath Damodaran (NYU) |
# | **EY Global IPO Trends** | [EY IPO Report](https://www.ey.com/en_us/insights/ipo/trends) | Ernst & Young |
# | **HKEX Listing Rules** | [HKEX Rules](https://en-rules.hkex.com.hk/rulebook/main-board-listing-rules) | HKEX Official |
# | **How to Read a Prospectus** | [SEC Guide](https://www.sec.gov/oiea/investor-alerts-bulletins/ib_prospectus.html) | US SEC |
#
# ### Valuation & Financial Analysis
#
# | Tài liệu | Link | Mô tả |
# |----------|------|-------|
# | **Damodaran Online** | [Damodaran Data](http://pages.stern.nyu.edu/~adamodar/) | Datasets, spreadsheets, lectures miễn phí |
# | **Multiples.app** | [multiples.app](https://www.multiples.app) | SaaS & Tech valuation multiples |
# | **FinBox** | [finbox.com](https://finbox.com) | DCF templates, fair value |
# | **Simply Wall St** | [simplywall.st](https://simplywall.st) | Visual stock analysis |
#
# ### LLM / Foundation Models Industry (MINIMAX)
#
# | Tài liệu | Link | Mô tả |
# |----------|------|-------|
# | **Stanford AI Index** | [aiindex.stanford.edu](https://aiindex.stanford.edu) | Tổng quan xu hướng AI toàn cầu |
# | **Artificial Analysis** | [artificialanalysis.ai](https://artificialanalysis.ai) | So sánh benchmark mô hình |
# | **LMSYS Chatbot Arena** | [lmarena.ai](https://lmarena.ai) | Theo dõi chất lượng model cộng đồng |
#
# ### AI & Chips Industry (Biren, Zhipu, Axera)
#
# | Tài liệu | Link | Mô tả |
# |----------|------|-------|
# | **SemiAnalysis** | [semianalysis.com](https://www.semianalysis.com) | Chip industry deep-dives |
# | **The Information** | [theinformation.com](https://www.theinformation.com) | Tech scoops (trả phí) |
# | **Import AI Newsletter** | [importai.net](https://importai.net) | AI research weekly |
# | **ChinAI Newsletter** | [chinai.substack.com](https://chinai.substack.com) | China AI translations |
#
# ---
#
# ## 🔖 Quick Links to Follow
#
# ### Twitter/X Accounts
#
# | Account | Handle | Focus |
# |---------|--------|-------|
# | IPO News | [@IPOborhood](https://twitter.com/IPOborhood) | IPO announcements |
# | Tech Scoops | [@EricNewcomer](https://twitter.com/EricNewcomer) | VC & Tech IPOs |
# | China Tech | [@ChinaTechBlog](https://twitter.com/ChinaTechBlog) | China tech news |
# | Semiconductors | [@SemiAnalysis_](https://twitter.com/SemiAnalysis_) | Chip industry |
#
# ### Newsletters đáng theo dõi
#
# | Newsletter | Link | Tần suất |
# |------------|------|----------|
# | **The Generalist** | [readthegeneralist.com](https://www.readthegeneralist.com) | Weekly deep-dives |
# | **Emerging Tech Brew** | [morningbrew.com/emerging-tech](https://www.morningbrew.com/emerging-tech) | Daily |
# | **Not Boring** | [notboring.co](https://www.notboring.co) | Weekly strategy |
# | **Interconnected** | [interconnected.blog](https://interconnected.blog) | China-US tech |
#
# ### Podcasts
#
# | Podcast | Link | Focus |
# |---------|------|-------|
# | **Acquired** | [acquired.fm](https://www.acquired.fm) | Company deep-dives |
# | **Invest Like the Best** | [joincolossus.com](https://www.joincolossus.com/episodes) | Investor interviews |
# | **China Talk** | [chinatalk.substack.com](https://chinatalk.substack.com) | China tech policy |
#
# ---
#
# ## ⚠️ Tuyên bố miễn trừ trách nhiệm
#
# > **QUAN TRỌNG**: Báo cáo này chỉ mang tính chất **nghiên cứu và giáo dục**.
# > Đây **KHÔNG PHẢI** lời khuyên đầu tư. Mọi quyết định đầu tư cần dựa trên
# > nghiên cứu của riêng bạn và tư vấn từ chuyên gia tài chính được cấp phép.
# >
# > Tác giả không chịu trách nhiệm cho bất kỳ tổn thất nào từ việc sử dụng
# > thông tin trong báo cáo này.
#
# ---
#
# **KẾT THÚC BÁO CÁO**
#
# *Template version: 4.0 | Cập nhật: 20/02/2026*
