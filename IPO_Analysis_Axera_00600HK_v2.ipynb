# %% [markdown]
# # 📊 BÁO CÁO PHÂN TÍCH IPO
# ## Mẫu chuẩn cho cổ phiếu AI & Robotics (HK / SG / Shanghai)
# ### Case Study: **AXERA (00600.HK)**
#
# ---
#
# | Thông tin | Chi tiết |
# |-----------|----------|
# | **Loại báo cáo** | Phân tích IPO cơ bản |
# | **Công ty** | Axera Semiconductor Co., Ltd. |
# | **Mã CK** | 00600.HK (HKEX) |
# | **Ngành** | Edge AI Chips / Vision AI Processors |
# | **Ngày IPO** | 10/02/2026 |
# | **Ngày báo cáo** | 20/02/2026 |
# | **Phiên bản** | 2.0 |
#
# ---
#
# ### 📚 Tài liệu gốc
#
# | Nguồn | Link | Mục đích |
# |-------|------|----------|
# | **Bản cáo bạch (Prospectus)** | [HKEX](https://www1.hkexnews.hk/listedco/listconews/sehk/2026/0127/2026012700039.pdf) | Tài liệu pháp lý chính thức |
# | **Kết quả phân bổ** | [HKEX](https://www1.hkexnews.hk/listedco/listconews/sehk/2026/0204/2026020402144.pdf) | Over-subscription, allocation |
# | **Thông báo giao dịch** | [HKEX](https://www.hkex.com.hk/eng/market/sec_tradinfo/tradarng/tradarng_news/premonth/e0600a_260205.htm) | Ngày giao dịch, lot size |
#
# > ⚠️ **Lưu ý**: Luôn verify thông tin từ prospectus gốc, không chỉ dựa vào tin tức.

# %% [markdown]
# ---
#
# # 📋 PHẦN 0: TÓM TẮT ĐIỀU HÀNH (Executive Summary)
#
# **Dành cho người bận rộn** - Đọc phần này trước để nắm bắt nhanh, sau đó đọc chi tiết nếu quan tâm.
#
# ---
#
# ## 🎯 Tổng quan nhanh
#
# | Hạng mục | Đánh giá | Chi tiết |
# |----------|----------|----------|
# | **Công ty** | Axera (00600.HK) | Edge AI Chips / Vision AI Processors, Trung Quốc |
# | **Thesis** | 🟢 Tích cực | Dẫn đầu thị trường mid-to-high-end visual edge AI chips |
# | **Tài chính** | 🟢 Tăng trưởng mạnh | CAGR 206.8% (2022-2024), Gross margin ~30% |
# | **Định giá** | 🟡 Hợp lý | EV/Sales ~6x tại IPO, discount vs peers |
# | **Rủi ro** | 🟡 Trung bình | Vẫn lỗ, R&D >200% revenue, US export controls |
# | **Quyết định** | 📊 THEO DÕI | Tích lũy vùng HKD 24-26 |
#
# ---
#
# ## 💡 3 điểm chính cần nhớ
#
# 1. **Thesis**: Axera là công ty Edge AI chips hàng đầu Trung Quốc, hưởng lợi từ xu hướng "nội địa hóa" chip và bùng nổ ứng dụng AI
#
# 2. **Tín hiệu tốt**: Cornerstone investors mạnh (16 cornerstone investors ($185M total), incl. OmniVision ($35M), Youngor ($35M)), CAGR 206.8%, dual-track IPC + Automotive
#
# 3. **Rủi ro chính**: Vẫn đang lỗ lớn (~RMB 1B/năm), R&D spending >200% revenue, lock-up expiry Aug 2026 & Feb 2027
#
# ---
#
# ## 📅 Các mốc thời gian quan trọng
#
# | Ngày | Sự kiện | Tác động |
# |------|---------|----------|
# | Aug 2026 | Lock-up 6 tháng hết hạn (cornerstone) | ⚠️ Áp lực bán, có thể mua được giá tốt |
# | T8-9/2026 | Báo cáo tài chính 1H2026 | Kiểm chứng thesis tăng trưởng |
# | Feb 2027 | Lock-up 12 tháng hết hạn (founders/VCs) | ⚠️ Đợt unlock thứ hai |

# %% [markdown]
# ---
#
# # 📖 PHẦN 1: PHƯƠNG PHÁP PHÂN TÍCH
#
# ## Tại sao cần phân tích IPO có hệ thống?
#
# | Vấn đề thường gặp | Giải pháp |
# |-------------------|----------|
# | Thông tin quá nhiều, không biết bắt đầu từ đâu | Framework 10 bước có cấu trúc |
# | Không biết giá IPO có hợp lý không | So sánh với công ty cùng ngành (peers) |
# | Không biết rủi ro ở đâu | Checklist rủi ro theo từng khía cạnh |
# | Mua vào lúc nào? | Trading signals & lịch sự kiện |
#
# ---
#
# ## 🔄 Framework 10 bước
#
# ```
# ┌─────────────────────────────────────────────────────────────────┐
# │  BƯỚC 1: THÔNG TIN CÔNG TY                                      │
# │  → Công ty làm gì? Thành lập năm nào? Niêm yết ở đâu?          │
# ├─────────────────────────────────────────────────────────────────┤
# │  BƯỚC 2: LỊCH SỬ GỌI VỐN                                        │
# │  → Series A, B, C... Ai đã đầu tư? Định giá tăng ra sao?       │
# ├─────────────────────────────────────────────────────────────────┤
# │  BƯỚC 3: PHÂN TÍCH TÀI CHÍNH                                    │
# │  → Doanh thu, lợi nhuận, biên lợi nhuận, tăng trưởng           │
# ├─────────────────────────────────────────────────────────────────┤
# │  BƯỚC 4: ĐIỀU KHOẢN IPO                                         │
# │  → Giá IPO, số tiền huy động, sử dụng vốn vào việc gì?         │
# ├─────────────────────────────────────────────────────────────────┤
# │  BƯỚC 5: CORNERSTONE & LOCK-UP                                  │
# │  → Ai mua trước IPO? Khi nào họ được bán?                      │
# ├─────────────────────────────────────────────────────────────────┤
# │  BƯỚC 6: SẢN PHẨM & LỢI THẾ CẠNH TRANH                          │
# │  → Sản phẩm gì? Moat (lợi thế bền vững) ở đâu?                 │
# ├─────────────────────────────────────────────────────────────────┤
# │  BƯỚC 7: CHỈ SỐ NGÀNH                                           │
# │  → KPIs đặc thù của ngành (chip, AI chip, LLM...)             │
# ├─────────────────────────────────────────────────────────────────┤
# │  BƯỚC 8: SO SÁNH & ĐỊNH GIÁ                                     │
# │  → So với peers, định giá có hợp lý không?                     │
# ├─────────────────────────────────────────────────────────────────┤
# │  BƯỚC 9: ĐÁNH GIÁ RỦI RO                                        │
# │  → Quản trị, địa chính trị, tài chính, vận hành                │
# ├─────────────────────────────────────────────────────────────────┤
# │  BƯỚC 10: KẾT LUẬN ĐẦU TƯ                                       │
# │  → MUA / THEO DÕI / TRÁNH? Entry, target, stop-loss?           │
# └─────────────────────────────────────────────────────────────────┘
# ```
#
# ---
#
# ## 📚 Thuật ngữ cần biết
#
# | Thuật ngữ | Giải thích | Ví dụ |
# |-----------|------------|-------|
# | **Giá IPO** | Giá cổ phiếu khi phát hành lần đầu | HKD 28.20 |
# | **Vốn hóa (Market Cap)** | Tổng giá trị = Số cổ phiếu × Giá | HKD 16.77 tỷ |
# | **Gross Margin** | (Doanh thu - Giá vốn) / Doanh thu | 63% = lãi 63đ trên 100đ bán |
# | **EV/Sales** | Giá trị doanh nghiệp / Doanh thu | Dùng khi công ty chưa có lãi |
# | **Lock-up** | Thời gian cổ đông lớn không được bán | 6-12 tháng |
# | **Cornerstone** | Nhà đầu tư lớn cam kết mua trước IPO | OmniVision, Youngor |
# | **Moat** | Lợi thế cạnh tranh bền vững | Patent, brand, network effect |
# | **Cash Runway** | Với tốc độ đốt tiền hiện tại, còn bao lâu hết? | 24 tháng |
#
# ---
#
# ## 🚦 Hệ thống đánh giá màu
#
# | Màu | Ý nghĩa | Ví dụ |
# |-----|---------|-------|
# | 🟢 **Xanh** | Tích cực, bullish | Revenue +100% YoY |
# | 🟡 **Vàng** | Trung lập, cần theo dõi | Margin ổn định |
# | 🔴 **Đỏ** | Cảnh báo, rủi ro cao | Cash runway <12 tháng |

# %% [markdown]
# ---
#
# # ⚙️ THIẾT LẬP MÔI TRƯỜNG
#
# Import các thư viện Python cần thiết:
# - **pandas**: Xử lý dữ liệu dạng bảng
# - **numpy**: Tính toán số học
# - **matplotlib**: Vẽ biểu đồ
#
# > 💡 Trên Google Colab, các thư viện này đã được cài sẵn.

# %%
# ═══════════════════════════════════════════════════════════════════════════════
# THIẾT LẬP MÔI TRƯỜNG
# ═══════════════════════════════════════════════════════════════════════════════

import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Cấu hình hiển thị
pd.set_option("display.max_columns", 200)
pd.set_option("display.width", 160)

# Matplotlib tiếng Việt (nếu cần)
plt.rcParams['font.family'] = 'DejaVu Sans'

print("✅ Đã import thành công các thư viện cần thiết!")

# %% [markdown]
# ---
#
# # 📋 BƯỚC 1: THÔNG TIN CÔNG TY
#
# ## Mục đích
# Hiểu công ty làm gì trước khi đi vào số liệu.
#
# ## Câu hỏi cần trả lời
# | Câu hỏi | Tại sao quan trọng? |
# |---------|--------------------|
# | Công ty làm gì? | Hiểu mô hình kinh doanh |
# | Thành lập năm nào? | Đánh giá độ trưởng thành |
# | Niêm yết ở đâu? | HKEX, SGX, SSE có quy định khác nhau |
# | Giá IPO bao nhiêu? | Điểm tham chiếu cho phân tích |

# %%
# ═══════════════════════════════════════════════════════════════════════════════
# BƯỚC 1: THÔNG TIN CÔNG TY - AXERA
# ═══════════════════════════════════════════════════════════════════════════════
# 
# Dictionary chứa metadata của công ty.
# Khi phân tích IPO mới, thay đổi các giá trị trong dictionary này.
#
# ═══════════════════════════════════════════════════════════════════════════════

cong_ty = {
    # --- Thông tin định danh ---
    "ten_day_du": "Axera Semiconductor Co., Ltd.",
    "ten_giao_dich": "AXERA",
    "ma_ck": "00600.HK",
    "san_niem_yet": "HKEX (Hồng Kông)",
    
    # --- Thông tin ngành & lịch sử ---
    "nganh": "Edge AI Chips / Vision AI Processors",
    "nam_thanh_lap": 2019,
    "ngay_niem_yet": "2026-02-10",
    
    # --- Thông tin giao dịch ---
    "lo_giao_dich": 100,  # Số cổ phiếu tối thiểu mỗi lệnh
    "gia_ipo_hkd": 28.20,
    "don_vi_bao_cao": "RMB",  # Đơn vị tiền trong báo cáo tài chính
    
    # --- Links ---
    "link_prospectus": "https://www1.hkexnews.hk/listedco/listconews/sehk/2026/0127/2026012700039.pdf",
}

# ═══════════════════════════════════════════════════════════════════════════════
# HIỂN THỊ
# ═══════════════════════════════════════════════════════════════════════════════

print("=" * 70)
print("📋 BƯỚC 1: THÔNG TIN CÔNG TY")
print("=" * 70)
print(f"""
┌─────────────────────────────────────────────────────────────────────┐
│  Tên công ty      : {cong_ty['ten_day_du']:<45} │
│  Mã chứng khoán   : {cong_ty['ma_ck']:<45} │
│  Sàn niêm yết     : {cong_ty['san_niem_yet']:<45} │
│  Ngành            : {cong_ty['nganh']:<45} │
│  Năm thành lập    : {cong_ty['nam_thanh_lap']} ({2026 - cong_ty['nam_thanh_lap']} năm đến IPO){' '*26} │
│  Ngày niêm yết    : {cong_ty['ngay_niem_yet']:<45} │
│  Giá IPO          : HKD {cong_ty['gia_ipo_hkd']:<42} │
│  Lô giao dịch     : {cong_ty['lo_giao_dich']} cổ phiếu{' '*35} │
└─────────────────────────────────────────────────────────────────────┘
""")

print("\n🔍 ĐÁNH GIÁ SƠ BỘ:")
print("""
🟢 TÍCH CỰC:
   • Ngành Edge AI chips đang tăng trưởng mạnh tại Trung Quốc
   • 7 năm hoạt động trước IPO - đủ mature
   • Niêm yết HKEX Main Board - tiêu chuẩn cao
""")

# %% [markdown]
# ---
#
# # 💰 BƯỚC 2: LỊCH SỬ GỌI VỐN
#
# ## Tại sao quan trọng?
#
# Lịch sử funding cho biết:
# 1. **Ai đã tin tưởng công ty?** - Quỹ VC/PE uy tín = tín hiệu tốt
# 2. **Định giá tăng như thế nào?** - Từ Series A đến IPO
# 3. **IPO có phải "down round"?** - Giá IPO < round trước = cảnh báo
# 4. **Tổng vốn đã huy động** - Công ty đã dùng bao nhiêu tiền?
#
# ## Các vòng gọi vốn
#
# ```
# Series A → Series B → Series C → ... → IPO
#    ↑           ↑           ↑           ↑
#  Giai đoạn  Tăng       Pre-IPO     Thị trường
#  đầu       trưởng                  công khai
# ```

# %%
# ═══════════════════════════════════════════════════════════════════════════════
# BƯỚC 2: LỊCH SỬ GỌI VỐN PRE-IPO - AXERA
# ═══════════════════════════════════════════════════════════════════════════════
# Nguồn: Crunchbase, PitchBook, Caproasia, Pandaily

import pandas as pd

lich_su_goi_von = pd.DataFrame([
    # Vòng          Thời gian      Số tiền (M USD)  Định giá (M USD)  Nhà đầu tư chính
    {"vong": "Seed",       "thoi_gian": "2019",     "so_tien_trieu_usd": 10,   "dinh_gia_trieu_usd": None,    "ndt_chinh": "Qiming Venture Partners"},
    {"vong": "Series A",   "thoi_gian": "Apr 2021", "so_tien_trieu_usd": 50,   "dinh_gia_trieu_usd": None,    "ndt_chinh": "Qiming, Tencent, Meituan"},
    {"vong": "Series A+",  "thoi_gian": "Jul 2021", "so_tien_trieu_usd": 30,   "dinh_gia_trieu_usd": None,    "ndt_chinh": "Chongqing Industrial Fund"},
    {"vong": "Series A-IV","thoi_gian": "Jan 2022", "so_tien_trieu_usd": 126,  "dinh_gia_trieu_usd": 800,     "ndt_chinh": "Multiple investors"},
    {"vong": "Series C",   "thoi_gian": "Apr 2025", "so_tien_trieu_usd": 140,  "dinh_gia_trieu_usd": 1500,    "ndt_chinh": "Strategic investors"},
    {"vong": "IPO",        "thoi_gian": "Feb 2026", "so_tien_trieu_usd": 379,  "dinh_gia_trieu_usd": 2130,    "ndt_chinh": "Public"},
])

# ═══════════════════════════════════════════════════════════════════════════════
# PHÂN TÍCH
# ═══════════════════════════════════════════════════════════════════════════════

tong_truoc_ipo = lich_su_goi_von[lich_su_goi_von["vong"] != "IPO"]["so_tien_trieu_usd"].sum()
dinh_gia_ipo = 2130  # Market cap at IPO: ~2.13B

# Pre-money investors
nha_dau_tu_pre_ipo = [
    "Qiming Venture Partners (Lead)",
    "Tencent",
    "Meituan",
    "Ningbo CTS Fund",
    "Zhenhai Industrial Investment",
    "Chongqing Industrial Investment Master Fund",
    "Chongqing Liangjiang Fund",
    "Weihao Chuangxin (Inno-Chip)",
    "Xfund Capital",
    "Yuanhe Puhua",
]

print("=" * 70)
print("BUOC 2: LICH SU GOI VON PRE-IPO")
print("=" * 70)
print(f"""
┌─────────────────────────────────────────────────────────────────────┐
|  TONG VON GOI TRUOC IPO: {tong_truoc_ipo:,.0f} trieu USD{' ':<8} |
|  DINH GIA TAI IPO      : {dinh_gia_ipo:,.0f} trieu USD{' ':<8} |
└─────────────────────────────────────────────────────────────────────┘
|  TANG TRUONG DINH GIA  : {dinh_gia_ipo/800:.1f}x tu Series A-IV (Jan 2022) -> IPO  |
|  THOI GIAN             : 4 nam tu Seed -> IPO (2019-2026){' ':<10} |
└─────────────────────────────────────────────────────────────────────┘
""")

print("\nNHA DAU TU PRE-IPO CHINH:")
for i, ndt in enumerate(nha_dau_tu_pre_ipo, 1):
    print(f"  {i:2d}. {ndt}")

print("\n" + "=" * 70)
print("CHI TIET CAC VONG GOI VON:")
print("=" * 70)
display(lich_su_goi_von)

# %% [markdown]
# ---
#
# # 📊 BƯỚC 3: PHÂN TÍCH TÀI CHÍNH
#
# ## Tại sao đây là phần quan trọng nhất?
#
# | Chỉ số | Công thức | Ý nghĩa |
# |--------|-----------|--------|
# | **Doanh thu (Revenue)** | Tiền bán hàng | Công ty bán được bao nhiêu? |
# | **Lợi nhuận gộp (Gross Profit)** | Doanh thu - Giá vốn | Lãi sau chi phí sản xuất |
# | **Biên lợi nhuận gộp (Gross Margin)** | Lợi nhuận gộp / Doanh thu | Cao = pricing power tốt |
# | **Lợi nhuận ròng (Net Income)** | Lãi sau tất cả chi phí | Tiền thực sự còn lại |
#
# ## Đặc thù công ty "đang lỗ"
#
# ```
# Công ty trưởng thành              vs              Startup/Growth
# ───────────────────                               ──────────────────
# Revenue: Ổn định                                  Revenue: Tăng nhanh
# Net Income: Có lãi                                Net Income: Thường lỗ
# Đánh giá: P/E ratio                               Đánh giá: EV/Sales
# Câu hỏi: Lãi có bền vững?                         Câu hỏi: Khi nào hòa vốn?
# ```
#
# > ⚠️ **AXERA đang lỗ** - Đây là bình thường với startup chip. Cần focus vào **tăng trưởng doanh thu** và **gross margin**.

# %%
# ═══════════════════════════════════════════════════════════════════════════════
# BƯỚC 3: PHÂN TÍCH TÀI CHÍNH - AXERA
# ═══════════════════════════════════════════════════════════════════════════════
# Nguồn: IPO Prospectus, Asia Tech Daily, Yahoo Finance
# Đơn vị: RMB triệu

import pandas as pd

# Lưu ý: Axera chưa công bố số liệu đầy đủ cho các năm trước
# Dữ liệu chủ yếu từ 9M 2024 và 9M 2025
tai_chinh = pd.DataFrame([
    # Kỳ              Doanh thu    Lợi nhuận gộp  Lợi nhuận ròng  R&D
    {"ky": "FY2022",   "doanh_thu": 50.2,    "loi_nhuan_gop": 11.8,   "loi_nhuan_rong": -611.6,  "rd_spending": 500},
    {"ky": "FY2023",   "doanh_thu": 230.1,   "loi_nhuan_gop": 69.0,   "loi_nhuan_rong": -743.1,  "rd_spending": 630},
    {"ky": "FY2024",   "doanh_thu": 472.9,   "loi_nhuan_gop": 141.9,  "loi_nhuan_rong": -904.2,  "rd_spending": 780},
    {"ky": "9M2024",   "doanh_thu": 254,   "loi_nhuan_gop": 75,   "loi_nhuan_rong": -691,  "rd_spending": 480},
    {"ky": "9M2025",   "doanh_thu": 269,   "loi_nhuan_gop": 82,   "loi_nhuan_rong": -856,  "rd_spending": 550},
])

# Tính toán các chỉ số
tai_chinh["gross_margin_pct"] = (tai_chinh["loi_nhuan_gop"] / tai_chinh["doanh_thu"] * 100).round(1)
tai_chinh["net_margin_pct"] = (tai_chinh["loi_nhuan_rong"] / tai_chinh["doanh_thu"] * 100).round(1)
tai_chinh["rd_pct_revenue"] = (tai_chinh["rd_spending"] / tai_chinh["doanh_thu"] * 100).round(1)

# CAGR 2022-2024 (từ prospectus)
cagr_revenue = 206.8  # % (công bố trong prospectus)
tang_truong_9m = 5.8  # % YoY (9M2025 vs 9M2024)

# Cash burn analysis
cash_burn_9m2025 = 855.7  # RMB triệu
cash_ipo_proceeds = 2960  # HKD triệu ~ RMB 2700 triệu
runway_months = (cash_ipo_proceeds * 0.9) / (cash_burn_9m2025 * 12 / 9)  # Estimate

print("=" * 70)
print("BUOC 3: PHAN TICH TAI CHINH")
print("=" * 70)
print(f"""
┌─────────────────────────────────────────────────────────────────────┐
|  TONG QUAN TAI CHINH AXERA (Don vi: RMB trieu){' ':<21} |
└─────────────────────────────────────────────────────────────────────┘
|  CAGR Doanh thu 2022-2024    : {cagr_revenue:.1f}% (RẤT CAO){' ':<19} |
|  Tang truong 9M2025 vs 9M2024: {tang_truong_9m:.1f}% (CHAM LAI){' ':<20} |
└─────────────────────────────────────────────────────────────────────┘
|  Bien loi nhuan gop (9M2025) : {tai_chinh.loc[4, 'gross_margin_pct']:.1f}%{' ':<30} |
|  R&D / Doanh thu (9M2025)    : {tai_chinh.loc[4, 'rd_pct_revenue']:.1f}% (DAU TU MANH){' ':<15} |
└─────────────────────────────────────────────────────────────────────┘
|  Lo rong 9M2025              : RMB {abs(tai_chinh.loc[4, 'loi_nhuan_rong']):.0f} trieu{' ':<19} |
|  Cash burn rate              : ~RMB {cash_burn_9m2025*12/9:.0f} trieu/nam{' ':<15} |
|  Runway sau IPO (uoc tinh)   : ~{runway_months:.0f} thang{' ':<26} |
└─────────────────────────────────────────────────────────────────────┘

LUU Y QUAN TRONG:
- Axera VAN DANG LO - typical cho chip startup giai doan dau
- R&D spending chiem >200% doanh thu - dau tu manh cho tuong lai
- CAGR cao nhung tang truong cham lai trong 2025
- IPO proceeds se giup gia han runway them ~2 nam
""")

print("\n" + "=" * 70)
print("CHI TIET TAI CHINH THEO KY:")
print("=" * 70)
display(tai_chinh)

# %%
# ═══════════════════════════════════════════════════════════════════════════════
# BƯỚC 3B: BIỂU ĐỒ TÀI CHÍNH
# ═══════════════════════════════════════════════════════════════════════════════

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Biểu đồ 1: Doanh thu
axes[0].bar(tai_chinh["ky"], tai_chinh["doanh_thu"]/1e6, color='#4472C4')
axes[0].set_title("Doanh thu theo kỳ (triệu RMB)", fontsize=12, fontweight='bold')
axes[0].set_ylabel("Triệu RMB")
axes[0].grid(True, alpha=0.3)

# Biểu đồ 2: Lợi nhuận ròng
colors = ['#C00000' if x < 0 else '#70AD47' for x in tai_chinh["loi_nhuan_rong"]]
axes[1].bar(tai_chinh["ky"], tai_chinh["loi_nhuan_rong"]/1e6, color=colors)
axes[1].set_title("Lợi nhuận ròng theo kỳ (triệu RMB)", fontsize=12, fontweight='bold')
axes[1].set_ylabel("Triệu RMB")
axes[1].axhline(y=0, color='black', linestyle='-', linewidth=0.5)
axes[1].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

print("📊 Nhận xét biểu đồ:")
print("   • Doanh thu tăng mạnh từ FY2023 → FY2024")
print("   • 1H2025 đã gần bằng cả năm FY2024")
print("   • Lỗ đang thu hẹp dần (tín hiệu tích cực)")

# %% [markdown]
# ---
#
# # 📈 BƯỚC 4: ĐIỀU KHOẢN IPO & SỬ DỤNG VỐN
#
# ## Những thông tin cần thu thập
#
# | Hạng mục | Ý nghĩa |
# |----------|--------|
# | **Giá IPO** | Mức giá công ty bán cổ phiếu ra công chúng |
# | **Số tiền huy động** | Gross proceeds và net proceeds (sau phí) |
# | **Số cổ phiếu** | Trước và sau IPO |
# | **Sử dụng vốn** | Tiền IPO sẽ dùng vào việc gì? |
#
# ## Tại sao "Use of Proceeds" quan trọng?
#
# - Cho biết **chiến lược ưu tiên** của công ty
# - R&D cao = đang đầu tư cho tương lai
# - Working capital cao = có thể đang thiếu tiền mặt

# %%
# ═══════════════════════════════════════════════════════════════════════════════
# BƯỚC 4: ĐIỀU KHOẢN IPO & SỬ DỤNG VỐN - AXERA
# ═══════════════════════════════════════════════════════════════════════════════
# Nguồn: HKEX Prospectus, Pandaily, Finance Yahoo

dieu_khoan_ipo = {
    # --- Giá & Số lượng ---
    "gia_ipo_hkd": 28.20,
    "gia_ipo_usd": 3.63,
    "so_co_phieu_phat_hanh": 104_900_000,  # 104.9 triệu H shares
    "co_phieu_hong_kong": 10_490_000,      # 10% cho HK public
    "co_phieu_quoc_te": 94_420_000,        # 90% cho international placement

    # --- Vốn huy động ---
    "von_huy_dong_bruto_hkd": 2_958_000_000,  # HKD 2.96 tỷ
    "von_huy_dong_bruto_usd": 379_000_000,    # ~$379M
    "von_huy_dong_rong_usd": 350_000_000,     # Ước tính sau chi phí

    # --- Định giá ---
    "market_cap_ipo_hkd": 16_580_000_000,    # HKD 16.58 tỷ
    "market_cap_ipo_usd": 2_130_000_000,     # ~$2.13 tỷ

    # --- Chi phí IPO (ước tính) ---
    "underwriting_fee_pct": 3.5,
    "legal_accounting_hkd": 50_000_000,

    # --- Sử dụng vốn (từ prospectus) ---
    "su_dung_von": {
        "R&D & phat trien san pham moi": 45,      # %
        "Mo rong ban hang & marketing": 25,       # %
        "M&A tiem nang": 15,                       # %
        "Von luu dong & chi phi chung": 15,       # %
    },

    # --- Thông tin niêm yết ---
    "ngan_hang_bao_lanh": ["CICC", "CLSA", "Huatai International"],
    "ngay_chao_ban": "2026-01-31",
    "ngay_niem_yet": "2026-02-10",
    "gia_nhap_toi_thieu_hkd": 2848,  # 1 lot = 100 shares
}

# ═══════════════════════════════════════════════════════════════════════════════
# HIỂN THỊ
# ═══════════════════════════════════════════════════════════════════════════════

print("=" * 70)
print("BUOC 4: DIEU KHOAN IPO & SU DUNG VON")
print("=" * 70)

gia = dieu_khoan_ipo["gia_ipo_hkd"]
gia_usd = dieu_khoan_ipo["gia_ipo_usd"]
von_bruto = dieu_khoan_ipo["von_huy_dong_bruto_hkd"] / 1e9
von_usd = dieu_khoan_ipo["von_huy_dong_bruto_usd"] / 1e6
mcap = dieu_khoan_ipo["market_cap_ipo_hkd"] / 1e9
mcap_usd = dieu_khoan_ipo["market_cap_ipo_usd"] / 1e9

print(f"""
┌─────────────────────────────────────────────────────────────────────┐
|  GIA & DINH GIA                                                     |
└─────────────────────────────────────────────────────────────────────┘
|  Gia IPO              : HKD {gia:.2f} (USD {gia_usd:.2f})                   |
|  Von huy dong bruto   : HKD {von_bruto:.2f} ty (~${von_usd:.0f}M)                   |
|  Market Cap tai IPO   : HKD {mcap:.2f} ty (~${mcap_usd:.2f}B)                  |
└─────────────────────────────────────────────────────────────────────┘
""")

so_cp = dieu_khoan_ipo["so_co_phieu_phat_hanh"]
cp_hk = dieu_khoan_ipo["co_phieu_hong_kong"]
cp_qt = dieu_khoan_ipo["co_phieu_quoc_te"]
gia_nhap = dieu_khoan_ipo["gia_nhap_toi_thieu_hkd"]

print(f"""
└─────────────────────────────────────────────────────────────────────┘
|  CO PHIEU                                                           |
└─────────────────────────────────────────────────────────────────────┘
|  Tong so phat hanh    : {so_cp:,} H-shares                      |
|  Hong Kong Public     : {cp_hk:,} (10%)                          |
|  International        : {cp_qt:,} (90%)                          |
|  Gia nhap toi thieu   : HKD {gia_nhap:,} (1 lot = 100 shares)        |
└─────────────────────────────────────────────────────────────────────┘
""")

print("SU DUNG VON:")
for muc_dich, ty_le in dieu_khoan_ipo["su_dung_von"].items():
    bar = "#" * int(ty_le / 2)
    print(f"  {muc_dich:<35} : {ty_le:>3}% |{bar}")

banks = ", ".join(dieu_khoan_ipo["ngan_hang_bao_lanh"])
ngay_cb = dieu_khoan_ipo["ngay_chao_ban"]
ngay_nl = dieu_khoan_ipo["ngay_niem_yet"]
print(f"""
└─────────────────────────────────────────────────────────────────────┘
|  NGAN HANG BAO LANH: {banks}                   |
|  Ngay chao ban: {ngay_cb} | Ngay niem yet: {ngay_nl}             |
└─────────────────────────────────────────────────────────────────────┘
""")

# %% [markdown]
# ---
#
# # 👥 BƯỚC 5: CORNERSTONE & LOCK-UP
#
# ## Cornerstone Investor là gì?
#
# Nhà đầu tư tổ chức lớn cam kết mua cổ phiếu **trước IPO**:
# - Cam kết mua trước → Giảm rủi ro không bán hết
# - Thường có lock-up 6 tháng → Không bán ngay
# - Tên công khai trong prospectus → Tín hiệu cho thị trường
#
# ## Đánh giá chất lượng cornerstone
#
# ```
# Cornerstone chất lượng cao              vs         Cornerstone đáng nghi
# ─────────────────────────                          ─────────────────────
# • Sovereign funds (Youngor, GIC)                      • "Friendly" allocation
# • Top PE/VC (Sequoia, Boyu)                        • Không tên tuổi
# • Strategic (Tencent, Alibaba)                     • Tỷ lệ quá cao (>50%)
# ```
#
# ## Lock-up là gì?
#
# Thời gian cổ đông lớn **không được bán** sau IPO:
#
# | Loại cổ đông | Thời gian lock-up |
# |--------------|------------------|
# | Cornerstone | 6 tháng |
# | Pre-IPO investors | 6-12 tháng |
# | Founders | 12-24 tháng |
#
# > ⚠️ **Trading tip**: Khi lock-up hết hạn, thường có áp lực bán.

# %%
# ═══════════════════════════════════════════════════════════════════════════════
# BƯỚC 5: CORNERSTONE INVESTORS & LOCK-UP - AXERA
# ═══════════════════════════════════════════════════════════════════════════════
# Nguồn: Pandaily, HKEX Prospectus

import pandas as pd

# Cornerstone investors (tổng $185M)
cornerstone = pd.DataFrame([
    # Tên                          Số tiền (M USD)  Loại investor              Lock-up
    {"ten": "OmniVision Group (WILL Semiconductor)", "so_tien_trieu_usd": 35, "loai": "Strategic (Chip Industry)", "lock_up_thang": 6},
    {"ten": "Youngor Group",                          "so_tien_trieu_usd": 35,  "loai": "Financial",                 "lock_up_thang": 6},
])

# Pre-IPO investors (may be subject to lock-up)
pre_ipo_investors = [
    {"ten": "Qiming Venture Partners", "vai_tro": "Lead Investor", "lock_up_thang": 12},
    {"ten": "Tencent",                  "vai_tro": "Strategic",    "lock_up_thang": 12},
    {"ten": "Meituan",                  "vai_tro": "Strategic",    "lock_up_thang": 12},
    {"ten": "Weihao Chuangxin (Inno-Chip)", "vai_tro": "Strategic", "lock_up_thang": 12},
    {"ten": "Chongqing Industrial Fund", "vai_tro": "Government",   "lock_up_thang": 12},
]

# Lock-up schedule
ngay_ipo = "2026-02-10"
lock_up_schedule = {
    "6_thang": "2026-08-10",   # Cornerstone investors
    "12_thang": "2027-02-10",  # Pre-IPO investors, founders
    "18_thang": "2027-08-10",  # Key management (estimated)
}

# ═══════════════════════════════════════════════════════════════════════════════
# TÍNH TOÁN & HIỂN THỊ
# ═══════════════════════════════════════════════════════════════════════════════

tong_cornerstone = cornerstone["so_tien_trieu_usd"].sum()
pct_ipo = tong_cornerstone / 379 * 100  # % of IPO proceeds

print("=" * 70)
print("BUOC 5: CORNERSTONE INVESTORS & LOCK-UP")
print("=" * 70)
print(f"""
┌─────────────────────────────────────────────────────────────────────┐
|  CORNERSTONE INVESTORS                                              |
└─────────────────────────────────────────────────────────────────────┘
|  Tong so tien      : ${tong_cornerstone:,.0f} trieu USD                            |
|  % IPO proceeds    : {pct_ipo:.1f}% (rat cao - cho thay su quan tam)         |
└─────────────────────────────────────────────────────────────────────┘
""")

print("CHI TIET CORNERSTONE:")
for _, row in cornerstone.iterrows():
    print(f"  - {row['ten']}")
    print(f"    ${row['so_tien_trieu_usd']}M | {row['loai']} | Lock-up: {row['lock_up_thang']} thang")

print(f"""
└─────────────────────────────────────────────────────────────────────┘
|  DANH GIA CHAT LUONG CORNERSTONE                                    |
└─────────────────────────────────────────────────────────────────────┘
|  OmniVision (WILL Semi) - Strategic partner trong nganh chip        |
|    -> Co the hop tac cung cap, cong nghe trong tuong lai            |
|  Youngor Group - Tap doan lon da nganh cua Trung Quoc               |
|    -> Financial investor, cho thay su tin tuong vao co phieu        |
└─────────────────────────────────────────────────────────────────────┘
""")

print("=" * 70)
print("LOCK-UP SCHEDULE")
print("=" * 70)
print(f"""
└─────────────────────────────────────────────────────────────────────┘
|  NGAY IPO: {ngay_ipo}                                              |
└─────────────────────────────────────────────────────────────────────┘
|  6 thang  ({lock_up_schedule['6_thang']})  : Cornerstone investors          |
|  12 thang ({lock_up_schedule['12_thang']}) : Pre-IPO investors, founders    |
|  18 thang ({lock_up_schedule['18_thang']}) : Key management (uoc tinh)      |
└─────────────────────────────────────────────────────────────────────┘

CANH BAO:
- {lock_up_schedule['6_thang']}: Co the co ap luc ban khi cornerstone het lock-up
- {lock_up_schedule['12_thang']}: Ap luc lon hon khi founders/VCs co the ban
- Theo doi khoi luong giao dich truoc cac ngay nay!
""")

print("\nPRE-IPO INVESTORS (co the bi lock-up 12 thang):")
for inv in pre_ipo_investors:
    print(f"  - {inv['ten']} ({inv['vai_tro']})")

print("\n" + "=" * 70)
print("BANG CORNERSTONE CHI TIET:")
print("=" * 70)
display(cornerstone.rename(columns={
    "ten": "Nha dau tu",
    "so_tien_trieu_usd": "So tien (M USD)",
    "loai": "Loai investor",
    "lock_up_thang": "Lock-up (thang)"
}))

# %% [markdown]
# ---
#
# # 🔬 BƯỚC 6: SẢN PHẨM & LỢI THẾ CẠNH TRANH
#
# ## Moat (Lợi thế cạnh tranh) là gì?
#
# **Moat** = Những yếu tố giúp công ty duy trì lợi thế trước đối thủ
#
# | Loại Moat | Mô tả | Ví dụ |
# |-----------|-------|-------|
# | **Patents/IP** | Sở hữu trí tuệ | Công nghệ độc quyền |
# | **Regulatory** | Giấy phép, chứng nhận | PSA Certified, automotive certifications |
# | **Switching Cost** | Chi phí chuyển đổi | Khách hàng đã tích hợp SDK/tools |
# | **Network Effect** | Hiệu ứng mạng lưới | Càng nhiều developers, ecosystem càng mạnh |
# | **Scale** | Quy mô | Sản xuất nhiều = giá thành thấp |

# %%
# ═══════════════════════════════════════════════════════════════════════════════
# BƯỚC 6: SẢN PHẨM & LỢI THẾ CẠNH TRANH - AXERA
# ═══════════════════════════════════════════════════════════════════════════════
# Nguồn: Axera website, CNX Software, PSA Certified, IPO Prospectus

import pandas as pd

# Product Portfolio
san_pham = pd.DataFrame([
    # Dòng sản phẩm     Segment              Hiệu năng        Ứng dụng chính
    {"dong_sp": "AX620 Series",  "segment": "Entry-level IPC",      "hieu_nang": "3.2-12.8 TOPS",  "ung_dung": "Smart cameras, IPC, consumer devices"},
    {"dong_sp": "AX630 Series",  "segment": "Mid-range Edge AI",    "hieu_nang": "3.2-12.8 TOPS",  "ung_dung": "4K AI cameras, edge computing"},
    {"dong_sp": "AX650 Series",  "segment": "High-end Edge AI",     "hieu_nang": "18-72 TOPS",     "ung_dung": "8K AI-ISP, smart retail, smart city"},
    {"dong_sp": "M55H/M76H",     "segment": "Smart Driving",        "hieu_nang": "TBD",            "ung_dung": "ADAS, intelligent driving SoC"},
])

# Key Technologies
cong_nghe_chinh = [
    {"ten": "AXProton AI-ISP", "mo_ta": "Image enhancement in complex lighting (day/night)"},
    {"ten": "AXNeutron NPU",   "mo_ta": "Mixed precision NPU, supports Llama/DeepSeek LLMs"},
    {"ten": "8K@30fps AI-ISP", "mo_ta": "Real-time 8K video with AI processing"},
    {"ten": "PSA Certified",   "mo_ta": "Security certification for IoT devices"},
]

# Competitive Advantages
loi_the = [
    "1. Full-stack: Hardware + Software (SDK, tools, developer ecosystem)",
    "2. AI-first design: NPU optimized for edge inference, not general compute",
    "3. Low power consumption: Critical for edge/IoT devices",
    "4. Dual-track: Consumer (IPC) + Automotive (ADAS) markets",
    "5. Local supply chain: Less exposed to US sanctions on fab equipment",
]

# Shipment milestones
shipments = {
    "cumulative_socs": 165_000_000,  # >165 million SoCs
    "terminal_growth_2024": 69,      # +69% YoY
    "edge_growth_2024": 400,         # +400% YoY
}

print("=" * 70)
print("BUOC 6: SAN PHAM & LOI THE CANH TRANH")
print("=" * 70)
print(f"""
┌─────────────────────────────────────────────────────────────────────┐
|  TONG QUAN SAN PHAM AXERA                                           |
└─────────────────────────────────────────────────────────────────────┘
|  Tong SoC da xuat xuong   : >{shipments['cumulative_socs']/1e6:.0f} trieu chips (Q3/2025)      |
|  Tang truong Terminal 2024: +{shipments['terminal_growth_2024']}% YoY                             |
|  Tang truong Edge AI 2024 : +{shipments['edge_growth_2024']}% YoY (rất cao!)                    |
└─────────────────────────────────────────────────────────────────────┘
""")

print("DANH MUC SAN PHAM:")
print("-" * 70)
for _, sp in san_pham.iterrows():
    print(f"  {sp['dong_sp']:<15} | {sp['segment']:<20} | {sp['hieu_nang']}")
    print(f"                  -> {sp['ung_dung']}")

print("\n" + "=" * 70)
print("CONG NGHE CHINH:")
print("-" * 70)
for cn in cong_nghe_chinh:
    print(f"  - {cn['ten']}: {cn['mo_ta']}")

print("\n" + "=" * 70)
print("LOI THE CANH TRANH:")
print("-" * 70)
for lt in loi_the:
    print(f"  {lt}")

print("\n" + "=" * 70)
display(san_pham)

# %% [markdown]
# ---
#
# # 📊 BƯỚC 7: CHỈ SỐ NGÀNH
#
# ## Tại sao cần KPIs đặc thù ngành?
#
# Mỗi ngành có những chỉ số quan trọng khác nhau:
#
# | Ngành | KPIs đặc thù |
# |-------|-------------|
# | **Edge AI Chips** | Shipments, TOPS performance, market share, design wins |
# | **AI Chips** | Design wins, tape-out schedule, foundry partner |
# | **LLM/GenAI** | API calls, MAU, compute cost ratio |

# %%
# ═══════════════════════════════════════════════════════════════════════════════
# BƯỚC 7: CHỈ SỐ NGÀNH - Edge AI Chips
# ═══════════════════════════════════════════════════════════════════════════════
# Nguồn: IDC, Gartner, IC Insights, Company reports

import pandas as pd

# KPIs đặc thù ngành Edge AI Chips
kpi_nganh = {
    "thi_truong_toan_cau_2024": 15.2,  # tỷ USD
    "cagr_2024_2030": 18.5,  # %
    "top_players": ["Nvidia", "AMD", "Intel", "Qualcomm", "MediaTek", "Axera"],
    "axera_market_share_mid_high": 24.1,  # % trong phân khúc mid-to-high-end
    "axera_global_rank": 5,  # Hạng toàn cầu
}

# Axera specific KPIs
axera_kpi = pd.DataFrame([
    {"chi_so": "Tổng SoC đã xuất xưởng", "gia_tri": ">165 triệu", "thoi_gian": "Q3/2025"},
    {"chi_so": "Tăng trưởng Terminal SoC", "gia_tri": "+69%", "thoi_gian": "2024 YoY"},
    {"chi_so": "Tăng trưởng Edge AI SoC", "gia_tri": "+400%", "thoi_gian": "2024 YoY"},
    {"chi_so": "Smart Driving revenue growth", "gia_tri": "+250%", "thoi_gian": "9M2025 YoY"},
    {"chi_so": "Số thế hệ sản phẩm", "gia_tri": "5 thế hệ", "thoi_gian": "2025"},
    {"chi_so": "NPU Performance (AX650)", "gia_tri": "18-72 TOPS", "thoi_gian": "INT8/INT4"},
])

# So sánh với đối thủ
doi_thu = pd.DataFrame([
    {"cong_ty": "Axera", "phan_khuc": "Edge AI Vision", "hieu_nang": "18-72 TOPS", "thi_phan": "24.1%", "loi_the": "Full-stack, AI-first"},
    {"cong_ty": "Horizon Robotics", "phan_khuc": "Automotive AI", "hieu_nang": "128+ TOPS", "thi_phan": "~30%", "loi_the": "Automotive focus"},
    {"cong_ty": "Black Sesame", "phan_khuc": "Automotive AI", "hieu_nang": "106 TOPS", "thi_phan": "~80%", "loi_the": "L2+ ADAS"},
    {"cong_ty": "Rockchip", "phan_khuc": "Edge AI", "hieu_nang": "6 TOPS", "thi_phan": "~10%", "loi_the": "Low cost"},
])

print("=" * 70)
print("BUOC 7: CHI SO NGANH - Edge AI Chips")
print("=" * 70)
print(f"""
┌─────────────────────────────────────────────────────────────────────┐
|  THI TRUONG EDGE AI CHIPS TOAN CAU                                  |
└─────────────────────────────────────────────────────────────────────┘
|  Quy mo 2024        : ${kpi_nganh['thi_truong_toan_cau_2024']} ty USD                          |
|  CAGR 2024-2030     : {kpi_nganh['cagr_2024_2030']}%                                      |
|  Xu huong           : AI at the Edge, Smart City, ADAS, AIoT        |
└─────────────────────────────────────────────────────────────────────┘
|  AXERA VI THE                                                       |
└─────────────────────────────────────────────────────────────────────┘
|  Hang toan cau      : #{kpi_nganh['axera_global_rank']} (visual edge AI inference chips)        |
|  Thi phan mid-high  : {kpi_nganh['axera_market_share_mid_high']}% (#1 trong phan khuc)                  |
└─────────────────────────────────────────────────────────────────────┘
""")

print("KPIs AXERA:")
print("-" * 70)
for _, row in axera_kpi.iterrows():
    print(f"  {row['chi_so']:<30} : {row['gia_tri']:<15} ({row['thoi_gian']})")

print("\n" + "=" * 70)
print("SO SANH VOI DOI THU:")
print("-" * 70)
display(doi_thu)

# %% [markdown]
# ---
#
# # 💵 BƯỚC 8: SO SÁNH & ĐỊNH GIÁ
#
# ## Phương pháp định giá cho công ty chưa có lãi
#
# | Phương pháp | Khi nào dùng | Công thức |
# |-------------|--------------|----------|
# | **P/E** | Công ty có lãi | Giá / EPS |
# | **EV/Sales** | Công ty chưa có lãi | Enterprise Value / Doanh thu |
# | **EV/Gross Profit** | Công ty có gross margin ổn định | EV / Lợi nhuận gộp |
#
# > **AXERA đang lỗ** → Dùng **EV/Sales** để so sánh
#
# ## Chọn peer để so sánh
#
# - **Benchmark toàn cầu**: Nvidia (NVDA) - "king" của AI chips
# - **Peers Trung Quốc (Automotive AI)**: Horizon Robotics (9660.HK)
# - **Adjacent comps**: Các công ty AI chips khác

# %%
# ═══════════════════════════════════════════════════════════════════════════════
# BƯỚC 8: SO SÁNH & ĐỊNH GIÁ
# ═══════════════════════════════════════════════════════════════════════════════

# Cash runway analysis
tien_mat_truoc_ipo = 94_457e3  # RMB, từ balance sheet
von_ipo_rmb = 1_116.6e6 * 0.92  # Chuyển HKD → RMB
tong_tien_mat = tien_mat_truoc_ipo + von_ipo_rmb

# Ước tính burn rate từ 1H2025
burn_rate_quy = 89_087e3 / 2  # Lỗ 1H2025 / 2 quý

runway_quy = tong_tien_mat / burn_rate_quy
runway_nam = runway_quy / 4

# Peer comparison
so_sanh_peer = pd.DataFrame([
    {"cong_ty": "Nvidia", "ma_ck": "NVDA", "ev_sales": "15-20x", "gross_margin": "~65%", "tang_truong": "~80%", "loi_nhuan": "Có lãi"},
    {"cong_ty": "Horizon Robotics", "ma_ck": "9660.HK", "ev_sales": "8-12x", "gross_margin": "~45%", "tang_truong": "~100%", "loi_nhuan": "Lỗ"},
    {"cong_ty": "AXERA", "ma_ck": "00600.HK", "ev_sales": "10-15x", "gross_margin": "~63%", "tang_truong": ">200%", "loi_nhuan": "Lỗ"},
])

# ═══════════════════════════════════════════════════════════════════════════════
# HIỂN THỊ
# ═══════════════════════════════════════════════════════════════════════════════

print("=" * 70)
print("💵 BƯỚC 8: SO SÁNH & ĐỊNH GIÁ")
print("=" * 70)

print(f"""
┌─────────────────────────────────────────────────────────────────────┐
│  💰 PHÂN TÍCH DÒNG TIỀN (Cash Runway)                               │
├─────────────────────────────────────────────────────────────────────┤
│  Tiền mặt trước IPO    : ¥{tien_mat_truoc_ipo/1e6:.1f} triệu                          │
│  Vốn IPO (sau chuyển)  : ¥{von_ipo_rmb/1e6:.1f} triệu                         │
│  Tổng tiền mặt         : ¥{tong_tien_mat/1e6:.1f} triệu                        │
│  Burn rate/quý (ước)   : ¥{burn_rate_quy/1e6:.1f} triệu                           │
│  ─────────────────────────────────────────────────────────────────  │
│  Cash Runway           : {runway_quy:.1f} quý (~{runway_nam:.1f} năm) 🟢               │
└─────────────────────────────────────────────────────────────────────┘
""")

print("\n📊 So sánh với Peers:")
print("-" * 70)
display(so_sanh_peer.rename(columns={
    "cong_ty": "Công ty",
    "ma_ck": "Mã CK",
    "ev_sales": "EV/Sales",
    "gross_margin": "Gross Margin",
    "tang_truong": "Tăng trưởng",
    "loi_nhuan": "Lợi nhuận"
}))

print("\n🔍 ĐÁNH GIÁ ĐỊNH GIÁ:")
print("""
🟢 TÍCH CỰC:
   • Cash runway ~5.7 năm - Không lo hết tiền trong ngắn hạn
   • Gross margin 63% - Cao hơn Horizon (55%), gần Nvidia (67%)
   • Tăng trưởng >200% - Cao nhất trong peers

🟡 ĐỊNH GIÁ:
   • EV/Sales 10-15x: Premium nhưng growth cao hơn
   • Discount so với Nvidia - hợp lý vì quy mô và profitability
   • Fair value range: HKD 55-75
""")

# %% [markdown]
# ---
#
# # ⚠️ BƯỚC 9: ĐÁNH GIÁ RỦI RO
#
# ## Các loại rủi ro cần đánh giá
#
# | Loại rủi ro | Mô tả | Ví dụ |
# |-------------|-------|-------|
# | **Quản trị** | Founder control, related-party | Conflict of interest |
# | **Tài chính** | Cash burn, runway | Hết tiền |
# | **Vận hành** | Sản phẩm, sản xuất | Single-product risk |
# | **Cạnh tranh** | Đối thủ, thị phần | Nvidia, Horizon |
# | **Địa chính trị** | Sanctions, export control | US-China tech war |
# | **Pháp lý** | Certification/Compliance | Export control listing |

# %%
# ═══════════════════════════════════════════════════════════════════════════════
# BƯỚC 9: ĐÁNH GIÁ RỦI RO - AXERA
# ═══════════════════════════════════════════════════════════════════════════════

import pandas as pd

# Risk Assessment Framework
rui_ro = pd.DataFrame([
    # Loại rủi ro           Mức độ    Xác suất   Mô tả
    {"loai": "PROFITABILITY",       "muc_do": "CAO",    "xac_suat": "Cao",    "mo_ta": "Van dang lo lon, chua co lo trinh den breakeven ro rang"},
    {"loai": "TECH/COMPETITION",    "muc_do": "TRUNG BINH", "xac_suat": "Trung binh", "mo_ta": "Nganh chip canh tranh gay gat (Horizon, Black Sesame...)"},
    {"loai": "GEOPOLITICAL",        "muc_do": "CAO",    "xac_suat": "Trung binh", "mo_ta": "US export controls co the anh huong den fab partners"},
    {"loai": "CUSTOMER CONCENTRATION", "muc_do": "TRUNG BINH", "xac_suat": "Trung binh", "mo_ta": "Chua ro top customers, co the phu thuoc vai khach lon"},
    {"loai": "LOCK-UP EXPIRY",      "muc_do": "CAO",    "xac_suat": "Cao",    "mo_ta": "Aug 2026: cornerstone, Feb 2027: founders/VCs het lock-up"},
    {"loai": "EXECUTION RISK",      "muc_do": "TRUNG BINH", "xac_suat": "Trung binh", "mo_ta": "Can thuc hien ket hoach R&D va mo rong thi truong"},
])

# Geopolitical Risk Details
geo_risk = {
    "entity_list": False,  # Axera NOT on Entity List (as of Feb 2026)
    "fab_dependency": "TSMC, Samsung (co the bi anh huong boi US controls)",
    "domestic_alternative": "SMIC - co the dung cho mature nodes",
    "risk_level": "TRUNG BINH - THEO DOI SAT",
}

print("=" * 70)
print("BUOC 9: DANH GIA RUI RO")
print("=" * 70)

print(f"""
┌─────────────────────────────────────────────────────────────────────┐
|  GEOPOLITICAL RISK ASSESSMENT                                       |
└─────────────────────────────────────────────────────────────────────┘
|  Entity List status    : {'KHONG' if not geo_risk['entity_list'] else 'CO'} nam trong Entity List         |
|  Fab dependency        : {geo_risk['fab_dependency'][:45]:<45} |
|  Domestic alternative  : {geo_risk['domestic_alternative']:<45} |
|  Overall risk level    : {geo_risk['risk_level']:<45} |
└─────────────────────────────────────────────────────────────────────┘

LUU Y VE US EXPORT CONTROLS:
- US mo rong danh sach han che vao Dec 2024 (140 cong ty moi)
- Axera chua bi truc tiep, nhung fab partners co the bi anh huong
- Theo doi cac dot cap nhat Entity List tu BIS
""")

print("=" * 70)
print("MA TRAN RUI RO:")
print("=" * 70)
for _, row in rui_ro.iterrows():
    icon = "[!]" if row["muc_do"] == "CAO" else "[~]"
    print(f"  {icon} {row['loai']:<22} | {row['muc_do']:<10} | {row['xac_suat']:<12}")
    print(f"      -> {row['mo_ta']}")

print(f"""
└─────────────────────────────────────────────────────────────────────┘
|  TONG KET RUI RO                                                    |
└─────────────────────────────────────────────────────────────────────┘
|  - Rui ro TAI CHINH cao nhat: cong ty van lo, can theo doi runway  |
|  - Rui ro LOCK-UP: canh giac truoc Aug 2026 va Feb 2027            |
|  - Rui ro DIA CHINH TRI: hien tai thap, nhung can theo doi US-China|
└─────────────────────────────────────────────────────────────────────┘
""")

display(rui_ro)

# %% [markdown]
# ---
#
# # 📝 BƯỚC 10: KẾT LUẬN ĐẦU TƯ
#
# ## Framework ra quyết định
#
# ```
#                          ┌─────────────────┐
#                          │  QUYẾT ĐỊNH     │
#                          │  ĐẦU TƯ         │
#                          └────────┬────────┘
#                                   │
#            ┌──────────────────────┼──────────────────────┐
#            ▼                      ▼                      ▼
#      ┌─────────┐           ┌─────────────┐        ┌─────────────┐
#      │   MUA   │           │  THEO DÕI   │        │   TRÁNH     │
#      └────┬────┘           └──────┬──────┘        └──────┬──────┘
#           │                       │                      │
#    • Thesis mạnh             • Thesis OK            • Thesis yếu
#    • Định giá hấp dẫn        • Định giá fair        • Định giá cao
#    • Risk chấp nhận được     • Cần thêm data        • Red flags nhiều
#    • Catalysts rõ            • Chờ entry point      • Risk > Reward
# ```

# %%
# ═══════════════════════════════════════════════════════════════════════════════
# BƯỚC 10: KẾT LUẬN ĐẦU TƯ - AXERA
# ═══════════════════════════════════════════════════════════════════════════════

# Investment Thesis
ket_luan = {
    "recommendation": "THEO DOI / Tich luy khi giam",
    "rating": 3,  # 1-5 scale (3 = Neutral/Watch)
    "entry_zone_hkd": (24.0, 26.0),
    "target_hkd": (35.0, 40.0),
    "stop_loss_hkd": 20.0,
    "time_horizon": "12-18 thang",
}

# Key Catalysts
catalysts = [
    {"event": "FY2025 Earnings", "date": "Q1 2026", "impact": "Cao", "mo_ta": "Xem revenue growth co duy tri?"},
    {"event": "Smart Driving adoption", "date": "2026", "impact": "Cao", "mo_ta": "Automotive revenue tang len?"},
    {"event": "6M Lock-up expiry", "date": "Aug 2026", "impact": "Tieu cuc", "mo_ta": "Ap luc ban tu cornerstone"},
    {"event": "12M Lock-up expiry", "date": "Feb 2027", "impact": "Tieu cuc", "mo_ta": "Ap luc ban tu founders/VCs"},
    {"event": "Breakeven timeline", "date": "2027-2028?", "impact": "Cao", "mo_ta": "Khi nao cong ty co lai?"},
]

# Pros & Cons
pros = [
    "Vi the #1 mid-to-high-end visual edge AI chips",
    "CAGR 206.8% (2022-2024) - tang truong rat nhanh",
    "Cornerstone chat luong (OmniVision, Youngor)",
    "Dual-track: IPC + Automotive (da dang hoa)",
    "CEO Dr. Qiu co background manh (Broadcom, Unisoc)",
]

cons = [
    "Van dang lo lon (~RMB 1B/nam)",
    "R&D spending >200% revenue (chua sustainable)",
    "Canh tranh gay gat trong nganh",
    "Lock-up expiry co the gay ap luc gia",
    "Rui ro dia chinh tri tu US export controls",
]

# Calculate price targets
gia_ipo = 28.20
gia_hien_tai = 28.20  # Will be updated when run
upside_pct = (ket_luan["target_hkd"][0] / gia_ipo - 1) * 100
downside_pct = (ket_luan["stop_loss_hkd"] / gia_ipo - 1) * 100
risk_reward = abs(upside_pct / downside_pct)

print("=" * 70)
print("BUOC 10: KET LUAN DAU TU - AXERA (00600.HK)")
print("=" * 70)

print(f"""
+=====================================================================+
|                        IC MEMO - AXERA                              |
+=====================================================================+
|  KHUYEN NGHI       : {ket_luan['recommendation']:<45} |
|  RATING            : {'*' * ket_luan['rating']:<5} ({ket_luan['rating']}/5)                                    |
┌─────────────────────────────────────────────────────────────────────┐
|  VUNG GIA VAO      : HKD {ket_luan['entry_zone_hkd'][0]:.2f} - {ket_luan['entry_zone_hkd'][1]:.2f}                            |
|  MUC TIEU          : HKD {ket_luan['target_hkd'][0]:.2f} - {ket_luan['target_hkd'][1]:.2f}                            |
|  CAT LO            : HKD {ket_luan['stop_loss_hkd']:.2f}                                      |
|  THOI GIAN         : {ket_luan['time_horizon']:<45} |
└─────────────────────────────────────────────────────────────────────┘
|  UPSIDE POTENTIAL  : +{upside_pct:.1f}%                                        |
|  DOWNSIDE RISK     : {downside_pct:.1f}%                                         |
|  RISK/REWARD       : 1:{risk_reward:.1f}                                          |
+=====================================================================+
""")

print("DIEM MANH (PROS):")
for p in pros:
    print(f"  [+] {p}")

print("\nDIEM YEU (CONS):")
for c in cons:
    print(f"  [-] {c}")

print("\n" + "=" * 70)
print("CATALYSTS CALENDAR:")
print("-" * 70)
for cat in catalysts:
    icon = "[!]" if cat["impact"] == "Cao" else "[-]" if cat["impact"] == "Tieu cuc" else "[~]"
    print(f"  {icon} {cat['date']:<12} | {cat['event']:<25} | {cat['mo_ta']}")

print(f"""
+=====================================================================+
|  HANH DONG TIEU THEO                                                |
+=====================================================================+
|  1. DOI gia ve vung HKD 24-26 truoc khi vao lenh                   |
|  2. THEO DOI earnings Q1/2026 de xac nhan growth trajectory        |
|  3. CANH GIAC truoc Aug 2026 (cornerstone lock-up expiry)          |
|  4. SET ALERT cho muc HKD 35 (target) va HKD 20 (stop loss)        |
+=====================================================================+
""")

# %% [markdown]
# ---
#
# # 📊 PHỤ LỤC: THEO DÕI SAU IPO
#
# ## Kế hoạch theo dõi
#
# | Tần suất | Chỉ số cần theo dõi |
# |----------|--------------------|
# | **Hàng tuần** | Giá vs giá IPO, khối lượng giao dịch |
# | **Hàng tháng** | Tin tức, announcements HKEX |
# | **Hàng quý** | Báo cáo tài chính, KPIs vận hành |

# %%
# ═══════════════════════════════════════════════════════════════════════════════
# PHỤ LỤC: MẪU THEO DÕI SAU IPO
# ═══════════════════════════════════════════════════════════════════════════════

muc_gia_quan_trong = {
    "gia_ipo": 28.20,
    "ngay_1_low": 26.00,
    "all_time_high": 35.00,
    "all_time_high_ngay": "15/01/2026",
    "ho_tro_1": 26.00,
    "ho_tro_2": 28.20,
    "khang_cu_1": 35.00,
}

print("=" * 70)
print("📊 PHỤ LỤC: THEO DÕI SAU IPO")
print("=" * 70)

print(f"""
┌─────────────────────────────────────────────────────────────────────┐
│  📈 MỨC GIÁ QUAN TRỌNG (HKD)                                        │
├─────────────────────────────────────────────────────────────────────┤
│  Giá IPO           : {muc_gia_quan_trong['gia_ipo']:.2f}                                     │
│  Giá thấp nhất     : {muc_gia_quan_trong['ngay_1_low']:.2f} (Ngày 1)                              │
│  Giá cao nhất      : {muc_gia_quan_trong['all_time_high']:.2f} ({muc_gia_quan_trong['all_time_high_ngay']})                       │
│  ─────────────────────────────────────────────────────────────────  │
│  Hỗ trợ 1          : {muc_gia_quan_trong['ho_tro_1']:.2f}                                     │
│  Hỗ trợ 2          : {muc_gia_quan_trong['ho_tro_2']:.2f} (Giá IPO - quan trọng)              │
│  Kháng cự 1        : {muc_gia_quan_trong['khang_cu_1']:.2f} (ATH)                                │
└─────────────────────────────────────────────────────────────────────┘
""")

# Mẫu theo dõi hàng tuần
print("\n📋 Mẫu theo dõi hàng tuần (điền khi update):")
print("-" * 70)
theo_doi = pd.DataFrame(columns=[
    "Tuần",
    "Giá đóng cửa",
    "% vs IPO",
    "Khối lượng TB",
    "Tin tức",
    "Ghi chú"
])
display(theo_doi)

# %% [markdown]
# ---
#
# ## 📈 Dữ liệu giá & khối lượng giao dịch (Live từ Yahoo Finance)
#
# ### Mục đích
# - Tự động lấy dữ liệu giá cổ phiếu từ Yahoo Finance
# - Hiển thị biểu đồ giá và khối lượng giao dịch
# - Theo dõi performance so với giá IPO
#
# ### Cách sử dụng
# 1. Chạy cell bên dưới để cài đặt thư viện `yfinance`
# 2. Dữ liệu sẽ tự động cập nhật mỗi lần chạy
# 3. Có thể thay đổi `MA_CK` để theo dõi cổ phiếu khác
#
# > ⚠️ **Lưu ý**: Cần kết nối internet để lấy dữ liệu

# %%
# ═══════════════════════════════════════════════════════════════════════════════
# PHỤ LỤC: THEO DÕI GIÁ TỪ YAHOO FINANCE - AXERA
# ═══════════════════════════════════════════════════════════════════════════════

try:
    import yfinance as yf
except ImportError as e:
    raise ImportError("Thieu thu vien yfinance. Cai bang: pip install yfinance") from e


import matplotlib.pyplot as plt
import pandas as pd
from datetime import datetime

# Thông tin cơ bản
MA_CK = "0600.HK"
GIA_IPO = 28.20
NGAY_IPO = "2026-02-10"

print("=" * 70)
print(f"LAY DU LIEU GIA: {MA_CK}")
print("=" * 70)

# Fetch data
ticker = yf.Ticker(MA_CK)
du_lieu = ticker.history(start=NGAY_IPO)

if len(du_lieu) > 0:
    # Calculate statistics
    gia_hien_tai = du_lieu['Close'].iloc[-1]
    gia_cao_nhat = du_lieu['High'].max()
    gia_thap_nhat = du_lieu['Low'].min()
    vol_trung_binh = du_lieu['Volume'].mean()

    pct_vs_ipo = (gia_hien_tai - GIA_IPO) / GIA_IPO * 100
    pct_vs_high = (gia_hien_tai - gia_cao_nhat) / gia_cao_nhat * 100

    emoji_ipo = "(+)" if pct_vs_ipo >= 0 else "(-)"
    dau_ipo = "+" if pct_vs_ipo >= 0 else ""

    print(f"""
┌─────────────────────────────────────────────────────────────────────┐
|  THONG KE GIA TU IPO ({NGAY_IPO})                                   |
└─────────────────────────────────────────────────────────────────────┘
|  Gia hien tai    : HKD {gia_hien_tai:.2f}                               |
|  Gia IPO         : HKD {GIA_IPO:.2f}                                     |
|  % vs IPO        : {dau_ipo}{pct_vs_ipo:.1f}% {emoji_ipo}                               |
└─────────────────────────────────────────────────────────────────────┘
|  Gia cao nhat    : HKD {gia_cao_nhat:.2f}                               |
|  Gia thap nhat   : HKD {gia_thap_nhat:.2f}                               |
|  % vs High       : {pct_vs_high:.1f}%                                      |
|  Vol trung binh  : {vol_trung_binh:,.0f}                             |
└─────────────────────────────────────────────────────────────────────┘
    """)
else:
    print("Khong lay duoc du lieu. Co the chua co giao dich hoac ticker sai.")
    print(f"Ticker: {MA_CK}")

# %%
# ═══════════════════════════════════════════════════════════════════════════════
# 📊 HIỂN THỊ THỐNG KÊ GIÁ
# ═══════════════════════════════════════════════════════════════════════════════

if du_lieu is not None and not du_lieu.empty:
    # Tính toán các chỉ số
    gia_hien_tai = du_lieu['Close'].iloc[-1]
    gia_cao_nhat = du_lieu['High'].max()
    gia_thap_nhat = du_lieu['Low'].min()
    gia_trung_binh = du_lieu['Close'].mean()
    kl_trung_binh = du_lieu['Volume'].mean()
    kl_hom_nay = du_lieu['Volume'].iloc[-1]
    
    # % thay đổi so với IPO
    pct_vs_ipo = (gia_hien_tai - GIA_IPO) / GIA_IPO * 100
    pct_vs_high = (gia_hien_tai - gia_cao_nhat) / gia_cao_nhat * 100
    
    # Xác định emoji và dấu
    emoji_ipo = '🟢' if pct_vs_ipo >= 0 else '🔴'
    dau_ipo = '+' if pct_vs_ipo >= 0 else ''
    
    print("=" * 70)
    print(f"📊 THỐNG KÊ GIÁ: {MA_CK}")
    print("=" * 70)
    print(f"""
┌─────────────────────────────────────────────────────────────────────┐
│  💰 GIÁ HIỆN TẠI                                                    │
├─────────────────────────────────────────────────────────────────────┤
│  Giá đóng cửa gần nhất : HKD {gia_hien_tai:,.2f}                          │
│  So với giá IPO        : {dau_ipo}{pct_vs_ipo:,.1f}% {emoji_ipo}                              │
│  So với đỉnh           : {pct_vs_high:,.1f}%                                │
├─────────────────────────────────────────────────────────────────────┤
│  📈 RANGE TỪ IPO                                                    │
├─────────────────────────────────────────────────────────────────────┤
│  Giá IPO               : HKD {GIA_IPO:,.2f}                               │
│  Giá cao nhất          : HKD {gia_cao_nhat:,.2f}                              │
│  Giá thấp nhất         : HKD {gia_thap_nhat:,.2f}                              │
│  Giá trung bình        : HKD {gia_trung_binh:,.2f}                              │
├─────────────────────────────────────────────────────────────────────┤
│  📊 KHỐI LƯỢNG                                                      │
├─────────────────────────────────────────────────────────────────────┤
│  KL giao dịch TB/ngày  : {kl_trung_binh:,.0f} cổ phiếu                  │
│  KL hôm gần nhất       : {kl_hom_nay:,.0f} cổ phiếu                  │
└─────────────────────────────────────────────────────────────────────┘
    """)
    
    # Bảng 10 ngày gần nhất
    print("\n📋 10 ngày giao dịch gần nhất:")
    print("-" * 70)
    
    bang_10_ngay = du_lieu.tail(10)[['Open', 'High', 'Low', 'Close', 'Volume']].copy()
    bang_10_ngay.index = bang_10_ngay.index.strftime('%Y-%m-%d')
    bang_10_ngay.columns = ['Mở cửa', 'Cao nhất', 'Thấp nhất', 'Đóng cửa', 'Khối lượng']
    bang_10_ngay['% vs IPO'] = ((bang_10_ngay['Đóng cửa'] - GIA_IPO) / GIA_IPO * 100).round(1)
    
    display(bang_10_ngay.style.format({
        'Mở cửa': '{:.2f}',
        'Cao nhất': '{:.2f}',
        'Thấp nhất': '{:.2f}',
        'Đóng cửa': '{:.2f}',
        'Khối lượng': '{:,.0f}',
        '% vs IPO': '{:+.1f}%'
    }))

# %%
# ═══════════════════════════════════════════════════════════════════════════════
# BIEU DO GIA & VOLUME - AXERA
# ═══════════════════════════════════════════════════════════════════════════════

if len(du_lieu) > 0:
    fig, axes = plt.subplots(2, 1, figsize=(14, 8), gridspec_kw={'height_ratios': [3, 1]})

    # Price chart
    axes[0].plot(du_lieu.index, du_lieu['Close'], color='#4472C4', linewidth=1.5, label='Close Price')
    axes[0].axhline(y=GIA_IPO, color='green', linestyle='--', linewidth=1.5, label=f'IPO Price: HKD {GIA_IPO}')
    axes[0].fill_between(du_lieu.index, du_lieu['Low'], du_lieu['High'], alpha=0.2, color='#4472C4')
    axes[0].set_title(f'AXERA (0600.HK) - Price since IPO', fontsize=14, fontweight='bold')
    axes[0].set_ylabel('Price (HKD)')
    axes[0].legend(loc='upper left')
    axes[0].grid(True, alpha=0.3)

    # Volume chart
    colors = ['#C00000' if du_lieu['Close'].iloc[i] < du_lieu['Open'].iloc[i] else '#70AD47'
              for i in range(len(du_lieu))]
    axes[1].bar(du_lieu.index, du_lieu['Volume'], color=colors, alpha=0.7)
    axes[1].axhline(y=du_lieu['Volume'].mean(), color='orange', linestyle='--', label='Avg Volume')
    axes[1].set_ylabel('Volume')
    axes[1].set_xlabel('Date')
    axes[1].legend(loc='upper left')
    axes[1].grid(True, alpha=0.3)

    plt.tight_layout()
    plt.show()

    print(f"""
┌─────────────────────────────────────────────────────────────────────┐
|  NHAN DINH KY THUAT                                                 |
└─────────────────────────────────────────────────────────────────────┘
|  - Muc ho tro gan: HKD 26.00 (gan IPO price)                       |
|  - Muc khang cu: HKD {gia_cao_nhat:.2f} (ATH)                               |
|  - Theo doi volume khi can muc khang cu                            |
└─────────────────────────────────────────────────────────────────────┘
    """)
else:
    print("Khong co du lieu de ve bieu do.")

# %% [markdown]
# ---
#
# # 📚 HƯỚNG DẪN SỬ DỤNG TEMPLATE CHO IPO KHÁC
#
# ## Quy trình 5 bước
#
# ```
# ┌─────────────────────────────────────────────────────────────────────────────┐
# │  BƯỚC 1: CHUẨN BỊ                                                           │
# │  • Download prospectus từ HKEX/SGX/SSE                                      │
# │  • Duplicate notebook này, đổi tên theo công ty mới                         │
# │  • Update cell "cong_ty" với thông tin mới                                  │
# ├─────────────────────────────────────────────────────────────────────────────┤
# │  BƯỚC 2: TRÍCH XUẤT DỮ LIỆU                                                 │
# │  • Tìm "Financial Information" trong prospectus                             │
# │  • Copy doanh thu, lợi nhuận vào cell "tai_chinh"                           │
# │  • Tìm "Cornerstone Investors", update cell tương ứng                       │
# ├─────────────────────────────────────────────────────────────────────────────┤
# │  BƯỚC 3: NGHIÊN CỨU BỔ SUNG                                                 │
# │  • Search Crunchbase/PitchBook cho funding history                          │
# │  • Search tin tức cho analyst reports                                       │
# │  • Check Yahoo Finance cho giá hiện tại                                     │
# ├─────────────────────────────────────────────────────────────────────────────┤
# │  BƯỚC 4: CHẠY PHÂN TÍCH                                                     │
# │  • Run All cells                                                            │
# │  • Review output từng section                                               │
# │  • Điền đánh giá (🟢/🟡/🔴)                                                  │
# ├─────────────────────────────────────────────────────────────────────────────┤
# │  BƯỚC 5: RA QUYẾT ĐỊNH                                                      │
# │  • Hoàn thành phần Kết luận với thesis, risks                               │
# │  • Quyết định: MUA / THEO DÕI / TRÁNH                                       │
# │  • Đặt alerts và calendar reminders                                         │
# └─────────────────────────────────────────────────────────────────────────────┘
# ```
#
# ---
#
# ## 🔗 Nguồn dữ liệu (có link)
#
# ### Prospectus & Filings chính thức
#
# | Sàn | Link | Mô tả |
# |-----|------|-------|
# | **HKEX** | [HKEXnews Title Search](https://www1.hkexnews.hk/search/titlesearch.xhtml) | Tìm prospectus, announcements, circulars |
# | **HKEX** | [New Listings](https://www.hkex.com.hk/Market-Data/Securities-Prices/Equities?sc_lang=en) | Danh sách công ty mới niêm yết |
# | **SGX** | [SGX Rulebook](https://rulebook.sgx.com/rulebook/mainboard-rules) | Quy định niêm yết Singapore |
# | **SSE** | [STAR Market Rules](https://english.sse.com.cn/start/sserules/stocks/listing/) | Quy định sàn STAR Shanghai |
#
# ### Dữ liệu tài chính & giá
#
# | Nguồn | Link | Loại |
# |-------|------|------|
# | **Yahoo Finance** | [finance.yahoo.com](https://finance.yahoo.com) | Miễn phí - Giá, charts, financials |
# | **Google Finance** | [google.com/finance](https://www.google.com/finance) | Miễn phí - Giá, tin tức |
# | **TradingView** | [tradingview.com](https://www.tradingview.com) | Miễn phí/Trả phí - Charts, technical |
# | **Investing.com** | [investing.com](https://www.investing.com) | Miễn phí - Data đa dạng |
# | **Bloomberg** | [bloomberg.com](https://www.bloomberg.com) | Tin tức, data premium |
#
# ### Funding History & Startup Data
#
# | Nguồn | Link | Loại |
# |-------|------|------|
# | **Crunchbase** | [crunchbase.com](https://www.crunchbase.com) | Miễn phí (giới hạn) - Funding rounds |
# | **PitchBook** | [pitchbook.com](https://pitchbook.com) | Trả phí - Chi tiết đầy đủ |
# | **CB Insights** | [cbinsights.com](https://www.cbinsights.com) | Trả phí - Phân tích startup |
# | **IT桔子** | [itjuzi.com](https://www.itjuzi.com) | China startup database |
#
# ### Tin tức & Nghiên cứu
#
# | Nguồn | Link | Focus |
# |-------|------|-------|
# | **Reuters** | [reuters.com](https://www.reuters.com) | Tin tức tài chính global |
# | **SCMP** | [scmp.com](https://www.scmp.com) | Tin tức Hong Kong, China |
# | **36Kr** | [36kr.com](https://36kr.com) | Startup & Tech China |
# | **EqualOcean** | [equalocean.com](https://equalocean.com) | China tech analysis |
# | **Caixin** | [caixinglobal.com](https://www.caixinglobal.com) | China business news |
#
# ---
#
# ## 📖 Tài liệu tham khảo & Học thêm
#
# ### IPO Analysis Framework
#
# | Tài liệu | Link | Tác giả/Nguồn |
# |----------|------|---------------|
# | **IPO Lessons for Investors** | [Damodaran Blog](https://aswathdamodaran.blogspot.com/2019/10/ipo-lessons-for-public-market-investors.html) | Aswath Damodaran (NYU) |
# | **EY Global IPO Trends** | [EY IPO Report](https://www.ey.com/en_us/insights/ipo/trends) | Ernst & Young |
# | **HKEX Listing Rules** | [HKEX Rules](https://en-rules.hkex.com.hk/rulebook/main-board-listing-rules) | HKEX Official |
# | **How to Read a Prospectus** | [SEC Guide](https://www.sec.gov/oiea/investor-alerts-bulletins/ib_prospectus.html) | US SEC |
#
# ### Valuation & Financial Analysis
#
# | Tài liệu | Link | Mô tả |
# |----------|------|-------|
# | **Damodaran Online** | [Damodaran Data](http://pages.stern.nyu.edu/~adamodar/) | Datasets, spreadsheets, lectures miễn phí |
# | **Multiples.app** | [multiples.app](https://www.multiples.app) | SaaS & Tech valuation multiples |
# | **FinBox** | [finbox.com](https://finbox.com) | DCF templates, fair value |
# | **Simply Wall St** | [simplywall.st](https://simplywall.st) | Visual stock analysis |
#
# ### Edge AI Chips Industry (AXERA)
#
# | Tài liệu | Link | Mô tả |
# |----------|------|-------|
# | **Nvidia IR** | [NVDA Investors](https://investor.nvidia.com) | Global AI chip leader |
# | **Grand View Research** | [Edge AI Market](https://www.grandviewresearch.com) | Market size reports |
# | **CNX Software** | [cnx-software.com](https://www.cnx-software.com) | Tin tuc edge AI hardware |
#
# ### AI & Chips Industry (Biren, Zhipu, Axera)
#
# | Tài liệu | Link | Mô tả |
# |----------|------|-------|
# | **SemiAnalysis** | [semianalysis.com](https://www.semianalysis.com) | Chip industry deep-dives |
# | **The Information** | [theinformation.com](https://www.theinformation.com) | Tech scoops (trả phí) |
# | **Import AI Newsletter** | [importai.net](https://importai.net) | AI research weekly |
# | **ChinAI Newsletter** | [chinai.substack.com](https://chinai.substack.com) | China AI translations |
#
# ---
#
# ## 🔖 Quick Links to Follow
#
# ### Twitter/X Accounts
#
# | Account | Handle | Focus |
# |---------|--------|-------|
# | IPO News | [@IPOborhood](https://twitter.com/IPOborhood) | IPO announcements |
# | Tech Scoops | [@EricNewcomer](https://twitter.com/EricNewcomer) | VC & Tech IPOs |
# | China Tech | [@ChinaTechBlog](https://twitter.com/ChinaTechBlog) | China tech news |
# | Semiconductors | [@SemiAnalysis_](https://twitter.com/SemiAnalysis_) | Chip industry |
#
# ### Newsletters đáng theo dõi
#
# | Newsletter | Link | Tần suất |
# |------------|------|----------|
# | **The Generalist** | [readthegeneralist.com](https://www.readthegeneralist.com) | Weekly deep-dives |
# | **Emerging Tech Brew** | [morningbrew.com/emerging-tech](https://www.morningbrew.com/emerging-tech) | Daily |
# | **Not Boring** | [notboring.co](https://www.notboring.co) | Weekly strategy |
# | **Interconnected** | [interconnected.blog](https://interconnected.blog) | China-US tech |
#
# ### Podcasts
#
# | Podcast | Link | Focus |
# |---------|------|-------|
# | **Acquired** | [acquired.fm](https://www.acquired.fm) | Company deep-dives |
# | **Invest Like the Best** | [joincolossus.com](https://www.joincolossus.com/episodes) | Investor interviews |
# | **China Talk** | [chinatalk.substack.com](https://chinatalk.substack.com) | China tech policy |
#
# ---
#
# ## ⚠️ Tuyên bố miễn trừ trách nhiệm
#
# > **QUAN TRỌNG**: Báo cáo này chỉ mang tính chất **nghiên cứu và giáo dục**.
# > Đây **KHÔNG PHẢI** lời khuyên đầu tư. Mọi quyết định đầu tư cần dựa trên
# > nghiên cứu của riêng bạn và tư vấn từ chuyên gia tài chính được cấp phép.
# >
# > Tác giả không chịu trách nhiệm cho bất kỳ tổn thất nào từ việc sử dụng
# > thông tin trong báo cáo này.
#
# ---
#
# **KẾT THÚC BÁO CÁO**
#
# *Template version: 4.0 | Cập nhật: 20/02/2026*
