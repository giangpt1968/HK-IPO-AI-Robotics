# %% [markdown]
# # 📊 BÁO CÁO PHÂN TÍCH IPO
# ## Mẫu chuẩn cho cổ phiếu AI & Robotics (HK / SG / Shanghai)
# ### Case Study: **ZHIPU-B (2513.HK)**
#
# ---
#
# | Thông tin | Chi tiết |
# |-----------|----------|
# | **Loại báo cáo** | Phân tích IPO cơ bản |
# | **Công ty** | Zhipu AI Co., Ltd. |
# | **Mã CK** | 2513.HK (HKEX) |
# | **Ngành** | Thiết bị y tế / Robot phẫu thuật |
# | **Ngày IPO** | 08/01/2026 |
# | **Ngày báo cáo** | 20/02/2026 |
# | **Phiên bản** | 4.0 |
#
# ---
#
# ### 📚 Tài liệu gốc
#
# | Nguồn | Link | Mục đích |
# |-------|------|----------|
# | **Bản cáo bạch (Prospectus)** | [HKEX](https://www1.hkexnews.hk/listedco/listconews/sehk/2025/1230/2025123000029.pdf) | Tài liệu pháp lý chính thức |
# | **Kết quả phân bổ** | [HKEX](https://www1.hkexnews.hk/listedco/listconews/sehk/2026/0204/2026020402144.pdf) | Over-subscription, allocation |
# | **Thông báo giao dịch** | [HKEX](https://www.hkex.com.hk/eng/market/sec_tradinfo/tradarng/tradarng_news/premonth/e2675a_260105.htm) | Ngày giao dịch, lot size |
#
# > ⚠️ **Lưu ý**: Luôn verify thông tin từ prospectus gốc, không chỉ dựa vào tin tức.

# %% [markdown]
# ---
#
# # 📋 PHẦN 0: TÓM TẮT ĐIỀU HÀNH (Executive Summary)
#
# **Dành cho người bận rộn** - Đọc phần này trước để nắm bắt nhanh, sau đó đọc chi tiết nếu quan tâm.
#
# ---
#
# ## 🎯 Tổng quan nhanh
#
# | Hạng mục | Đánh giá | Chi tiết |
# |----------|----------|----------|
# | **Công ty** | ZHIPU-B (2513.HK) | Robot phẫu thuật nội soi, Trung Quốc |
# | **Thesis** | 🟢 Tích cực | Thay thế da Vinci tại thị trường nội địa TQ |
# | **Tài chính** | 🟢 Tăng trưởng mạnh | Revenue +233% YoY, Gross margin 63% |
# | **Định giá** | 🟡 Hợp lý | EV/Sales ~10-15x, premium vs peers |
# | **Rủi ro** | 🟡 Trung bình | Vẫn lỗ, lock-up tháng 7/2026 |
# | **Quyết định** | 📊 THEO DÕI | Chờ mua vùng HKD 50-55 |
#
# ---
#
# ## 💡 3 điểm chính cần nhớ
#
# 1. **Thesis**: ZHIPU-B là công ty robot phẫu thuật hàng đầu Trung Quốc, hưởng lợi từ xu hướng "nội địa hóa" thiết bị y tế
#
# 2. **Tín hiệu tốt**: Cornerstone investors chất lượng cao (Tencent, ADIA), revenue tăng 3x, gross margin tương đương Intuitive Surgical
#
# 3. **Rủi ro chính**: Vẫn đang lỗ (cần theo dõi cash runway), lock-up expiry tháng 7/2026 có thể tạo áp lực bán
#
# ---
#
# ## 📅 Các mốc thời gian quan trọng
#
# | Ngày | Sự kiện | Tác động |
# |------|---------|----------|
# | 08/07/2026 | Lock-up 6 tháng hết hạn | ⚠️ Áp lực bán, có thể mua được giá tốt |
# | T8-9/2026 | Báo cáo tài chính 1H2026 | Kiểm chứng thesis tăng trưởng |
# | 08/01/2027 | Lock-up 12 tháng hết hạn | ⚠️ Đợt unlock thứ hai |

# %% [markdown]
# ---
#
# # 📖 PHẦN 1: PHƯƠNG PHÁP PHÂN TÍCH
#
# ## Tại sao cần phân tích IPO có hệ thống?
#
# | Vấn đề thường gặp | Giải pháp |
# |-------------------|----------|
# | Thông tin quá nhiều, không biết bắt đầu từ đâu | Framework 10 bước có cấu trúc |
# | Không biết giá IPO có hợp lý không | So sánh với công ty cùng ngành (peers) |
# | Không biết rủi ro ở đâu | Checklist rủi ro theo từng khía cạnh |
# | Mua vào lúc nào? | Trading signals & lịch sự kiện |
#
# ---
#
# ## 🔄 Framework 10 bước
#
# ```
# ┌─────────────────────────────────────────────────────────────────┐
# │  BƯỚC 1: THÔNG TIN CÔNG TY                                      │
# │  → Công ty làm gì? Thành lập năm nào? Niêm yết ở đâu?          │
# ├─────────────────────────────────────────────────────────────────┤
# │  BƯỚC 2: LỊCH SỬ GỌI VỐN                                        │
# │  → Series A, B, C... Ai đã đầu tư? Định giá tăng ra sao?       │
# ├─────────────────────────────────────────────────────────────────┤
# │  BƯỚC 3: PHÂN TÍCH TÀI CHÍNH                                    │
# │  → Doanh thu, lợi nhuận, biên lợi nhuận, tăng trưởng           │
# ├─────────────────────────────────────────────────────────────────┤
# │  BƯỚC 4: ĐIỀU KHOẢN IPO                                         │
# │  → Giá IPO, số tiền huy động, sử dụng vốn vào việc gì?         │
# ├─────────────────────────────────────────────────────────────────┤
# │  BƯỚC 5: CORNERSTONE & LOCK-UP                                  │
# │  → Ai mua trước IPO? Khi nào họ được bán?                      │
# ├─────────────────────────────────────────────────────────────────┤
# │  BƯỚC 6: SẢN PHẨM & LỢI THẾ CẠNH TRANH                          │
# │  → Sản phẩm gì? Moat (lợi thế bền vững) ở đâu?                 │
# ├─────────────────────────────────────────────────────────────────┤
# │  BƯỚC 7: CHỈ SỐ NGÀNH                                           │
# │  → KPIs đặc thù của ngành (robot, AI chip, LLM...)             │
# ├─────────────────────────────────────────────────────────────────┤
# │  BƯỚC 8: SO SÁNH & ĐỊNH GIÁ                                     │
# │  → So với peers, định giá có hợp lý không?                     │
# ├─────────────────────────────────────────────────────────────────┤
# │  BƯỚC 9: ĐÁNH GIÁ RỦI RO                                        │
# │  → Quản trị, địa chính trị, tài chính, vận hành                │
# ├─────────────────────────────────────────────────────────────────┤
# │  BƯỚC 10: KẾT LUẬN ĐẦU TƯ                                       │
# │  → MUA / THEO DÕI / TRÁNH? Entry, target, stop-loss?           │
# └─────────────────────────────────────────────────────────────────┘
# ```
#
# ---
#
# ## 📚 Thuật ngữ cần biết
#
# | Thuật ngữ | Giải thích | Ví dụ |
# |-----------|------------|-------|
# | **Giá IPO** | Giá cổ phiếu khi phát hành lần đầu | HKD 43.24 |
# | **Vốn hóa (Market Cap)** | Tổng giá trị = Số cổ phiếu × Giá | HKD 16.77 tỷ |
# | **Gross Margin** | (Doanh thu - Giá vốn) / Doanh thu | 63% = lãi 63đ trên 100đ bán |
# | **EV/Sales** | Giá trị doanh nghiệp / Doanh thu | Dùng khi công ty chưa có lãi |
# | **Lock-up** | Thời gian cổ đông lớn không được bán | 6-12 tháng |
# | **Cornerstone** | Nhà đầu tư lớn cam kết mua trước IPO | Tencent, ADIA |
# | **Moat** | Lợi thế cạnh tranh bền vững | Patent, brand, network effect |
# | **Cash Runway** | Với tốc độ đốt tiền hiện tại, còn bao lâu hết? | 24 tháng |
#
# ---
#
# ## 🚦 Hệ thống đánh giá màu
#
# | Màu | Ý nghĩa | Ví dụ |
# |-----|---------|-------|
# | 🟢 **Xanh** | Tích cực, bullish | Revenue +100% YoY |
# | 🟡 **Vàng** | Trung lập, cần theo dõi | Margin ổn định |
# | 🔴 **Đỏ** | Cảnh báo, rủi ro cao | Cash runway <12 tháng |

# %% [markdown]
# ---
#
# # ⚙️ THIẾT LẬP MÔI TRƯỜNG
#
# Import các thư viện Python cần thiết:
# - **pandas**: Xử lý dữ liệu dạng bảng
# - **numpy**: Tính toán số học
# - **matplotlib**: Vẽ biểu đồ
#
# > 💡 Trên Google Colab, các thư viện này đã được cài sẵn.

# %%
# ═══════════════════════════════════════════════════════════════════════════════
# THIẾT LẬP MÔI TRƯỜNG
# ═══════════════════════════════════════════════════════════════════════════════

import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Cấu hình hiển thị
pd.set_option("display.max_columns", 200)
pd.set_option("display.width", 160)

# Matplotlib tiếng Việt (nếu cần)
plt.rcParams['font.family'] = 'DejaVu Sans'

print("✅ Đã import thành công các thư viện cần thiết!")
# Out:
# ✅ Đã import thành công các thư viện cần thiết!

# %% [markdown]
# ---
#
# # 📋 BƯỚC 1: THÔNG TIN CÔNG TY
#
# ## Mục đích
# Hiểu công ty làm gì trước khi đi vào số liệu.
#
# ## Câu hỏi cần trả lời
# | Câu hỏi | Tại sao quan trọng? |
# |---------|--------------------|
# | Công ty làm gì? | Hiểu mô hình kinh doanh |
# | Thành lập năm nào? | Đánh giá độ trưởng thành |
# | Niêm yết ở đâu? | HKEX, SGX, SSE có quy định khác nhau |
# | Giá IPO bao nhiêu? | Điểm tham chiếu cho phân tích |

# %%
# ═══════════════════════════════════════════════════════════════════════════════
# BƯỚC 1: THÔNG TIN CÔNG TY - ZHIPU-B
# ═══════════════════════════════════════════════════════════════════════════════
# 
# Dictionary chứa metadata của công ty.
# Khi phân tích IPO mới, thay đổi các giá trị trong dictionary này.
#
# ═══════════════════════════════════════════════════════════════════════════════

cong_ty = {
    # --- Thông tin định danh ---
    "ten_day_du": "Zhipu AI Co., Ltd.",
    "ten_giao_dich": "ZHIPU-B",
    "ma_ck": "2513.HK",
    "san_niem_yet": "HKEX (Hồng Kông)",
    
    # --- Thông tin ngành & lịch sử ---
    "nganh": "Thiết bị y tế / Robot phẫu thuật",
    "nam_thanh_lap": 2017,
    "ngay_niem_yet": "2026-01-08",
    
    # --- Thông tin giao dịch ---
    "lo_giao_dich": 100,  # Số cổ phiếu tối thiểu mỗi lệnh
    "gia_ipo_hkd": 43.24,
    "don_vi_bao_cao": "RMB",  # Đơn vị tiền trong báo cáo tài chính
    
    # --- Links ---
    "link_prospectus": "https://www1.hkexnews.hk/listedco/listconews/sehk/2025/1230/2025123000029.pdf",
}

# ═══════════════════════════════════════════════════════════════════════════════
# HIỂN THỊ
# ═══════════════════════════════════════════════════════════════════════════════

print("=" * 70)
print("📋 BƯỚC 1: THÔNG TIN CÔNG TY")
print("=" * 70)
print(f"""
┌─────────────────────────────────────────────────────────────────────┐
│  Tên công ty      : {cong_ty['ten_day_du']:<45} │
│  Mã chứng khoán   : {cong_ty['ma_ck']:<45} │
│  Sàn niêm yết     : {cong_ty['san_niem_yet']:<45} │
│  Ngành            : {cong_ty['nganh']:<45} │
│  Năm thành lập    : {cong_ty['nam_thanh_lap']} ({2026 - cong_ty['nam_thanh_lap']} năm đến IPO){' '*26} │
│  Ngày niêm yết    : {cong_ty['ngay_niem_yet']:<45} │
│  Giá IPO          : HKD {cong_ty['gia_ipo_hkd']:<42} │
│  Lô giao dịch     : {cong_ty['lo_giao_dich']} cổ phiếu{' '*35} │
└─────────────────────────────────────────────────────────────────────┘
""")

print("\n🔍 ĐÁNH GIÁ SƠ BỘ:")
print("""
🟢 TÍCH CỰC:
   • Ngành robot phẫu thuật đang tăng trưởng mạnh tại Trung Quốc
   • 9 năm hoạt động trước IPO - đủ mature
   • Niêm yết HKEX Main Board - tiêu chuẩn cao
""")
# Out:
# ...
# 📋 BƯỚC 1: THÔNG TIN CÔNG TY
# ...
#
# ┌─────────────────────────────────────────────────────────────────────┐
# │  Tên công ty      : Zhipu AI Co., Ltd.               │
# │  Mã chứng khoán   : 2513.HK                                      │
# │  Sàn niêm yết     : HKEX (Hồng Kông)                              │
# │  Ngành            : Thiết bị y tế / Robot phẫu thuật              │
# │  Năm thành lập    : 2017 (9 năm đến IPO)                           │
# │  Ngày niêm yết    : 2026-01-08                                    │
# │  Giá IPO          : HKD 43.24                                      │
# │  Lô giao dịch     : 100 cổ phiếu                                    │
# └─────────────────────────────────────────────────────────────────────┘
#
#
# 🔍 ĐÁNH GIÁ SƠ BỘ:
#
# 🟢 TÍCH CỰC:
#    • Ngành robot phẫu thuật đang tăng trưởng mạnh tại Trung Quốc
#    • 9 năm hoạt động trước IPO - đủ mature
#    • Niêm yết HKEX Main Board - tiêu chuẩn cao

# %% [markdown]
# ---
#
# # 💰 BƯỚC 2: LỊCH SỬ GỌI VỐN
#
# ## Tại sao quan trọng?
#
# Lịch sử funding cho biết:
# 1. **Ai đã tin tưởng công ty?** - Quỹ VC/PE uy tín = tín hiệu tốt
# 2. **Định giá tăng như thế nào?** - Từ Series A đến IPO
# 3. **IPO có phải "down round"?** - Giá IPO < round trước = cảnh báo
# 4. **Tổng vốn đã huy động** - Công ty đã dùng bao nhiêu tiền?
#
# ## Các vòng gọi vốn
#
# ```
# Series A → Series B → Series C → ... → IPO
#    ↑           ↑           ↑           ↑
#  Giai đoạn  Tăng       Pre-IPO     Thị trường
#  đầu       trưởng                  công khai
# ```

# %%
# ═══════════════════════════════════════════════════════════════════════════════
# BƯỚC 2: LỊCH SỬ GỌI VỐN - ZHIPU-B
# ═══════════════════════════════════════════════════════════════════════════════
# 
# Nguồn: Crunchbase, PitchBook, Prospectus
#
# ═══════════════════════════════════════════════════════════════════════════════

lich_su_goi_von = pd.DataFrame([
    {
        "vong": "Series A", 
        "thoi_gian": "2018", 
        "so_tien_trieu_usd": 15.0, 
        "nha_dau_tu_chinh": "LYFE Capital, Legend Star"
    },
    {
        "vong": "Series B", 
        "thoi_gian": "06/2020", 
        "so_tien_trieu_usd": 92.0, 
        "nha_dau_tu_chinh": "Boyu Capital, LYFE Capital"
    },
    {
        "vong": "Series C", 
        "thoi_gian": "11/2021", 
        "so_tien_trieu_usd": 200.0, 
        "nha_dau_tu_chinh": "Boyu Capital, China SOE Fund, Firstred Capital"
    },
    {
        "vong": "IPO", 
        "thoi_gian": "01/2026", 
        "so_tien_trieu_usd": 154.0,
        "nha_dau_tu_chinh": "Thị trường công khai (HKEX)"
    },
])

# Tính toán
tong_truoc_ipo = lich_su_goi_von[lich_su_goi_von["vong"] != "IPO"]["so_tien_trieu_usd"].sum()

# ═══════════════════════════════════════════════════════════════════════════════
# HIỂN THỊ
# ═══════════════════════════════════════════════════════════════════════════════

print("=" * 70)
print("💰 BƯỚC 2: LỊCH SỬ GỌI VỐN")
print("=" * 70)
print(f"""
┌─────────────────────────────────────────────────────────────────────┐
│  📈 TÓM TẮT                                                         │
├─────────────────────────────────────────────────────────────────────┤
│  Tổng vốn trước IPO  : ${tong_truoc_ipo:,.0f} triệu USD                       │
│  Vốn huy động IPO    : $154 triệu USD                               │
│  Vốn hóa tại IPO     : ~$2.15 tỷ USD (HKD 16.77 tỷ)                 │
│  Thời gian từ A→IPO  : ~8 năm (2018 → 2026)                         │
└─────────────────────────────────────────────────────────────────────┘
""")

print("\n📋 Chi tiết các vòng gọi vốn:")
print("-" * 70)
display(lich_su_goi_von)

print("\n🔍 ĐÁNH GIÁ:")
print("""
🟢 TÍCH CỰC:
   • Boyu Capital (top PE Trung Quốc) tham gia từ Series B
   • LYFE Capital (chuyên healthcare) đồng hành từ đầu
   • China SOE Fund (quỹ nhà nước) tham gia Series C
   • Định giá IPO > Series C → Không phải down round

🟡 CẦN THEO DÕI:
   • Định giá các vòng trước không công khai chi tiết
""")
# Out:
# ...
# 💰 BƯỚC 2: LỊCH SỬ GỌI VỐN
# ...
#
# ┌─────────────────────────────────────────────────────────────────────┐
# │  📈 TÓM TẮT                                                         │
# ├─────────────────────────────────────────────────────────────────────┤
# │  Tổng vốn trước IPO  : $307 triệu USD                       │
# │  Vốn huy động IPO    : $154 triệu USD                               │
# │  Vốn hóa tại IPO     : ~$2.15 tỷ USD (HKD 16.77 tỷ)                 │
# │  Thời gian từ A→IPO  : ~8 năm (2018 → 2026)                         │
# └─────────────────────────────────────────────────────────────────────┘
#
#
# 📋 Chi tiết các vòng gọi vốn:
# ----------------------------------------------------------------------
#        vong thoi_gian  so_tien_trieu_usd                                nha_dau_tu_chinh
# 0  Series A      2018               15.0                       LYFE Capital, Legend Star
# 1  Series B   06/2020               92.0                      Boyu Capital, LYFE Capital
# ...

# %% [markdown]
# ---
#
# # 📊 BƯỚC 3: PHÂN TÍCH TÀI CHÍNH
#
# ## Tại sao đây là phần quan trọng nhất?
#
# | Chỉ số | Công thức | Ý nghĩa |
# |--------|-----------|--------|
# | **Doanh thu (Revenue)** | Tiền bán hàng | Công ty bán được bao nhiêu? |
# | **Lợi nhuận gộp (Gross Profit)** | Doanh thu - Giá vốn | Lãi sau chi phí sản xuất |
# | **Biên lợi nhuận gộp (Gross Margin)** | Lợi nhuận gộp / Doanh thu | Cao = pricing power tốt |
# | **Lợi nhuận ròng (Net Income)** | Lãi sau tất cả chi phí | Tiền thực sự còn lại |
#
# ## Đặc thù công ty "đang lỗ"
#
# ```
# Công ty trưởng thành              vs              Startup/Growth
# ───────────────────                               ──────────────────
# Revenue: Ổn định                                  Revenue: Tăng nhanh
# Net Income: Có lãi                                Net Income: Thường lỗ
# Đánh giá: P/E ratio                               Đánh giá: EV/Sales
# Câu hỏi: Lãi có bền vững?                         Câu hỏi: Khi nào hòa vốn?
# ```
#
# > ⚠️ **ZHIPU-B đang lỗ** - Đây là bình thường với startup robot. Cần focus vào **tăng trưởng doanh thu** và **gross margin**.

# %%
# ═══════════════════════════════════════════════════════════════════════════════
# BƯỚC 3: PHÂN TÍCH TÀI CHÍNH - ZHIPU-B
# ═══════════════════════════════════════════════════════════════════════════════
# 
# Nguồn: Prospectus - Accountants' Report (Appendix I)
# Đơn vị gốc: RMB'000 (nghìn RMB) → Đã chuyển sang RMB
#
# ═══════════════════════════════════════════════════════════════════════════════

tai_chinh = pd.DataFrame([
    {"ky": "FY2023",  "doanh_thu": 48_042e3,  "loi_nhuan_gop": 28_466e3,  "loi_nhuan_rong": -212_869e3},
    {"ky": "FY2024",  "doanh_thu": 159_994e3, "loi_nhuan_gop": 98_077e3,  "loi_nhuan_rong": -218_509e3},
    {"ky": "1H2024",  "doanh_thu": 30_245e3,  "loi_nhuan_gop": 19_157e3,  "loi_nhuan_rong": -132_567e3},
    {"ky": "1H2025",  "doanh_thu": 149_383e3, "loi_nhuan_gop": 93_850e3,  "loi_nhuan_rong": -89_087e3},
])

# Tính toán các chỉ số
tai_chinh["gross_margin_pct"] = (tai_chinh["loi_nhuan_gop"] / tai_chinh["doanh_thu"] * 100).round(1)
tai_chinh["net_margin_pct"] = (tai_chinh["loi_nhuan_rong"] / tai_chinh["doanh_thu"] * 100).round(1)

# Tăng trưởng
tang_truong_fy = (tai_chinh.loc[1, "doanh_thu"] / tai_chinh.loc[0, "doanh_thu"] - 1) * 100
tang_truong_1h = (tai_chinh.loc[3, "doanh_thu"] / tai_chinh.loc[2, "doanh_thu"] - 1) * 100

# ═══════════════════════════════════════════════════════════════════════════════
# HIỂN THỊ
# ═══════════════════════════════════════════════════════════════════════════════

print("=" * 70)
print("📊 BƯỚC 3: PHÂN TÍCH TÀI CHÍNH")
print("=" * 70)
print(f"""
┌─────────────────────────────────────────────────────────────────────┐
│  📈 ĐIỂM NỔI BẬT                                                    │
├─────────────────────────────────────────────────────────────────────┤
│  Tăng trưởng doanh thu (FY24 vs FY23) : +{tang_truong_fy:,.0f}% 🚀              │
│  Tăng trưởng doanh thu (1H25 vs 1H24) : +{tang_truong_1h:,.0f}% 🚀              │
│  Biên lợi nhuận gộp (1H2025)          : {tai_chinh.loc[3, 'gross_margin_pct']:.1f}% (rất tốt)           │
│  Tình trạng lợi nhuận                 : Vẫn lỗ (bình thường)        │
│  Xu hướng lỗ                          : Thu hẹp (1H25 < 1H24) ✅     │
└─────────────────────────────────────────────────────────────────────┘
""")

# Bảng chi tiết
print("\n📋 Chi tiết theo kỳ (triệu RMB):")
print("-" * 70)

hien_thi = tai_chinh.copy()
hien_thi["doanh_thu_m"] = (hien_thi["doanh_thu"] / 1e6).round(1)
hien_thi["loi_nhuan_gop_m"] = (hien_thi["loi_nhuan_gop"] / 1e6).round(1)
hien_thi["loi_nhuan_rong_m"] = (hien_thi["loi_nhuan_rong"] / 1e6).round(1)

display(hien_thi[["ky", "doanh_thu_m", "loi_nhuan_gop_m", "loi_nhuan_rong_m", "gross_margin_pct"]].rename(
    columns={
        "ky": "Kỳ",
        "doanh_thu_m": "Doanh thu (¥M)",
        "loi_nhuan_gop_m": "Lợi nhuận gộp (¥M)",
        "loi_nhuan_rong_m": "Lợi nhuận ròng (¥M)",
        "gross_margin_pct": "Gross Margin (%)"
    }
))

print("\n🔍 ĐÁNH GIÁ:")
print(f"""
🟢 TÍCH CỰC:
   • Doanh thu FY24: +{tang_truong_fy:.0f}% YoY - Tăng trưởng cực mạnh (>3 lần)
   • Doanh thu 1H25: +{tang_truong_1h:.0f}% YoY - Đà tăng trưởng tiếp tục
   • Gross margin: ~63% - Tương đương Intuitive Surgical (benchmark)
   • Lỗ thu hẹp: 1H25 lỗ ¥89M < 1H24 lỗ ¥133M

🟡 CẦN THEO DÕI:
   • Vẫn đang lỗ - Cần theo dõi path to profitability
   • Tăng trưởng có bền vững không hay chỉ là one-off?

📌 CÂU HỎI CHÍNH:
   Với gross margin 63% và doanh thu tăng 3x, khi nào hòa vốn?
   → Ước tính: Khi doanh thu đạt ~¥500-600M/năm
""")
# Out:
# ...
# 📊 BƯỚC 3: PHÂN TÍCH TÀI CHÍNH
# ...
#
# ┌─────────────────────────────────────────────────────────────────────┐
# │  📈 ĐIỂM NỔI BẬT                                                    │
# ├─────────────────────────────────────────────────────────────────────┤
# │  Tăng trưởng doanh thu (FY24 vs FY23) : +233% 🚀              │
# │  Tăng trưởng doanh thu (1H25 vs 1H24) : +394% 🚀              │
# │  Biên lợi nhuận gộp (1H2025)          : 62.8% (rất tốt)           │
# │  Tình trạng lợi nhuận                 : Vẫn lỗ (bình thường)        │
# │  Xu hướng lỗ                          : Thu hẹp (1H25 < 1H24) ✅     │
# └─────────────────────────────────────────────────────────────────────┘
#
#
# 📋 Chi tiết theo kỳ (triệu RMB):
# ----------------------------------------------------------------------
#        Kỳ  Doanh thu (¥M)  Lợi nhuận gộp (¥M)  Lợi nhuận ròng (¥M)  Gross Margin (%)
# 0  FY2023            48.0                28.5               -212.9              59.3
# ...

# %%
# ═══════════════════════════════════════════════════════════════════════════════
# BƯỚC 3B: BIỂU ĐỒ TÀI CHÍNH
# ═══════════════════════════════════════════════════════════════════════════════

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Biểu đồ 1: Doanh thu
axes[0].bar(tai_chinh["ky"], tai_chinh["doanh_thu"]/1e6, color='#4472C4')
axes[0].set_title("Doanh thu theo kỳ (triệu RMB)", fontsize=12, fontweight='bold')
axes[0].set_ylabel("Triệu RMB")
axes[0].grid(True, alpha=0.3)

# Biểu đồ 2: Lợi nhuận ròng
colors = ['#C00000' if x < 0 else '#70AD47' for x in tai_chinh["loi_nhuan_rong"]]
axes[1].bar(tai_chinh["ky"], tai_chinh["loi_nhuan_rong"]/1e6, color=colors)
axes[1].set_title("Lợi nhuận ròng theo kỳ (triệu RMB)", fontsize=12, fontweight='bold')
axes[1].set_ylabel("Triệu RMB")
axes[1].axhline(y=0, color='black', linestyle='-', linewidth=0.5)
axes[1].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

print("📊 Nhận xét biểu đồ:")
print("   • Doanh thu tăng mạnh từ FY2023 → FY2024")
print("   • 1H2025 đã gần bằng cả năm FY2024")
print("   • Lỗ đang thu hẹp dần (tín hiệu tích cực)")
# Out:
# 📊 Nhận xét biểu đồ:
#    • Doanh thu tăng mạnh từ FY2023 → FY2024
#    • 1H2025 đã gần bằng cả năm FY2024
#    • Lỗ đang thu hẹp dần (tín hiệu tích cực)

# %% [markdown]
# ---
#
# # 📈 BƯỚC 4: ĐIỀU KHOẢN IPO & SỬ DỤNG VỐN
#
# ## Những thông tin cần thu thập
#
# | Hạng mục | Ý nghĩa |
# |----------|--------|
# | **Giá IPO** | Mức giá công ty bán cổ phiếu ra công chúng |
# | **Số tiền huy động** | Gross proceeds và net proceeds (sau phí) |
# | **Số cổ phiếu** | Trước và sau IPO |
# | **Sử dụng vốn** | Tiền IPO sẽ dùng vào việc gì? |
#
# ## Tại sao "Use of Proceeds" quan trọng?
#
# - Cho biết **chiến lược ưu tiên** của công ty
# - R&D cao = đang đầu tư cho tương lai
# - Working capital cao = có thể đang thiếu tiền mặt

# %%
# ═══════════════════════════════════════════════════════════════════════════════
# BƯỚC 4: ĐIỀU KHOẢN IPO - ZHIPU-B
# ═══════════════════════════════════════════════════════════════════════════════

dieu_khoan_ipo = {
    "gia_ipo_hkd": 43.24,
    "von_huy_dong_rong_hkd": 1_116.6e6,  # Net proceeds (sau phí)
    "co_phieu_truoc_ipo": 360_000_000,
    "co_phieu_sau_ipo": 387_722_200,
    
    # Phân bổ sử dụng vốn (% của net proceeds)
    "su_dung_von": {
        "R&D: Robot nội soi đa cổng": 0.23,
        "R&D: Robot nội soi đơn cổng": 0.19,
        "Thương mại hóa sản phẩm": 0.20,
        "Mở rộng sản xuất": 0.10,
        "R&D các sản phẩm khác": 0.08,
        "M&A / Đầu tư chiến lược": 0.10,
        "Vốn lưu động": 0.10,
    },
}

# ═══════════════════════════════════════════════════════════════════════════════
# HIỂN THỊ
# ═══════════════════════════════════════════════════════════════════════════════

print("=" * 70)
print("📈 BƯỚC 4: ĐIỀU KHOẢN IPO")
print("=" * 70)
print(f"""
┌─────────────────────────────────────────────────────────────────────┐
│  💵 THÔNG TIN IPO                                                   │
├─────────────────────────────────────────────────────────────────────┤
│  Giá IPO              : HKD {dieu_khoan_ipo['gia_ipo_hkd']:.2f}                              │
│  Vốn huy động ròng    : HKD {dieu_khoan_ipo['von_huy_dong_rong_hkd']/1e6:,.1f} triệu (~$144M USD)           │
│  Cổ phiếu trước IPO   : {dieu_khoan_ipo['co_phieu_truoc_ipo']:,}                           │
│  Cổ phiếu sau IPO     : {dieu_khoan_ipo['co_phieu_sau_ipo']:,}                           │
│  Dilution             : {(dieu_khoan_ipo['co_phieu_sau_ipo']/dieu_khoan_ipo['co_phieu_truoc_ipo']-1)*100:.1f}%                                         │
└─────────────────────────────────────────────────────────────────────┘
""")

# Biểu đồ sử dụng vốn
print("\n📊 Phân bổ sử dụng vốn IPO:")
print("-" * 70)

su_dung_von_df = pd.DataFrame([
    {"hang_muc": k, "ty_le": v*100} 
    for k, v in dieu_khoan_ipo["su_dung_von"].items()
]).sort_values("ty_le", ascending=False)

# Biểu đồ
fig, ax = plt.subplots(figsize=(10, 5))
bars = ax.barh(su_dung_von_df["hang_muc"], su_dung_von_df["ty_le"], color='#4472C4')
ax.set_xlabel("Tỷ lệ (%)")
ax.set_title("Phân bổ sử dụng vốn IPO", fontsize=12, fontweight='bold')

# Thêm label
for bar, val in zip(bars, su_dung_von_df["ty_le"]):
    ax.text(bar.get_width() + 0.5, bar.get_y() + bar.get_height()/2, 
            f'{val:.0f}%', va='center')

plt.tight_layout()
plt.show()

print("\n🔍 ĐÁNH GIÁ:")
print("""
🟢 TÍCH CỰC:
   • 50% vốn cho R&D (23% + 19% + 8%) - Đầu tư mạnh cho tương lai
   • 20% cho thương mại hóa - Đẩy mạnh bán hàng
   • Cân bằng giữa R&D và commercialization

🟡 CẦN THEO DÕI:
   • Working capital 10% - Theo dõi cash burn rate
""")
# Out:
# ...
# 📈 BƯỚC 4: ĐIỀU KHOẢN IPO
# ...
#
# ┌─────────────────────────────────────────────────────────────────────┐
# │  💵 THÔNG TIN IPO                                                   │
# ├─────────────────────────────────────────────────────────────────────┤
# │  Giá IPO              : HKD 43.24                              │
# │  Vốn huy động ròng    : HKD 1,116.6 triệu (~$144M USD)           │
# │  Cổ phiếu trước IPO   : 360,000,000                           │
# │  Cổ phiếu sau IPO     : 387,722,200                           │
# │  Dilution             : 7.7%                                         │
# └─────────────────────────────────────────────────────────────────────┘
#
#
# 📊 Phân bổ sử dụng vốn IPO:
# ----------------------------------------------------------------------
# 🔍 ĐÁNH GIÁ:
#
# 🟢 TÍCH CỰC:
#    • 50% vốn cho R&D (23% + 19% + 8%) - Đầu tư mạnh cho tương lai
#    • 20% cho thương mại hóa - Đẩy mạnh bán hàng
#    • Cân bằng giữa R&D và commercialization
#
# 🟡 CẦN THEO DÕI:
# ...

# %% [markdown]
# ---
#
# # 👥 BƯỚC 5: CORNERSTONE & LOCK-UP
#
# ## Cornerstone Investor là gì?
#
# Nhà đầu tư tổ chức lớn cam kết mua cổ phiếu **trước IPO**:
# - Cam kết mua trước → Giảm rủi ro không bán hết
# - Thường có lock-up 6 tháng → Không bán ngay
# - Tên công khai trong prospectus → Tín hiệu cho thị trường
#
# ## Đánh giá chất lượng cornerstone
#
# ```
# Cornerstone chất lượng cao              vs         Cornerstone đáng nghi
# ─────────────────────────                          ─────────────────────
# • Sovereign funds (ADIA, GIC)                      • "Friendly" allocation
# • Top PE/VC (Sequoia, Boyu)                        • Không tên tuổi
# • Strategic (Tencent, Alibaba)                     • Tỷ lệ quá cao (>50%)
# ```
#
# ## Lock-up là gì?
#
# Thời gian cổ đông lớn **không được bán** sau IPO:
#
# | Loại cổ đông | Thời gian lock-up |
# |--------------|------------------|
# | Cornerstone | 6 tháng |
# | Pre-IPO investors | 6-12 tháng |
# | Founders | 12-24 tháng |
#
# > ⚠️ **Trading tip**: Khi lock-up hết hạn, thường có áp lực bán.

# %%
# ═══════════════════════════════════════════════════════════════════════════════
# BƯỚC 5: CORNERSTONE & LOCK-UP - ZHIPU-B
# ═══════════════════════════════════════════════════════════════════════════════

cornerstone = pd.DataFrame([
    {"nha_dau_tu": "Tencent (Huang River Investment)", "loai": "Tập đoàn công nghệ", "lockup_het_han": "08/07/2026"},
    {"nha_dau_tu": "Abu Dhabi Investment Authority (ADIA)", "loai": "Quỹ quốc gia", "lockup_het_han": "08/07/2026"},
    {"nha_dau_tu": "UBS Asset Management Singapore", "loai": "Quỹ đầu tư", "lockup_het_han": "08/07/2026"},
    {"nha_dau_tu": "OrbiMed Genesis", "loai": "Healthcare PE", "lockup_het_han": "08/07/2026"},
    {"nha_dau_tu": "Huaxia Fund (Hong Kong)", "loai": "Quỹ đầu tư", "lockup_het_han": "08/07/2026"},
    {"nha_dau_tu": "LYFE Capital", "loai": "Healthcare VC", "lockup_het_han": "08/07/2026"},
    {"nha_dau_tu": "(+ 7-9 NĐT tổ chức khác)", "loai": "Khác", "lockup_het_han": "08/07/2026"},
])

lich_lockup = pd.DataFrame([
    {"loai_co_dong": "Cornerstone Investors (13-15)", "ngay_het_han": "08/07/2026", "tin_hieu": "⚠️ Áp lực bán"},
    {"loai_co_dong": "Pre-IPO Investors (Boyu, LYFE...)", "ngay_het_han": "08/07/2026", "tin_hieu": "⚠️ Đợt unlock lớn"},
    {"loai_co_dong": "Founder / Ban điều hành", "ngay_het_han": "08/01/2027", "tin_hieu": "Theo dõi"},
    {"loai_co_dong": "Cổ đông kiểm soát", "ngay_het_han": "08/01/2027", "tin_hieu": "Theo dõi"},
])

# ═══════════════════════════════════════════════════════════════════════════════
# HIỂN THỊ
# ═══════════════════════════════════════════════════════════════════════════════

print("=" * 70)
print("👥 BƯỚC 5: CORNERSTONE & LOCK-UP")
print("=" * 70)

print("\n📋 Danh sách Cornerstone Investors (13-15 tổ chức):")
print("-" * 70)
display(cornerstone.rename(columns={
    "nha_dau_tu": "Nhà đầu tư",
    "loai": "Loại",
    "lockup_het_han": "Lock-up hết hạn"
}))

print("\n📅 Lịch Lock-up hết hạn:")
print("-" * 70)
display(lich_lockup.rename(columns={
    "loai_co_dong": "Loại cổ đông",
    "ngay_het_han": "Ngày hết hạn",
    "tin_hieu": "Tín hiệu"
}))

print("\n🔍 ĐÁNH GIÁ:")
print("""
🟢 TÍCH CỰC:
   • Tencent (Big Tech TQ) + ADIA (quỹ quốc gia UAE) = Backing rất mạnh
   • OrbiMed - quỹ healthcare hàng đầu thế giới
   • LYFE Capital đồng hành từ Series A đến IPO

🔴 CẦN CHÚ Ý:
   • NGÀY 08/07/2026: Lock-up 6 tháng hết hạn
   • Có thể có áp lực bán lớn → Cơ hội mua giá tốt?
""")
# Out:
# ...
# 👥 BƯỚC 5: CORNERSTONE & LOCK-UP
# ...
#
# 📋 Danh sách Cornerstone Investors (13-15 tổ chức):
# ----------------------------------------------------------------------
#                               Nhà đầu tư                Loại Lock-up hết hạn
# 0       Tencent (Huang River Investment)  Tập đoàn công nghệ      08/07/2026
# 1  Abu Dhabi Investment Authority (ADIA)        Quỹ quốc gia      08/07/2026
# 2         UBS Asset Management Singapore          Quỹ đầu tư      08/07/2026
# 3                        OrbiMed Genesis       Healthcare PE      08/07/2026
# 4                Huaxia Fund (Hong Kong)          Quỹ đầu tư      08/07/2026
# 5                           LYFE Capital       Healthcare VC      08/07/2026
# 6               (+ 7-9 NĐT tổ chức khác)                Khác      08/07/2026
# 📅 Lịch Lock-up hết hạn:
# ----------------------------------------------------------------------
#                         Loại cổ đông Ngày hết hạn           Tín hiệu
# ...

# %% [markdown]
# ---
#
# # 🔬 BƯỚC 6: SẢN PHẨM & LỢI THẾ CẠNH TRANH
#
# ## Moat (Lợi thế cạnh tranh) là gì?
#
# **Moat** = Những yếu tố giúp công ty duy trì lợi thế trước đối thủ
#
# | Loại Moat | Mô tả | Ví dụ |
# |-----------|-------|-------|
# | **Patents/IP** | Sở hữu trí tuệ | Công nghệ độc quyền |
# | **Regulatory** | Giấy phép, chứng nhận | FDA, CE, NMPA approval |
# | **Switching Cost** | Chi phí chuyển đổi | Bác sĩ đã quen dùng robot |
# | **Network Effect** | Hiệu ứng mạng lưới | Càng nhiều bệnh viện dùng, data càng tốt |
# | **Scale** | Quy mô | Sản xuất nhiều = giá thành thấp |

# %%
# ═══════════════════════════════════════════════════════════════════════════════
# BƯỚC 6: SẢN PHẨM & LỢI THẾ CẠNH TRANH - ZHIPU-B
# ═══════════════════════════════════════════════════════════════════════════════

san_pham = pd.DataFrame([
    {"san_pham": "MP1000 (Robot đa cổng)", "trang_thai": "Đã thương mại", "chi_dinh": "Tiết niệu, Phụ khoa, Lồng ngực", "doi_thu": "da Vinci Xi"},
    {"san_pham": "MP2000 (Thế hệ mới)", "trang_thai": "Ra mắt T8/2024", "chi_dinh": "Đa chuyên khoa", "doi_thu": "da Vinci 5"},
    {"san_pham": "SP1000 (Robot đơn cổng)", "trang_thai": "Đã thương mại", "chi_dinh": "Phẫu thuật 1 lỗ", "doi_thu": "da Vinci SP"},
    {"san_pham": "Robot nội soi phế quản", "trang_thai": "Đã thương mại", "chi_dinh": "Hô hấp", "doi_thu": "Ion, Monarch"},
])

moat_checklist = pd.DataFrame([
    {"khia_canh": "Giấy phép NMPA (Trung Quốc)", "trang_thai": "🟢 Đã có", "ghi_chu": "MP1000, SP1000 đã approved"},
    {"khia_canh": "Chứng nhận CE (Châu Âu)", "trang_thai": "🟢 Đã có", "ghi_chu": "Mở cửa thị trường EU"},
    {"khia_canh": "FDA (Mỹ)", "trang_thai": "🟡 Chưa có", "ghi_chu": "Catalyst tiềm năng nếu submit"},
    {"khia_canh": "Thử nghiệm lâm sàng", "trang_thai": "🟢 Tích cực", "ghi_chu": "RCT: Tương đương da Vinci"},
    {"khia_canh": "Patents/IP", "trang_thai": "🟢 Có", "ghi_chu": "Kiểm tra chi tiết trong prospectus"},
    {"khia_canh": "Installed base", "trang_thai": "🟢 Đang tăng", "ghi_chu": ">4,000 ca phẫu thuật (12/2024)"},
])

# ═══════════════════════════════════════════════════════════════════════════════
# HIỂN THỊ
# ═══════════════════════════════════════════════════════════════════════════════

print("=" * 70)
print("🔬 BƯỚC 6: SẢN PHẨM & LỢI THẾ CẠNH TRANH")
print("=" * 70)

print("\n📦 Danh mục sản phẩm:")
print("-" * 70)
display(san_pham.rename(columns={
    "san_pham": "Sản phẩm",
    "trang_thai": "Trạng thái",
    "chi_dinh": "Chỉ định",
    "doi_thu": "Đối thủ cạnh tranh"
}))

print("\n🛡️ Checklist lợi thế cạnh tranh (Moat):")
print("-" * 70)
display(moat_checklist.rename(columns={
    "khia_canh": "Khía cạnh",
    "trang_thai": "Trạng thái",
    "ghi_chu": "Ghi chú"
}))

print("\n🔍 ĐÁNH GIÁ:")
print("""
🟢 TÍCH CỰC:
   • 4 sản phẩm đã thương mại - Pipeline đa dạng
   • NMPA + CE approved - Có thể bán tại TQ và EU
   • Thử nghiệm lâm sàng tương đương da Vinci - Đủ tin cậy
   • >4,000 ca phẫu thuật - Đã có traction

🟡 CƠ HỘI:
   • FDA approval sẽ là catalyst lớn nếu submit
   • Mở rộng ra các chỉ định mới
""")
# Out:
# ...
# 🔬 BƯỚC 6: SẢN PHẨM & LỢI THẾ CẠNH TRANH
# ...
#
# 📦 Danh mục sản phẩm:
# ----------------------------------------------------------------------
#                   Sản phẩm      Trạng thái                        Chỉ định Đối thủ cạnh tranh
# 0   MP1000 (Robot đa cổng)   Đã thương mại  Tiết niệu, Phụ khoa, Lồng ngực        da Vinci Xi
# 1      MP2000 (Thế hệ mới)  Ra mắt T8/2024                  Đa chuyên khoa         da Vinci 5
# 2  SP1000 (Robot đơn cổng)   Đã thương mại                 Phẫu thuật 1 lỗ        da Vinci SP
# 3   Robot nội soi phế quản   Đã thương mại                          Hô hấp       Ion, Monarch
# 🛡️ Checklist lợi thế cạnh tranh (Moat):
# ----------------------------------------------------------------------
#                      Khía cạnh   Trạng thái                             Ghi chú
# 0  Giấy phép NMPA (Trung Quốc)      🟢 Đã có          MP1000, SP1000 đã approved
# 1      Chứng nhận CE (Châu Âu)      🟢 Đã có                Mở cửa thị trường EU
# ...

# %% [markdown]
# ---
#
# # 📊 BƯỚC 7: CHỈ SỐ NGÀNH
#
# ## Tại sao cần KPIs đặc thù ngành?
#
# Mỗi ngành có những chỉ số quan trọng khác nhau:
#
# | Ngành | KPIs đặc thù |
# |-------|-------------|
# | **Robot phẫu thuật** | Số ca phẫu thuật, số hệ thống lắp đặt, doanh thu vật tư tiêu hao |
# | **AI Chips** | Design wins, tape-out schedule, foundry partner |
# | **LLM/GenAI** | API calls, MAU, compute cost ratio |

# %%
# ═══════════════════════════════════════════════════════════════════════════════
# BƯỚC 7: CHỈ SỐ NGÀNH - Robot phẫu thuật
# ═══════════════════════════════════════════════════════════════════════════════

kpi_nganh = pd.DataFrame([
    {"chi_so": "Số ca phẫu thuật (tích lũy)", "fy2023": ">1,000", "fy2024": ">4,000", "xu_huong": "🟢 Tăng mạnh"},
    {"chi_so": "Số hệ thống lắp đặt", "fy2023": "TBD", "fy2024": "TBD", "xu_huong": "Cần verify từ prospectus"},
    {"chi_so": "Số bệnh viện sử dụng", "fy2023": "TBD", "fy2024": "TBD", "xu_huong": "Cần verify từ prospectus"},
    {"chi_so": "Số sản phẩm thương mại", "fy2023": "1 (MP1000)", "fy2024": "3+", "xu_huong": "🟢 Pipeline mở rộng"},
    {"chi_so": "CE Mark", "fy2023": "Chưa có", "fy2024": "Đã có", "xu_huong": "🟢 Mở cửa EU"},
    {"chi_so": "So sánh với da Vinci (RCT)", "fy2023": "-", "fy2024": "Tương đương", "xu_huong": "🟢 Đã validate"},
])

# ═══════════════════════════════════════════════════════════════════════════════
# HIỂN THỊ
# ═══════════════════════════════════════════════════════════════════════════════

print("=" * 70)
print("📊 BƯỚC 7: CHỈ SỐ NGÀNH (Robot phẫu thuật)")
print("=" * 70)

display(kpi_nganh.rename(columns={
    "chi_so": "Chỉ số",
    "fy2023": "FY2023",
    "fy2024": "FY2024",
    "xu_huong": "Xu hướng"
}))

print("\n🔍 ĐÁNH GIÁ:")
print("""
🟢 TÍCH CỰC:
   • Số ca phẫu thuật tăng 4x trong 1 năm (>1,000 → >4,000)
   • Pipeline sản phẩm mở rộng nhanh
   • Đã có clinical validation

📌 CẦN THEO DÕI TRONG BÁO CÁO TIẾP THEO:
   • Số hệ thống mới lắp đặt mỗi quý
   • Tỷ lệ doanh thu từ vật tư tiêu hao (recurring revenue)
   • Mở rộng ra các bệnh viện mới
""")
# Out:
# ...
# 📊 BƯỚC 7: CHỈ SỐ NGÀNH (Robot phẫu thuật)
# ...
#                         Chỉ số      FY2023       FY2024                  Xu hướng
# 0  Số ca phẫu thuật (tích lũy)      >1,000       >4,000               🟢 Tăng mạnh
# 1          Số hệ thống lắp đặt         TBD          TBD  Cần verify từ prospectus
# 2         Số bệnh viện sử dụng         TBD          TBD  Cần verify từ prospectus
# 3       Số sản phẩm thương mại  1 (MP1000)           3+        🟢 Pipeline mở rộng
# 4                      CE Mark     Chưa có        Đã có               🟢 Mở cửa EU
# 5   So sánh với da Vinci (RCT)           -  Tương đương             🟢 Đã validate
# 🔍 ĐÁNH GIÁ:
#
# 🟢 TÍCH CỰC:
#    • Số ca phẫu thuật tăng 4x trong 1 năm (>1,000 → >4,000)
#    • Pipeline sản phẩm mở rộng nhanh
#    • Đã có clinical validation
#
# 📌 CẦN THEO DÕI TRONG BÁO CÁO TIẾP THEO:
#    • Số hệ thống mới lắp đặt mỗi quý
#    • Tỷ lệ doanh thu từ vật tư tiêu hao (recurring revenue)
#    • Mở rộng ra các bệnh viện mới

# %% [markdown]
# ---
#
# # 💵 BƯỚC 8: SO SÁNH & ĐỊNH GIÁ
#
# ## Phương pháp định giá cho công ty chưa có lãi
#
# | Phương pháp | Khi nào dùng | Công thức |
# |-------------|--------------|----------|
# | **P/E** | Công ty có lãi | Giá / EPS |
# | **EV/Sales** | Công ty chưa có lãi | Enterprise Value / Doanh thu |
# | **EV/Gross Profit** | Công ty có gross margin ổn định | EV / Lợi nhuận gộp |
#
# > **ZHIPU-B đang lỗ** → Dùng **EV/Sales** để so sánh
#
# ## Chọn peer để so sánh
#
# - **Benchmark toàn cầu**: Intuitive Surgical (ISRG) - "king" của surgical robotics
# - **Peers Trung Quốc**: MicroPort MedBot (2252.HK)
# - **Adjacent comps**: Các công ty thiết bị y tế khác

# %%
# ═══════════════════════════════════════════════════════════════════════════════
# BƯỚC 8: SO SÁNH & ĐỊNH GIÁ
# ═══════════════════════════════════════════════════════════════════════════════

# Cash runway analysis
tien_mat_truoc_ipo = 94_457e3  # RMB, từ balance sheet
von_ipo_rmb = 1_116.6e6 * 0.92  # Chuyển HKD → RMB
tong_tien_mat = tien_mat_truoc_ipo + von_ipo_rmb

# Ước tính burn rate từ 1H2025
burn_rate_quy = 89_087e3 / 2  # Lỗ 1H2025 / 2 quý

runway_quy = tong_tien_mat / burn_rate_quy
runway_nam = runway_quy / 4

# Peer comparison
so_sanh_peer = pd.DataFrame([
    {"cong_ty": "Intuitive Surgical", "ma_ck": "ISRG", "ev_sales": "15-20x", "gross_margin": "~67%", "tang_truong": "~15%", "loi_nhuan": "Có lãi"},
    {"cong_ty": "MicroPort MedBot", "ma_ck": "2252.HK", "ev_sales": "8-12x", "gross_margin": "~55%", "tang_truong": "~50%", "loi_nhuan": "Lỗ"},
    {"cong_ty": "ZHIPU-B", "ma_ck": "2513.HK", "ev_sales": "10-15x", "gross_margin": "~63%", "tang_truong": ">200%", "loi_nhuan": "Lỗ"},
])

# ═══════════════════════════════════════════════════════════════════════════════
# HIỂN THỊ
# ═══════════════════════════════════════════════════════════════════════════════

print("=" * 70)
print("💵 BƯỚC 8: SO SÁNH & ĐỊNH GIÁ")
print("=" * 70)

print(f"""
┌─────────────────────────────────────────────────────────────────────┐
│  💰 PHÂN TÍCH DÒNG TIỀN (Cash Runway)                               │
├─────────────────────────────────────────────────────────────────────┤
│  Tiền mặt trước IPO    : ¥{tien_mat_truoc_ipo/1e6:.1f} triệu                          │
│  Vốn IPO (sau chuyển)  : ¥{von_ipo_rmb/1e6:.1f} triệu                         │
│  Tổng tiền mặt         : ¥{tong_tien_mat/1e6:.1f} triệu                        │
│  Burn rate/quý (ước)   : ¥{burn_rate_quy/1e6:.1f} triệu                           │
│  ─────────────────────────────────────────────────────────────────  │
│  Cash Runway           : {runway_quy:.1f} quý (~{runway_nam:.1f} năm) 🟢               │
└─────────────────────────────────────────────────────────────────────┘
""")

print("\n📊 So sánh với Peers:")
print("-" * 70)
display(so_sanh_peer.rename(columns={
    "cong_ty": "Công ty",
    "ma_ck": "Mã CK",
    "ev_sales": "EV/Sales",
    "gross_margin": "Gross Margin",
    "tang_truong": "Tăng trưởng",
    "loi_nhuan": "Lợi nhuận"
}))

print("\n🔍 ĐÁNH GIÁ ĐỊNH GIÁ:")
print("""
🟢 TÍCH CỰC:
   • Cash runway ~5.7 năm - Không lo hết tiền trong ngắn hạn
   • Gross margin 63% - Cao hơn MicroPort (55%), gần Intuitive (67%)
   • Tăng trưởng >200% - Cao nhất trong peers

🟡 ĐỊNH GIÁ:
   • EV/Sales 10-15x: Premium so với MicroPort (8-12x)
   • Discount so với Intuitive (15-20x) - Hợp lý vì quy mô nhỏ hơn
   • Fair value range: HKD 55-75
""")
# Out:
# ...
# 💵 BƯỚC 8: SO SÁNH & ĐỊNH GIÁ
# ...
#
# ┌─────────────────────────────────────────────────────────────────────┐
# │  💰 PHÂN TÍCH DÒNG TIỀN (Cash Runway)                               │
# ├─────────────────────────────────────────────────────────────────────┤
# │  Tiền mặt trước IPO    : ¥94.5 triệu                          │
# │  Vốn IPO (sau chuyển)  : ¥1027.3 triệu                         │
# │  Tổng tiền mặt         : ¥1121.7 triệu                        │
# │  Burn rate/quý (ước)   : ¥44.5 triệu                           │
# │  ─────────────────────────────────────────────────────────────────  │
# │  Cash Runway           : 25.2 quý (~6.3 năm) 🟢               │
# └─────────────────────────────────────────────────────────────────────┘
#
#
# 📊 So sánh với Peers:
# ----------------------------------------------------------------------
#               Công ty     Mã CK EV/Sales Gross Margin Tăng trưởng Lợi nhuận
# 0  Intuitive Surgical      ISRG   15-20x         ~67%        ~15%    Có lãi
# ...

# %% [markdown]
# ---
#
# # ⚠️ BƯỚC 9: ĐÁNH GIÁ RỦI RO
#
# ## Các loại rủi ro cần đánh giá
#
# | Loại rủi ro | Mô tả | Ví dụ |
# |-------------|-------|-------|
# | **Quản trị** | Founder control, related-party | Conflict of interest |
# | **Tài chính** | Cash burn, runway | Hết tiền |
# | **Vận hành** | Sản phẩm, sản xuất | Single-product risk |
# | **Cạnh tranh** | Đối thủ, thị phần | Intuitive, MicroPort |
# | **Địa chính trị** | Sanctions, export control | US-China tech war |
# | **Pháp lý** | Regulatory approval | FDA rejection |

# %%
# ═══════════════════════════════════════════════════════════════════════════════
# BƯỚC 9: ĐÁNH GIÁ RỦI RO - ZHIPU-B
# ═══════════════════════════════════════════════════════════════════════════════

rui_ro = pd.DataFrame([
    {"loai": "Tài chính", "rui_ro": "Vẫn đang lỗ, đốt tiền", "muc_do": "🟡 Trung bình", "ghi_chu": "Runway ~5.7 năm, đủ buffer"},
    {"loai": "Tài chính", "rui_ro": "Lock-up expiry T7/2026", "muc_do": "🔴 Cao", "ghi_chu": "Có thể có áp lực bán mạnh"},
    {"loai": "Cạnh tranh", "rui_ro": "Intuitive Surgical thống trị", "muc_do": "🟡 Trung bình", "ghi_chu": "Nhưng TQ ưu tiên nội địa hóa"},
    {"loai": "Cạnh tranh", "rui_ro": "MicroPort, đối thủ nội địa mới", "muc_do": "🟡 Trung bình", "ghi_chu": "Cạnh tranh gia tăng"},
    {"loai": "Vận hành", "rui_ro": "Scale sản xuất & bán hàng", "muc_do": "🟡 Trung bình", "ghi_chu": "Cần theo dõi execution"},
    {"loai": "Địa chính trị", "rui_ro": "US-China tech war", "muc_do": "🟢 Thấp", "ghi_chu": "Thiết bị y tế ít bị target"},
    {"loai": "Pháp lý", "rui_ro": "NMPA/CE compliance", "muc_do": "🟢 Thấp", "ghi_chu": "Đã có approval"},
])

# ═══════════════════════════════════════════════════════════════════════════════
# HIỂN THỊ
# ═══════════════════════════════════════════════════════════════════════════════

print("=" * 70)
print("⚠️ BƯỚC 9: ĐÁNH GIÁ RỦI RO")
print("=" * 70)

display(rui_ro.rename(columns={
    "loai": "Loại",
    "rui_ro": "Rủi ro",
    "muc_do": "Mức độ",
    "ghi_chu": "Ghi chú"
}))

print("\n📊 TÓM TẮT RỦI RO:")
print("""
┌─────────────────────────────────────────────────────────────────────┐
│  🔴 RỦI RO CAO:                                                     │
│     • Lock-up expiry 08/07/2026 - Áp lực bán tiềm năng             │
├─────────────────────────────────────────────────────────────────────┤
│  🟡 RỦI RO TRUNG BÌNH:                                              │
│     • Vẫn đang lỗ (nhưng runway đủ dài)                            │
│     • Cạnh tranh từ Intuitive và MicroPort                         │
│     • Execution risk khi scale                                      │
├─────────────────────────────────────────────────────────────────────┤
│  🟢 RỦI RO THẤP:                                                    │
│     • Địa chính trị (ít bị ảnh hưởng US sanctions)                 │
│     • Regulatory (đã có NMPA, CE)                                   │
└─────────────────────────────────────────────────────────────────────┘
""")
# Out:
# ...
# ⚠️ BƯỚC 9: ĐÁNH GIÁ RỦI RO
# ...
#             Loại                          Rủi ro        Mức độ                       Ghi chú
# 0      Tài chính           Vẫn đang lỗ, đốt tiền  🟡 Trung bình    Runway ~5.7 năm, đủ buffer
# 1      Tài chính          Lock-up expiry T7/2026         🔴 Cao     Có thể có áp lực bán mạnh
# 2     Cạnh tranh    Intuitive Surgical thống trị  🟡 Trung bình  Nhưng TQ ưu tiên nội địa hóa
# 3     Cạnh tranh  MicroPort, đối thủ nội địa mới  🟡 Trung bình           Cạnh tranh gia tăng
# 4       Vận hành       Scale sản xuất & bán hàng  🟡 Trung bình        Cần theo dõi execution
# 5  Địa chính trị               US-China tech war        🟢 Thấp    Thiết bị y tế ít bị target
# 6        Pháp lý              NMPA/CE compliance        🟢 Thấp                Đã có approval
# 📊 TÓM TẮT RỦI RO:
#
# ┌─────────────────────────────────────────────────────────────────────┐
# │  🔴 RỦI RO CAO:                                                     │
# ...

# %% [markdown]
# ---
#
# # 📝 BƯỚC 10: KẾT LUẬN ĐẦU TƯ
#
# ## Framework ra quyết định
#
# ```
#                          ┌─────────────────┐
#                          │  QUYẾT ĐỊNH     │
#                          │  ĐẦU TƯ         │
#                          └────────┬────────┘
#                                   │
#            ┌──────────────────────┼──────────────────────┐
#            ▼                      ▼                      ▼
#      ┌─────────┐           ┌─────────────┐        ┌─────────────┐
#      │   MUA   │           │  THEO DÕI   │        │   TRÁNH     │
#      └────┬────┘           └──────┬──────┘        └──────┬──────┘
#           │                       │                      │
#    • Thesis mạnh             • Thesis OK            • Thesis yếu
#    • Định giá hấp dẫn        • Định giá fair        • Định giá cao
#    • Risk chấp nhận được     • Cần thêm data        • Red flags nhiều
#    • Catalysts rõ            • Chờ entry point      • Risk > Reward
# ```

# %%
# ═══════════════════════════════════════════════════════════════════════════════
# BƯỚC 10: KẾT LUẬN ĐẦU TƯ - ZHIPU-B
# ═══════════════════════════════════════════════════════════════════════════════

print("=" * 80)
print("📝 KẾT LUẬN ĐẦU TƯ")
print("=" * 80)

print("""
╔══════════════════════════════════════════════════════════════════════════════╗
║                        ZHIPU-B (2513.HK)                             ║
║                        Robot phẫu thuật | HKEX Main Board                    ║
╠══════════════════════════════════════════════════════════════════════════════╣
║                                                                              ║
║   📋 THESIS (Luận điểm đầu tư):                                              ║
║   Công ty robot phẫu thuật hàng đầu Trung Quốc, hưởng lợi từ xu hướng        ║
║   nội địa hóa thiết bị y tế. Có backing mạnh từ Tencent và ADIA.             ║
║                                                                              ║
╠══════════════════════════════════════════════════════════════════════════════╣
║                                                                              ║
║   ✅ ĐIỀU KIỆN CẦN ĐÚNG:                                                     ║
║   1. Tiếp tục tăng trưởng >50% YoY về doanh thu                              ║
║   2. Duy trì gross margin >60%                                               ║
║   3. MP2000/SP1000 cạnh tranh được với da Vinci                              ║
║                                                                              ║
╠══════════════════════════════════════════════════════════════════════════════╣
║                                                                              ║
║   ⚠️ RỦI RO CHÍNH:                                                           ║
║   1. Lock-up expiry 08/07/2026 - Áp lực bán                                  ║
║   2. Vẫn đang lỗ - Cần theo dõi path to profitability                        ║
║   3. Cạnh tranh từ Intuitive và MicroPort                                    ║
║                                                                              ║
╠══════════════════════════════════════════════════════════════════════════════╣
║                                                                              ║
║   💵 ĐÁNH GIÁ ĐỊNH GIÁ:                                                      ║
║   • EV/Sales 10-15x: Premium vs MicroPort, discount vs Intuitive             ║
║   • Vùng giá hợp lý: HKD 55-75                                               ║
║                                                                              ║
╠══════════════════════════════════════════════════════════════════════════════╣
║                                                                              ║
║                         🎯 QUYẾT ĐỊNH                                        ║
║   ═══════════════════════════════════════════════════════════════════════    ║
║                                                                              ║
║   KHUYẾN NGHỊ:    📊 THEO DÕI / MUA KHI GIÁ GIẢM                             ║
║                                                                              ║
║   Vùng mua:       HKD 50-55 (gần vùng hỗ trợ)                                ║
║   Mục tiêu:       HKD 70-80 (nếu thesis đúng)                                ║
║   Cắt lỗ:         HKD 40 (dưới giá IPO = thesis sai)                         ║
║                                                                              ║
║   ═══════════════════════════════════════════════════════════════════════    ║
║                                                                              ║
║   LÝ DO:                                                                     ║
║   • Thesis mạnh (nội địa hóa, backing tốt)                                   ║
║   • Định giá fair nhưng chưa rẻ ở mức hiện tại                               ║
║   • Cơ hội mua tốt hơn quanh lock-up expiry (T7/2026)                        ║
║   • Báo cáo 1H2026 (T8-9) sẽ kiểm chứng thesis                               ║
║                                                                              ║
╚══════════════════════════════════════════════════════════════════════════════╝
""")

print("\n📅 LỊCH SỰ KIỆN QUAN TRỌNG:")
print("-" * 80)
lich_su_kien = pd.DataFrame([
    {"ngay": "08/07/2026", "su_kien": "Lock-up 6 tháng hết hạn", "tac_dong": "⚠️ Áp lực bán, có thể có giá tốt"},
    {"ngay": "T8-9/2026", "su_kien": "Báo cáo tài chính 1H2026", "tac_dong": "Kiểm chứng thesis tăng trưởng"},
    {"ngay": "TBD", "su_kien": "FDA submission (nếu có)", "tac_dong": "📈 Catalyst tích cực lớn"},
    {"ngay": "08/01/2027", "su_kien": "Lock-up 12 tháng hết hạn", "tac_dong": "⚠️ Đợt unlock thứ hai"},
])
display(lich_su_kien.rename(columns={"ngay": "Ngày", "su_kien": "Sự kiện", "tac_dong": "Tác động"}))

print("\n📋 VIỆC CẦN LÀM TIẾP THEO:")
print("""
   □ Đặt cảnh báo giá vùng HKD 50-55
   □ Đặt lịch nhắc ngày 08/07/2026 (lock-up expiry)
   □ Theo dõi tin tức HKEX hàng tuần
   □ Review lại khi có báo cáo 1H2026
""")
# Out:
# ...
# 📝 KẾT LUẬN ĐẦU TƯ
# ...
#
# ╔══════════════════════════════════════════════════════════════════════════════╗
# ║                        ZHIPU-B (2513.HK)                             ║
# ║                        Robot phẫu thuật | HKEX Main Board                    ║
# ╠══════════════════════════════════════════════════════════════════════════════╣
# ║                                                                              ║
# ║   📋 THESIS (Luận điểm đầu tư):                                              ║
# ║   Công ty robot phẫu thuật hàng đầu Trung Quốc, hưởng lợi từ xu hướng        ║
# ║   nội địa hóa thiết bị y tế. Có backing mạnh từ Tencent và ADIA.             ║
# ║                                                                              ║
# ╠══════════════════════════════════════════════════════════════════════════════╣
# ║                                                                              ║
# ...

# %% [markdown]
# ---
#
# # 📊 PHỤ LỤC: THEO DÕI SAU IPO
#
# ## Kế hoạch theo dõi
#
# | Tần suất | Chỉ số cần theo dõi |
# |----------|--------------------|
# | **Hàng tuần** | Giá vs giá IPO, khối lượng giao dịch |
# | **Hàng tháng** | Tin tức, announcements HKEX |
# | **Hàng quý** | Báo cáo tài chính, KPIs vận hành |

# %%
# ═══════════════════════════════════════════════════════════════════════════════
# PHỤ LỤC: MẪU THEO DÕI SAU IPO
# ═══════════════════════════════════════════════════════════════════════════════

muc_gia_quan_trong = {
    "gia_ipo": 43.24,
    "ngay_1_low": 48.00,
    "all_time_high": 73.70,
    "all_time_high_ngay": "15/01/2026",
    "ho_tro_1": 48.00,
    "ho_tro_2": 43.24,
    "khang_cu_1": 73.70,
}

print("=" * 70)
print("📊 PHỤ LỤC: THEO DÕI SAU IPO")
print("=" * 70)

print(f"""
┌─────────────────────────────────────────────────────────────────────┐
│  📈 MỨC GIÁ QUAN TRỌNG (HKD)                                        │
├─────────────────────────────────────────────────────────────────────┤
│  Giá IPO           : {muc_gia_quan_trong['gia_ipo']:.2f}                                     │
│  Giá thấp nhất     : {muc_gia_quan_trong['ngay_1_low']:.2f} (Ngày 1)                              │
│  Giá cao nhất      : {muc_gia_quan_trong['all_time_high']:.2f} ({muc_gia_quan_trong['all_time_high_ngay']})                       │
│  ─────────────────────────────────────────────────────────────────  │
│  Hỗ trợ 1          : {muc_gia_quan_trong['ho_tro_1']:.2f}                                     │
│  Hỗ trợ 2          : {muc_gia_quan_trong['ho_tro_2']:.2f} (Giá IPO - quan trọng)              │
│  Kháng cự 1        : {muc_gia_quan_trong['khang_cu_1']:.2f} (ATH)                                │
└─────────────────────────────────────────────────────────────────────┘
""")

# Mẫu theo dõi hàng tuần
print("\n📋 Mẫu theo dõi hàng tuần (điền khi update):")
print("-" * 70)
theo_doi = pd.DataFrame(columns=[
    "Tuần",
    "Giá đóng cửa",
    "% vs IPO",
    "Khối lượng TB",
    "Tin tức",
    "Ghi chú"
])
display(theo_doi)
# Out:
# ...
# 📊 PHỤ LỤC: THEO DÕI SAU IPO
# ...
#
# ┌─────────────────────────────────────────────────────────────────────┐
# │  📈 MỨC GIÁ QUAN TRỌNG (HKD)                                        │
# ├─────────────────────────────────────────────────────────────────────┤
# │  Giá IPO           : 43.24                                     │
# │  Giá thấp nhất     : 48.00 (Ngày 1)                              │
# │  Giá cao nhất      : 73.70 (15/01/2026)                       │
# │  ─────────────────────────────────────────────────────────────────  │
# │  Hỗ trợ 1          : 48.00                                     │
# │  Hỗ trợ 2          : 43.24 (Giá IPO - quan trọng)              │
# │  Kháng cự 1        : 73.70 (ATH)                                │
# └─────────────────────────────────────────────────────────────────────┘
#
#
# 📋 Mẫu theo dõi hàng tuần (điền khi update):
# ----------------------------------------------------------------------
# Empty DataFrame
# ...

# %% [markdown]
# ---
#
# ## 📈 Dữ liệu giá & khối lượng giao dịch (Live từ Yahoo Finance)
#
# ### Mục đích
# - Tự động lấy dữ liệu giá cổ phiếu từ Yahoo Finance
# - Hiển thị biểu đồ giá và khối lượng giao dịch
# - Theo dõi performance so với giá IPO
#
# ### Cách sử dụng
# 1. Chạy cell bên dưới để cài đặt thư viện `yfinance`
# 2. Dữ liệu sẽ tự động cập nhật mỗi lần chạy
# 3. Có thể thay đổi `MA_CK` để theo dõi cổ phiếu khác
#
# > ⚠️ **Lưu ý**: Cần kết nối internet để lấy dữ liệu

# %%
# ═══════════════════════════════════════════════════════════════════════════════
# 📈 LẤY DỮ LIỆU GIÁ TỪ YAHOO FINANCE
# ═══════════════════════════════════════════════════════════════════════════════
# 
# Sử dụng thư viện yfinance để lấy dữ liệu giá cổ phiếu
# Docs: https://pypi.org/project/yfinance/
#
# ═══════════════════════════════════════════════════════════════════════════════

# Cài đặt thư viện (chỉ cần chạy 1 lần)
# !pip install yfinance -q

import yfinance as yf
from datetime import datetime, timedelta

# ═══════════════════════════════════════════════════════════════════════════════
# CẤU HÌNH
# ═══════════════════════════════════════════════════════════════════════════════

MA_CK = "2513.HK"           # Mã chứng khoán (Yahoo format)
GIA_IPO = 116.2             # Giá IPO (HKD)
NGAY_IPO = "2026-01-08"     # Ngày niêm yết
SO_NGAY = 90                # Số ngày lấy dữ liệu (từ IPO hoặc 90 ngày gần nhất)

# ═══════════════════════════════════════════════════════════════════════════════
# LẤY DỮ LIỆU
# ═══════════════════════════════════════════════════════════════════════════════

print("=" * 70)
print(f"📈 LẤY DỮ LIỆU GIÁ: {MA_CK}")
print("=" * 70)

try:
    # Tạo object ticker
    ticker = yf.Ticker(MA_CK)
    
    # Lấy thông tin cơ bản
    info = ticker.info
    ten_cty = info.get('longName', info.get('shortName', MA_CK))
    
    # Lấy dữ liệu giá (từ ngày IPO hoặc 90 ngày)
    ngay_bat_dau = NGAY_IPO
    du_lieu = ticker.history(start=ngay_bat_dau)
    
    if du_lieu.empty:
        # Nếu không có dữ liệu từ IPO, lấy 90 ngày gần nhất
        du_lieu = ticker.history(period="3mo")
    
    print(f"\n✅ Đã lấy dữ liệu: {ten_cty}")
    print(f"   Số ngày giao dịch: {len(du_lieu)}")
    print(f"   Từ: {du_lieu.index[0].strftime('%Y-%m-%d')} đến {du_lieu.index[-1].strftime('%Y-%m-%d')}")
    
except Exception as e:
    print(f"❌ Lỗi khi lấy dữ liệu: {e}")
    print("   Kiểm tra lại mã chứng khoán hoặc kết nối internet")
    du_lieu = None
# Out:
# ...
# 📈 LẤY DỮ LIỆU GIÁ: 2513.HK
# ...
#
# ✅ Đã lấy dữ liệu: Shenzhen ZHIPU-B Co Ltd
#    Số ngày giao dịch: 29
#    Từ: 2026-01-08 đến 2026-02-20

# %%
# ═══════════════════════════════════════════════════════════════════════════════
# 📊 HIỂN THỊ THỐNG KÊ GIÁ
# ═══════════════════════════════════════════════════════════════════════════════

if du_lieu is not None and not du_lieu.empty:
    # Tính toán các chỉ số
    gia_hien_tai = du_lieu['Close'].iloc[-1]
    gia_cao_nhat = du_lieu['High'].max()
    gia_thap_nhat = du_lieu['Low'].min()
    gia_trung_binh = du_lieu['Close'].mean()
    kl_trung_binh = du_lieu['Volume'].mean()
    kl_hom_nay = du_lieu['Volume'].iloc[-1]
    
    # % thay đổi so với IPO
    pct_vs_ipo = (gia_hien_tai - GIA_IPO) / GIA_IPO * 100
    pct_vs_high = (gia_hien_tai - gia_cao_nhat) / gia_cao_nhat * 100
    
    # Xác định emoji và dấu
    emoji_ipo = '🟢' if pct_vs_ipo >= 0 else '🔴'
    dau_ipo = '+' if pct_vs_ipo >= 0 else ''
    
    print("=" * 70)
    print(f"📊 THỐNG KÊ GIÁ: {MA_CK}")
    print("=" * 70)
    print(f"""
┌─────────────────────────────────────────────────────────────────────┐
│  💰 GIÁ HIỆN TẠI                                                    │
├─────────────────────────────────────────────────────────────────────┤
│  Giá đóng cửa gần nhất : HKD {gia_hien_tai:,.2f}                          │
│  So với giá IPO        : {dau_ipo}{pct_vs_ipo:,.1f}% {emoji_ipo}                              │
│  So với đỉnh           : {pct_vs_high:,.1f}%                                │
├─────────────────────────────────────────────────────────────────────┤
│  📈 RANGE TỪ IPO                                                    │
├─────────────────────────────────────────────────────────────────────┤
│  Giá IPO               : HKD {GIA_IPO:,.2f}                               │
│  Giá cao nhất          : HKD {gia_cao_nhat:,.2f}                              │
│  Giá thấp nhất         : HKD {gia_thap_nhat:,.2f}                              │
│  Giá trung bình        : HKD {gia_trung_binh:,.2f}                              │
├─────────────────────────────────────────────────────────────────────┤
│  📊 KHỐI LƯỢNG                                                      │
├─────────────────────────────────────────────────────────────────────┤
│  KL giao dịch TB/ngày  : {kl_trung_binh:,.0f} cổ phiếu                  │
│  KL hôm gần nhất       : {kl_hom_nay:,.0f} cổ phiếu                  │
└─────────────────────────────────────────────────────────────────────┘
    """)
    
    # Bảng 10 ngày gần nhất
    print("\n📋 10 ngày giao dịch gần nhất:")
    print("-" * 70)
    
    bang_10_ngay = du_lieu.tail(10)[['Open', 'High', 'Low', 'Close', 'Volume']].copy()
    bang_10_ngay.index = bang_10_ngay.index.strftime('%Y-%m-%d')
    bang_10_ngay.columns = ['Mở cửa', 'Cao nhất', 'Thấp nhất', 'Đóng cửa', 'Khối lượng']
    bang_10_ngay['% vs IPO'] = ((bang_10_ngay['Đóng cửa'] - GIA_IPO) / GIA_IPO * 100).round(1)
    
    display(bang_10_ngay.style.format({
        'Mở cửa': '{:.2f}',
        'Cao nhất': '{:.2f}',
        'Thấp nhất': '{:.2f}',
        'Đóng cửa': '{:.2f}',
        'Khối lượng': '{:,.0f}',
        '% vs IPO': '{:+.1f}%'
    }))
# Out:
# ...
# 📊 THỐNG KÊ GIÁ: 2513.HK
# ...
#
# ┌─────────────────────────────────────────────────────────────────────┐
# │  💰 GIÁ HIỆN TẠI                                                    │
# ├─────────────────────────────────────────────────────────────────────┤
# │  Giá đóng cửa gần nhất : HKD 65.95                          │
# │  So với giá IPO        : +52.5% 🟢                              │
# │  So với đỉnh           : -10.5%                                │
# ├─────────────────────────────────────────────────────────────────────┤
# │  📈 RANGE TỪ IPO                                                    │
# ├─────────────────────────────────────────────────────────────────────┤
# │  Giá IPO               : HKD 43.24                               │
# │  Giá cao nhất          : HKD 73.70                              │
# │  Giá thấp nhất         : HKD 48.00                              │
# │  Giá trung bình        : HKD 63.48                              │
# ...

# %%
# ═══════════════════════════════════════════════════════════════════════════════
# 📈 BIỂU ĐỒ GIÁ VÀ KHỐI LƯỢNG
# ═══════════════════════════════════════════════════════════════════════════════

if du_lieu is not None and not du_lieu.empty:
    
    # Tạo figure với 2 subplot (giá trên, volume dưới)
    fig, axes = plt.subplots(2, 1, figsize=(14, 8), gridspec_kw={'height_ratios': [3, 1]})
    fig.suptitle(f'📈 {MA_CK} - Giá và Khối lượng giao dịch từ IPO', fontsize=14, fontweight='bold')
    
    # ─────────────────────────────────────────────────────────────────────────────
    # BIỂU ĐỒ GIÁ (trên)
    # ─────────────────────────────────────────────────────────────────────────────
    ax1 = axes[0]
    
    # Vẽ giá đóng cửa
    ax1.plot(du_lieu.index, du_lieu['Close'], color='#2E86AB', linewidth=2, label='Giá đóng cửa')
    
    # Vẽ range High-Low (shaded area)
    ax1.fill_between(du_lieu.index, du_lieu['Low'], du_lieu['High'], 
                     alpha=0.2, color='#2E86AB', label='Range (Cao-Thấp)')
    
    # Đường giá IPO
    ax1.axhline(y=GIA_IPO, color='#E94F37', linestyle='--', linewidth=2, label=f'Giá IPO: {GIA_IPO}')
    
    # Đường giá trung bình
    gia_tb = du_lieu['Close'].mean()
    ax1.axhline(y=gia_tb, color='#F39C12', linestyle=':', linewidth=1.5, label=f'TB: {gia_tb:.2f}')
    
    ax1.set_ylabel('Giá (HKD)', fontsize=11)
    ax1.legend(loc='upper left', fontsize=9)
    ax1.grid(True, alpha=0.3)
    ax1.set_xlim(du_lieu.index[0], du_lieu.index[-1])
    
    # Highlight vùng lãi/lỗ so với IPO
    ax1.fill_between(du_lieu.index, GIA_IPO, du_lieu['Close'], 
                     where=(du_lieu['Close'] >= GIA_IPO), 
                     color='#27AE60', alpha=0.1)
    ax1.fill_between(du_lieu.index, GIA_IPO, du_lieu['Close'], 
                     where=(du_lieu['Close'] < GIA_IPO), 
                     color='#E74C3C', alpha=0.1)
    
    # ─────────────────────────────────────────────────────────────────────────────
    # BIỂU ĐỒ KHỐI LƯỢNG (dưới)
    # ─────────────────────────────────────────────────────────────────────────────
    ax2 = axes[1]
    
    # Màu thanh volume dựa trên giá tăng/giảm
    colors = ['#27AE60' if du_lieu['Close'].iloc[i] >= du_lieu['Open'].iloc[i] else '#E74C3C' 
              for i in range(len(du_lieu))]
    
    ax2.bar(du_lieu.index, du_lieu['Volume'], color=colors, alpha=0.7, width=0.8)
    
    # Đường trung bình volume
    vol_ma = du_lieu['Volume'].rolling(window=5).mean()
    ax2.plot(du_lieu.index, vol_ma, color='#F39C12', linewidth=1.5, label='MA5 Volume')
    
    ax2.set_ylabel('Khối lượng', fontsize=11)
    ax2.set_xlabel('Ngày', fontsize=11)
    ax2.legend(loc='upper left', fontsize=9)
    ax2.grid(True, alpha=0.3)
    ax2.set_xlim(du_lieu.index[0], du_lieu.index[-1])
    
    # Format trục Y của volume
    ax2.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, p: f'{x/1e6:.1f}M' if x >= 1e6 else f'{x/1e3:.0f}K'))
    
    plt.tight_layout()
    plt.show()
    
    # ─────────────────────────────────────────────────────────────────────────────
    # NHẬN XÉT TỰ ĐỘNG
    # ─────────────────────────────────────────────────────────────────────────────
    print("\n" + "=" * 70)
    print("🔍 NHẬN XÉT TỰ ĐỘNG")
    print("=" * 70)
    
    # Tính các chỉ số
    gia_hien_tai = du_lieu['Close'].iloc[-1]
    pct_vs_ipo = (gia_hien_tai / GIA_IPO - 1) * 100
    thay_doi_5_ngay = (du_lieu['Close'].iloc[-1] / du_lieu['Close'].iloc[-5] - 1) * 100 if len(du_lieu) >= 5 else 0
    vol_hom_nay = du_lieu['Volume'].iloc[-1]
    vol_tb = du_lieu['Volume'].mean()
    gia_thap_nhat = du_lieu['Low'].min()
    gia_cao_nhat = du_lieu['High'].max()
    vi_tri_range = (gia_hien_tai - gia_thap_nhat) / (gia_cao_nhat - gia_thap_nhat) * 100
    
    dau_ipo = '+' if pct_vs_ipo >= 0 else ''
    dau_5d = '+' if thay_doi_5_ngay >= 0 else ''
    vol_status = '(Cao hơn TB)' if vol_hom_nay > vol_tb else '(Thấp hơn TB)'
    
    print(f"""
📈 XU HƯỚNG:
   • Giá hiện tại: HKD {gia_hien_tai:.2f} ({dau_ipo}{pct_vs_ipo:.1f}% vs IPO)
   • Thay đổi 5 ngày: {dau_5d}{thay_doi_5_ngay:.1f}%
   • Vị trí trong range: {vi_tri_range:.0f}% từ đáy

📊 KHỐI LƯỢNG:
   • KL hôm nay: {vol_hom_nay:,.0f}
   • So với TB: {vol_hom_nay/vol_tb*100:.0f}% {vol_status}

🎯 MỨC GIÁ QUAN TRỌNG:
   • Hỗ trợ 1: HKD {gia_thap_nhat:.2f} (đáy)
   • Hỗ trợ 2: HKD {GIA_IPO:.2f} (giá IPO)
   • Kháng cự: HKD {gia_cao_nhat:.2f} (đỉnh)
""")
# Out:
# C:\Users\giang\AppData\Local\Temp\ipykernel_21768\388257947.py:67: UserWarning: Glyph 128200 (\N{CHART WITH UPWARDS TREND}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# ...
# 🔍 NHẬN XÉT TỰ ĐỘNG
# ...
#
# 📈 XU HƯỚNG:
#    • Giá hiện tại: HKD 65.95 (+52.5% vs IPO)
#    • Thay đổi 5 ngày: +2.6%
#    • Vị trí trong range: 70% từ đáy
#
# 📊 KHỐI LƯỢNG:
#    • KL hôm nay: 70,300
#    • So với TB: 6% (Thấp hơn TB)
#
# 🎯 MỨC GIÁ QUAN TRỌNG:
#    • Hỗ trợ 1: HKD 48.00 (đáy)
#    • Hỗ trợ 2: HKD 43.24 (giá IPO)
#    • Kháng cự: HKD 73.70 (đỉnh)

# %% [markdown]
# ---
#
# # 📚 HƯỚNG DẪN SỬ DỤNG TEMPLATE CHO IPO KHÁC
#
# ## Quy trình 5 bước
#
# ```
# ┌─────────────────────────────────────────────────────────────────────────────┐
# │  BƯỚC 1: CHUẨN BỊ                                                           │
# │  • Download prospectus từ HKEX/SGX/SSE                                      │
# │  • Duplicate notebook này, đổi tên theo công ty mới                         │
# │  • Update cell "cong_ty" với thông tin mới                                  │
# ├─────────────────────────────────────────────────────────────────────────────┤
# │  BƯỚC 2: TRÍCH XUẤT DỮ LIỆU                                                 │
# │  • Tìm "Financial Information" trong prospectus                             │
# │  • Copy doanh thu, lợi nhuận vào cell "tai_chinh"                           │
# │  • Tìm "Cornerstone Investors", update cell tương ứng                       │
# ├─────────────────────────────────────────────────────────────────────────────┤
# │  BƯỚC 3: NGHIÊN CỨU BỔ SUNG                                                 │
# │  • Search Crunchbase/PitchBook cho funding history                          │
# │  • Search tin tức cho analyst reports                                       │
# │  • Check Yahoo Finance cho giá hiện tại                                     │
# ├─────────────────────────────────────────────────────────────────────────────┤
# │  BƯỚC 4: CHẠY PHÂN TÍCH                                                     │
# │  • Run All cells                                                            │
# │  • Review output từng section                                               │
# │  • Điền đánh giá (🟢/🟡/🔴)                                                  │
# ├─────────────────────────────────────────────────────────────────────────────┤
# │  BƯỚC 5: RA QUYẾT ĐỊNH                                                      │
# │  • Hoàn thành phần Kết luận với thesis, risks                               │
# │  • Quyết định: MUA / THEO DÕI / TRÁNH                                       │
# │  • Đặt alerts và calendar reminders                                         │
# └─────────────────────────────────────────────────────────────────────────────┘
# ```
#
# ---
#
# ## 🔗 Nguồn dữ liệu (có link)
#
# ### Prospectus & Filings chính thức
#
# | Sàn | Link | Mô tả |
# |-----|------|-------|
# | **HKEX** | [HKEXnews Title Search](https://www1.hkexnews.hk/search/titlesearch.xhtml) | Tìm prospectus, announcements, circulars |
# | **HKEX** | [New Listings](https://www.hkex.com.hk/Market-Data/Securities-Prices/Equities?sc_lang=en) | Danh sách công ty mới niêm yết |
# | **SGX** | [SGX Rulebook](https://rulebook.sgx.com/rulebook/mainboard-rules) | Quy định niêm yết Singapore |
# | **SSE** | [STAR Market Rules](https://english.sse.com.cn/start/sserules/stocks/listing/) | Quy định sàn STAR Shanghai |
#
# ### Dữ liệu tài chính & giá
#
# | Nguồn | Link | Loại |
# |-------|------|------|
# | **Yahoo Finance** | [finance.yahoo.com](https://finance.yahoo.com) | Miễn phí - Giá, charts, financials |
# | **Google Finance** | [google.com/finance](https://www.google.com/finance) | Miễn phí - Giá, tin tức |
# | **TradingView** | [tradingview.com](https://www.tradingview.com) | Miễn phí/Trả phí - Charts, technical |
# | **Investing.com** | [investing.com](https://www.investing.com) | Miễn phí - Data đa dạng |
# | **Bloomberg** | [bloomberg.com](https://www.bloomberg.com) | Tin tức, data premium |
#
# ### Funding History & Startup Data
#
# | Nguồn | Link | Loại |
# |-------|------|------|
# | **Crunchbase** | [crunchbase.com](https://www.crunchbase.com) | Miễn phí (giới hạn) - Funding rounds |
# | **PitchBook** | [pitchbook.com](https://pitchbook.com) | Trả phí - Chi tiết đầy đủ |
# | **CB Insights** | [cbinsights.com](https://www.cbinsights.com) | Trả phí - Phân tích startup |
# | **IT桔子** | [itjuzi.com](https://www.itjuzi.com) | China startup database |
#
# ### Tin tức & Nghiên cứu
#
# | Nguồn | Link | Focus |
# |-------|------|-------|
# | **Reuters** | [reuters.com](https://www.reuters.com) | Tin tức tài chính global |
# | **SCMP** | [scmp.com](https://www.scmp.com) | Tin tức Hong Kong, China |
# | **36Kr** | [36kr.com](https://36kr.com) | Startup & Tech China |
# | **EqualOcean** | [equalocean.com](https://equalocean.com) | China tech analysis |
# | **Caixin** | [caixinglobal.com](https://www.caixinglobal.com) | China business news |
#
# ---
#
# ## 📖 Tài liệu tham khảo & Học thêm
#
# ### IPO Analysis Framework
#
# | Tài liệu | Link | Tác giả/Nguồn |
# |----------|------|---------------|
# | **IPO Lessons for Investors** | [Damodaran Blog](https://aswathdamodaran.blogspot.com/2019/10/ipo-lessons-for-public-market-investors.html) | Aswath Damodaran (NYU) |
# | **EY Global IPO Trends** | [EY IPO Report](https://www.ey.com/en_us/insights/ipo/trends) | Ernst & Young |
# | **HKEX Listing Rules** | [HKEX Rules](https://en-rules.hkex.com.hk/rulebook/main-board-listing-rules) | HKEX Official |
# | **How to Read a Prospectus** | [SEC Guide](https://www.sec.gov/oiea/investor-alerts-bulletins/ib_prospectus.html) | US SEC |
#
# ### Valuation & Financial Analysis
#
# | Tài liệu | Link | Mô tả |
# |----------|------|-------|
# | **Damodaran Online** | [Damodaran Data](http://pages.stern.nyu.edu/~adamodar/) | Datasets, spreadsheets, lectures miễn phí |
# | **Multiples.app** | [multiples.app](https://www.multiples.app) | SaaS & Tech valuation multiples |
# | **FinBox** | [finbox.com](https://finbox.com) | DCF templates, fair value |
# | **Simply Wall St** | [simplywall.st](https://simplywall.st) | Visual stock analysis |
#
# ### Surgical Robotics Industry (ZHIPU-B)
#
# | Tài liệu | Link | Mô tả |
# |----------|------|-------|
# | **Intuitive Surgical IR** | [ISRG Investors](https://isrg.intuitive.com/investors) | Benchmark số 1 ngành |
# | **Grand View Research** | [Surgical Robots Market](https://www.grandviewresearch.com/industry-analysis/surgical-robots-market) | Market size reports |
# | **MedRobot** | [medrobot.tech](https://medrobot.tech) | Tin tức robot y tế |
#
# ### AI & Chips Industry (Biren, Zhipu, Axera)
#
# | Tài liệu | Link | Mô tả |
# |----------|------|-------|
# | **SemiAnalysis** | [semianalysis.com](https://www.semianalysis.com) | Chip industry deep-dives |
# | **The Information** | [theinformation.com](https://www.theinformation.com) | Tech scoops (trả phí) |
# | **Import AI Newsletter** | [importai.net](https://importai.net) | AI research weekly |
# | **ChinAI Newsletter** | [chinai.substack.com](https://chinai.substack.com) | China AI translations |
#
# ---
#
# ## 🔖 Quick Links to Follow
#
# ### Twitter/X Accounts
#
# | Account | Handle | Focus |
# |---------|--------|-------|
# | IPO News | [@IPOborhood](https://twitter.com/IPOborhood) | IPO announcements |
# | Tech Scoops | [@EricNewcomer](https://twitter.com/EricNewcomer) | VC & Tech IPOs |
# | China Tech | [@ChinaTechBlog](https://twitter.com/ChinaTechBlog) | China tech news |
# | Semiconductors | [@SemiAnalysis_](https://twitter.com/SemiAnalysis_) | Chip industry |
#
# ### Newsletters đáng theo dõi
#
# | Newsletter | Link | Tần suất |
# |------------|------|----------|
# | **The Generalist** | [readthegeneralist.com](https://www.readthegeneralist.com) | Weekly deep-dives |
# | **Emerging Tech Brew** | [morningbrew.com/emerging-tech](https://www.morningbrew.com/emerging-tech) | Daily |
# | **Not Boring** | [notboring.co](https://www.notboring.co) | Weekly strategy |
# | **Interconnected** | [interconnected.blog](https://interconnected.blog) | China-US tech |
#
# ### Podcasts
#
# | Podcast | Link | Focus |
# |---------|------|-------|
# | **Acquired** | [acquired.fm](https://www.acquired.fm) | Company deep-dives |
# | **Invest Like the Best** | [joincolossus.com](https://www.joincolossus.com/episodes) | Investor interviews |
# | **China Talk** | [chinatalk.substack.com](https://chinatalk.substack.com) | China tech policy |
#
# ---
#
# ## ⚠️ Tuyên bố miễn trừ trách nhiệm
#
# > **QUAN TRỌNG**: Báo cáo này chỉ mang tính chất **nghiên cứu và giáo dục**.
# > Đây **KHÔNG PHẢI** lời khuyên đầu tư. Mọi quyết định đầu tư cần dựa trên
# > nghiên cứu của riêng bạn và tư vấn từ chuyên gia tài chính được cấp phép.
# >
# > Tác giả không chịu trách nhiệm cho bất kỳ tổn thất nào từ việc sử dụng
# > thông tin trong báo cáo này.
#
# ---
#
# **KẾT THÚC BÁO CÁO**
#
# *Template version: 4.0 | Cập nhật: 20/02/2026*
